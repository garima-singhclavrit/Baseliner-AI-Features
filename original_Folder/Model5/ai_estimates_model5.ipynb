# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
#
#    Variance  Risk_factor_int
# 0      6561                1
# 1       441                4
# 2       729                8
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Optimistic_estimate
oe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
oe_train = train_df_res["Optimistic"].to_numpy().reshape(-1,1)
oe_test = test_df_res["Optimistic"].to_numpy().reshape(-1,1)
oe_enc.fit(oe_train)
len_oe_enc = oe_enc.categories_[0].shape
print(len_oe_enc)

oe_train = oe_enc.transform(oe_train)
oe_test = oe_enc.transform(oe_test)
print(oe_train.shape, oe_test.shape)
# Out:
# (23,)
# (5791, 23) (644, 23)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Most_likely_estimate
mle_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
mle_train = train_df_res["Most_likely"].to_numpy().reshape(-1,1)
mle_test = test_df_res["Most_likely"].to_numpy().reshape(-1,1)
mle_enc.fit(mle_train)
len_mle_enc = mle_enc.categories_[0].shape
print(len_mle_enc)

mle_train = mle_enc.transform(mle_train)
mle_test = mle_enc.transform(mle_test)
print(mle_train.shape, mle_test.shape)
# Out:
# (22,)
# (5791, 22) (644, 22)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Pessimestic_Estimate
pes_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pes_train = train_df_res["Pessimistic"].to_numpy().reshape(-1,1)
pes_test = test_df_res["Pessimistic"].to_numpy().reshape(-1,1)
pes_enc.fit(pes_train)
len_pes_enc = pes_enc.categories_[0].shape
print(len_pes_enc)

pes_train = pes_enc.transform(pes_train)
pes_test = pes_enc.transform(pes_test)
print(pes_train.shape, pes_test.shape)
# Out:
# (29,)
# (5791, 29) (644, 29)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Risk_factor_int
rfi_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
rfi_train = train_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_test = test_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_enc.fit(rfi_train)
len_rfi_enc = rfi_enc.categories_[0].shape
print(len_rfi_enc)

rfi_train = rfi_enc.transform(rfi_train)
rfi_test = rfi_enc.transform(rfi_test)
print(rfi_train.shape, rfi_test.shape)
# Out:
# (11,)
# (5791, 11) (644, 11)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
# tn_train = gpt_model.vectors(train_df_res["Task_name"])
# np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
# print(type(tn_train))
# print(tn_train.shape)

# %%
# testing embeddings
# tn_test = gpt_model.vectors(test_df_res["Task_name"])
# np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
# print(type(tn_test))
# print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
# td_train = gpt_model.vectors(train_df_res["Task_description"])
# np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
# print(type(td_train))
# print(td_train.shape)

# %%
# testing embeddings
# td_test = gpt_model.vectors(test_df_res["Task_description"])
# np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
# print(type(td_test))
# print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test= np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %%
tn_train.shape
# Out:
# (5791, 768)

# %%
td_train.shape
# Out:
# (5791, 768)

# %%
td_test.shape
# Out:
# (644, 768)

# %%
tn_test.shape
# Out:
# (644, 768)

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)

# Branch-6 Risk Factor multiplied by 100
inp6 = tf.keras.Input(shape=(11,), dtype=tf.int32, name="input_layer_6")
lay6 = tf.keras.layers.Dense(16, activation='relu')(inp6)

# Branch-7 Optimistic estimate
inp7 = tf.keras.Input(shape=(23,), dtype=tf.int32, name="input_layer_7")
lay7 = tf.keras.layers.Dense(32, activation='relu')(inp7)

# Branch-8 Most Likely estimate
inp8 = tf.keras.Input(shape=(22,), dtype=tf.int32, name="input_layer_8")
lay8 = tf.keras.layers.Dense(32, activation='relu')(inp8)

# Branch-9 Pessimistic estimate
inp9 = tf.keras.Input(shape=(29,), dtype=tf.int32, name="input_layer_9")
lay9 = tf.keras.layers.Dense(32, activation='relu')(inp9)

# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5, lay6, lay7, lay8, lay9])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5, inp6, inp7, inp8, inp9], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  input_layer_6 (InputLayer)  [(None, 11)]                 0         []
#
#  input_layer_7 (InputLayer)  [(None, 23)]                 0         []
#
#  input_layer_8 (InputLayer)  [(None, 22)]                 0         []
#
#  input_layer_9 (InputLayer)  [(None, 29)]                 0         []
#
#  dense_12 (Dense)            (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_13 (Dense)            (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_14 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_15 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_16 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  dense_17 (Dense)            (None, 16)                   192       ['input_layer_6[0][0]']
#
#  dense_18 (Dense)            (None, 32)                   768       ['input_layer_7[0][0]']
#
#  dense_19 (Dense)            (None, 32)                   736       ['input_layer_8[0][0]']
#
#  dense_20 (Dense)            (None, 32)                   960       ['input_layer_9[0][0]']
#
#  concatenate_1 (Concatenate  (None, 420)                  0         ['dense_12[0][0]',
#  )                                                                   'dense_13[0][0]',
#                                                                      'dense_14[0][0]',
#                                                                      'dense_15[0][0]',
#                                                                      'dense_16[0][0]',
#                                                                      'dense_17[0][0]',
#                                                                      'dense_18[0][0]',
#                                                                      'dense_19[0][0]',
#                                                                      'dense_20[0][0]']
#
#  dense_21 (Dense)            (None, 384)                  161664    ['concatenate_1[0][0]']
#
#  dense_22 (Dense)            (None, 128)                  49280     ['dense_21[0][0]']
#
#  dense_23 (Dense)            (None, 26)                   3354      ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 415022 (1.58 MB)
# Trainable params: 415022 (1.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train, rfi_train, oe_train, mle_train, pes_train], ae_train,
    epochs=100,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test, oe_test, mle_test, pes_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 176/181 [============================>.] - ETA: 0s - loss: 1.5167 - accuracy: 0.4142
# Epoch 1: loss improved from inf to 1.50151, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 5s 13ms/step - loss: 1.5015 - accuracy: 0.4184 - val_loss: 0.9775 - val_accuracy: 0.4814
# Epoch 2/100
#   1/181 [..............................] - ETA: 2s - loss: 0.9704 - accuracy: 0.3438
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 179/181 [============================>.] - ETA: 0s - loss: 0.8743 - accuracy: 0.4873
# Epoch 2: loss improved from 1.50151 to 0.87445, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.8744 - accuracy: 0.4873 - val_loss: 0.8489 - val_accuracy: 0.5171
# Epoch 3/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.8056 - accuracy: 0.5084
# Epoch 3: loss improved from 0.87445 to 0.80582, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.8058 - accuracy: 0.5091 - val_loss: 0.7887 - val_accuracy: 0.5186
# Epoch 4/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7633 - accuracy: 0.5089
# Epoch 4: loss improved from 0.80582 to 0.76329, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.7633 - accuracy: 0.5089 - val_loss: 0.7684 - val_accuracy: 0.4984
# Epoch 5/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7477 - accuracy: 0.5016
# Epoch 5: loss improved from 0.76329 to 0.74758, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 5s 26ms/step - loss: 0.7476 - accuracy: 0.5011 - val_loss: 0.7344 - val_accuracy: 0.5342
# Epoch 6/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7369 - accuracy: 0.5155
# Epoch 6: loss improved from 0.74758 to 0.73717, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 4s 22ms/step - loss: 0.7372 - accuracy: 0.5155 - val_loss: 0.7467 - val_accuracy: 0.5109
# Epoch 7/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.5066
# Epoch 7: loss improved from 0.73717 to 0.72531, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7253 - accuracy: 0.5051 - val_loss: 0.7390 - val_accuracy: 0.4953
# Epoch 8/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7141 - accuracy: 0.5224
# Epoch 8: loss improved from 0.72531 to 0.71314, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7131 - accuracy: 0.5231 - val_loss: 0.7245 - val_accuracy: 0.5140
# Epoch 9/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5148
# Epoch 9: loss improved from 0.71314 to 0.70860, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7086 - accuracy: 0.5156 - val_loss: 0.7022 - val_accuracy: 0.5357
# Epoch 10/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7004 - accuracy: 0.5246
# Epoch 10: loss improved from 0.70860 to 0.70120, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7012 - accuracy: 0.5220 - val_loss: 0.7056 - val_accuracy: 0.5217
# Epoch 11/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6943 - accuracy: 0.5143
# Epoch 11: loss improved from 0.70120 to 0.69423, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6942 - accuracy: 0.5153 - val_loss: 0.7185 - val_accuracy: 0.5078
# Epoch 12/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.5274
# Epoch 12: loss did not improve from 0.69423
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6954 - accuracy: 0.5274 - val_loss: 0.6971 - val_accuracy: 0.5031
# Epoch 13/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6921 - accuracy: 0.5161
# Epoch 13: loss improved from 0.69423 to 0.69193, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6919 - accuracy: 0.5168 - val_loss: 0.7022 - val_accuracy: 0.5031
# Epoch 14/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5332
# Epoch 14: loss improved from 0.69193 to 0.69181, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6918 - accuracy: 0.5332 - val_loss: 0.6940 - val_accuracy: 0.5047
# Epoch 15/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6868 - accuracy: 0.5249
# Epoch 15: loss improved from 0.69181 to 0.68587, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6859 - accuracy: 0.5251 - val_loss: 0.6974 - val_accuracy: 0.5140
# Epoch 16/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6856 - accuracy: 0.5216
# Epoch 16: loss improved from 0.68587 to 0.68558, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6856 - accuracy: 0.5213 - val_loss: 0.6877 - val_accuracy: 0.5140
# Epoch 17/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6856 - accuracy: 0.5144
# Epoch 17: loss did not improve from 0.68558
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6860 - accuracy: 0.5141 - val_loss: 0.6876 - val_accuracy: 0.5342
# Epoch 18/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6813 - accuracy: 0.5209
# Epoch 18: loss improved from 0.68558 to 0.68154, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6815 - accuracy: 0.5208 - val_loss: 0.6849 - val_accuracy: 0.5093
# Epoch 19/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.5144
# Epoch 19: loss improved from 0.68154 to 0.68009, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6801 - accuracy: 0.5144 - val_loss: 0.6783 - val_accuracy: 0.5311
# Epoch 20/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6805 - accuracy: 0.5152
# Epoch 20: loss did not improve from 0.68009
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6809 - accuracy: 0.5153 - val_loss: 0.6773 - val_accuracy: 0.5047
# Epoch 21/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6794 - accuracy: 0.5226
# Epoch 21: loss improved from 0.68009 to 0.67962, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6796 - accuracy: 0.5222 - val_loss: 0.6838 - val_accuracy: 0.5295
# Epoch 22/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6771 - accuracy: 0.5200
# Epoch 22: loss improved from 0.67962 to 0.67715, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6771 - accuracy: 0.5199 - val_loss: 0.6855 - val_accuracy: 0.5093
# Epoch 23/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6756 - accuracy: 0.5263
# Epoch 23: loss improved from 0.67715 to 0.67544, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6754 - accuracy: 0.5274 - val_loss: 0.6839 - val_accuracy: 0.5264
# Epoch 24/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6771 - accuracy: 0.5149
# Epoch 24: loss did not improve from 0.67544
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6771 - accuracy: 0.5149 - val_loss: 0.6755 - val_accuracy: 0.5093
# Epoch 25/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6768 - accuracy: 0.5214
# Epoch 25: loss did not improve from 0.67544
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6761 - accuracy: 0.5208 - val_loss: 0.6759 - val_accuracy: 0.5295
# Epoch 26/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6759 - accuracy: 0.5235
# Epoch 26: loss did not improve from 0.67544
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6761 - accuracy: 0.5229 - val_loss: 0.6767 - val_accuracy: 0.5248
# Epoch 27/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6735 - accuracy: 0.5200
# Epoch 27: loss improved from 0.67544 to 0.67344, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6734 - accuracy: 0.5203 - val_loss: 0.6834 - val_accuracy: 0.5078
# Epoch 28/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.5217
# Epoch 28: loss did not improve from 0.67344
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6744 - accuracy: 0.5217 - val_loss: 0.6800 - val_accuracy: 0.5078
# Epoch 29/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.5284
# Epoch 29: loss did not improve from 0.67344
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6743 - accuracy: 0.5284 - val_loss: 0.6779 - val_accuracy: 0.5311
# Epoch 30/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6738 - accuracy: 0.5244
# Epoch 30: loss did not improve from 0.67344
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6738 - accuracy: 0.5244 - val_loss: 0.6826 - val_accuracy: 0.5093
# Epoch 31/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.5117
# Epoch 31: loss did not improve from 0.67344
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6753 - accuracy: 0.5118 - val_loss: 0.6796 - val_accuracy: 0.5280
# Epoch 32/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6704 - accuracy: 0.5265
# Epoch 32: loss improved from 0.67344 to 0.67184, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6718 - accuracy: 0.5248 - val_loss: 0.6819 - val_accuracy: 0.5155
# Epoch 33/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6752 - accuracy: 0.5201
# Epoch 33: loss did not improve from 0.67184
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6750 - accuracy: 0.5199 - val_loss: 0.6788 - val_accuracy: 0.5062
# Epoch 34/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.5135
# Epoch 34: loss did not improve from 0.67184
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6725 - accuracy: 0.5141 - val_loss: 0.6859 - val_accuracy: 0.5109
# Epoch 35/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.5258
# Epoch 35: loss did not improve from 0.67184
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6731 - accuracy: 0.5265 - val_loss: 0.6777 - val_accuracy: 0.5171
# Epoch 36/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6697 - accuracy: 0.5349
# Epoch 36: loss improved from 0.67184 to 0.67012, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6701 - accuracy: 0.5344 - val_loss: 0.6788 - val_accuracy: 0.5140
# Epoch 37/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.5207
# Epoch 37: loss did not improve from 0.67012
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6715 - accuracy: 0.5205 - val_loss: 0.6813 - val_accuracy: 0.5217
# Epoch 38/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6711 - accuracy: 0.5138
# Epoch 38: loss did not improve from 0.67012
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6709 - accuracy: 0.5148 - val_loss: 0.6735 - val_accuracy: 0.5093
# Epoch 39/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6714 - accuracy: 0.5178
# Epoch 39: loss did not improve from 0.67012
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6711 - accuracy: 0.5184 - val_loss: 0.6799 - val_accuracy: 0.5357
# Epoch 40/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6706 - accuracy: 0.5246
# Epoch 40: loss did not improve from 0.67012
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6705 - accuracy: 0.5248 - val_loss: 0.6743 - val_accuracy: 0.5093
# Epoch 41/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6687 - accuracy: 0.5183
# Epoch 41: loss improved from 0.67012 to 0.66905, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6691 - accuracy: 0.5179 - val_loss: 0.6768 - val_accuracy: 0.5450
# Epoch 42/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6704 - accuracy: 0.5189
# Epoch 42: loss did not improve from 0.66905
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6703 - accuracy: 0.5193 - val_loss: 0.6723 - val_accuracy: 0.5404
# Epoch 43/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6709 - accuracy: 0.5226
# Epoch 43: loss did not improve from 0.66905
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6704 - accuracy: 0.5222 - val_loss: 0.6678 - val_accuracy: 0.5295
# Epoch 44/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6679 - accuracy: 0.5215
# Epoch 44: loss improved from 0.66905 to 0.66769, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6677 - accuracy: 0.5224 - val_loss: 0.6674 - val_accuracy: 0.5481
# Epoch 45/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.5293
# Epoch 45: loss did not improve from 0.66769
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6699 - accuracy: 0.5293 - val_loss: 0.6742 - val_accuracy: 0.5031
# Epoch 46/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.5210
# Epoch 46: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6687 - accuracy: 0.5222 - val_loss: 0.6733 - val_accuracy: 0.5031
# Epoch 47/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6686 - accuracy: 0.5250
# Epoch 47: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6686 - accuracy: 0.5250 - val_loss: 0.6701 - val_accuracy: 0.5388
# Epoch 48/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.5190
# Epoch 48: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6688 - accuracy: 0.5187 - val_loss: 0.6760 - val_accuracy: 0.4953
# Epoch 49/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6695 - accuracy: 0.5237
# Epoch 49: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6694 - accuracy: 0.5248 - val_loss: 0.6764 - val_accuracy: 0.5171
# Epoch 50/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.5286
# Epoch 50: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6682 - accuracy: 0.5300 - val_loss: 0.6738 - val_accuracy: 0.5202
# Epoch 51/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6680 - accuracy: 0.5237
# Epoch 51: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6680 - accuracy: 0.5248 - val_loss: 0.6729 - val_accuracy: 0.5109
# Epoch 52/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6678 - accuracy: 0.5237
# Epoch 52: loss did not improve from 0.66769
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6680 - accuracy: 0.5227 - val_loss: 0.6677 - val_accuracy: 0.5419
# Epoch 53/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6663 - accuracy: 0.5349
# Epoch 53: loss improved from 0.66769 to 0.66622, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 18ms/step - loss: 0.6662 - accuracy: 0.5348 - val_loss: 0.6717 - val_accuracy: 0.5217
# Epoch 54/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6671 - accuracy: 0.5319
# Epoch 54: loss did not improve from 0.66622
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6671 - accuracy: 0.5319 - val_loss: 0.6663 - val_accuracy: 0.5311
# Epoch 55/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.5199
# Epoch 55: loss did not improve from 0.66622
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6669 - accuracy: 0.5203 - val_loss: 0.6726 - val_accuracy: 0.5155
# Epoch 56/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6668 - accuracy: 0.5181
# Epoch 56: loss did not improve from 0.66622
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6669 - accuracy: 0.5182 - val_loss: 0.6668 - val_accuracy: 0.5481
# Epoch 57/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6658 - accuracy: 0.5320
# Epoch 57: loss improved from 0.66622 to 0.66580, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6658 - accuracy: 0.5317 - val_loss: 0.6795 - val_accuracy: 0.4876
# Epoch 58/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6671 - accuracy: 0.5206
# Epoch 58: loss did not improve from 0.66580
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6671 - accuracy: 0.5206 - val_loss: 0.6725 - val_accuracy: 0.5093
# Epoch 59/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6685 - accuracy: 0.5215
# Epoch 59: loss did not improve from 0.66580
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6684 - accuracy: 0.5222 - val_loss: 0.6699 - val_accuracy: 0.5186
# Epoch 60/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6655 - accuracy: 0.5302
# Epoch 60: loss improved from 0.66580 to 0.66579, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6658 - accuracy: 0.5288 - val_loss: 0.6656 - val_accuracy: 0.5202
# Epoch 61/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6670 - accuracy: 0.5314
# Epoch 61: loss did not improve from 0.66579
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6668 - accuracy: 0.5322 - val_loss: 0.6724 - val_accuracy: 0.5109
# Epoch 62/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6653 - accuracy: 0.5320
# Epoch 62: loss did not improve from 0.66579
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6658 - accuracy: 0.5308 - val_loss: 0.6679 - val_accuracy: 0.5481
# Epoch 63/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.5262
# Epoch 63: loss improved from 0.66579 to 0.66548, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6655 - accuracy: 0.5262 - val_loss: 0.6700 - val_accuracy: 0.5155
# Epoch 64/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6658 - accuracy: 0.5347
# Epoch 64: loss did not improve from 0.66548
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6658 - accuracy: 0.5346 - val_loss: 0.6729 - val_accuracy: 0.5280
# Epoch 65/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6654 - accuracy: 0.5163
# Epoch 65: loss did not improve from 0.66548
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6657 - accuracy: 0.5153 - val_loss: 0.6683 - val_accuracy: 0.5217
# Epoch 66/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6652 - accuracy: 0.5208
# Epoch 66: loss did not improve from 0.66548
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6663 - accuracy: 0.5193 - val_loss: 0.6684 - val_accuracy: 0.5171
# Epoch 67/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6671 - accuracy: 0.5168
# Epoch 67: loss did not improve from 0.66548
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6666 - accuracy: 0.5175 - val_loss: 0.6702 - val_accuracy: 0.5016
# Epoch 68/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6643 - accuracy: 0.5284
# Epoch 68: loss improved from 0.66548 to 0.66456, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6646 - accuracy: 0.5275 - val_loss: 0.6727 - val_accuracy: 0.5202
# Epoch 69/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6652 - accuracy: 0.5223
# Epoch 69: loss did not improve from 0.66456
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6656 - accuracy: 0.5224 - val_loss: 0.6694 - val_accuracy: 0.5388
# Epoch 70/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.6652 - accuracy: 0.5288
# Epoch 70: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6648 - accuracy: 0.5288 - val_loss: 0.6682 - val_accuracy: 0.5357
# Epoch 71/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6644 - accuracy: 0.5309
# Epoch 71: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6648 - accuracy: 0.5298 - val_loss: 0.6680 - val_accuracy: 0.5280
# Epoch 72/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6648 - accuracy: 0.5239
# Epoch 72: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6650 - accuracy: 0.5231 - val_loss: 0.6695 - val_accuracy: 0.5047
# Epoch 73/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.5228
# Epoch 73: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6662 - accuracy: 0.5218 - val_loss: 0.6677 - val_accuracy: 0.5047
# Epoch 74/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6677 - accuracy: 0.5239
# Epoch 74: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6678 - accuracy: 0.5239 - val_loss: 0.6726 - val_accuracy: 0.5155
# Epoch 75/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6662 - accuracy: 0.5190
# Epoch 75: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6664 - accuracy: 0.5184 - val_loss: 0.6675 - val_accuracy: 0.5217
# Epoch 76/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6654 - accuracy: 0.5233
# Epoch 76: loss did not improve from 0.66456
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6650 - accuracy: 0.5236 - val_loss: 0.6680 - val_accuracy: 0.5264
# Epoch 77/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.5293
# Epoch 77: loss improved from 0.66456 to 0.66432, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 19ms/step - loss: 0.6643 - accuracy: 0.5293 - val_loss: 0.6677 - val_accuracy: 0.5186
# Epoch 78/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.6651 - accuracy: 0.5223
# Epoch 78: loss did not improve from 0.66432
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6648 - accuracy: 0.5220 - val_loss: 0.6661 - val_accuracy: 0.5357
# Epoch 79/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.5280
# Epoch 79: loss improved from 0.66432 to 0.66427, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6643 - accuracy: 0.5284 - val_loss: 0.6686 - val_accuracy: 0.5186
# Epoch 80/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6640 - accuracy: 0.5274
# Epoch 80: loss did not improve from 0.66427
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6644 - accuracy: 0.5270 - val_loss: 0.6681 - val_accuracy: 0.5155
# Epoch 81/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.5137
# Epoch 81: loss improved from 0.66427 to 0.66414, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6641 - accuracy: 0.5141 - val_loss: 0.6679 - val_accuracy: 0.5326
# Epoch 82/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6641 - accuracy: 0.5314
# Epoch 82: loss did not improve from 0.66414
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6643 - accuracy: 0.5313 - val_loss: 0.6697 - val_accuracy: 0.5124
# Epoch 83/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.5244
# Epoch 83: loss improved from 0.66414 to 0.66411, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6641 - accuracy: 0.5243 - val_loss: 0.6658 - val_accuracy: 0.5233
# Epoch 84/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6637 - accuracy: 0.5245
# Epoch 84: loss improved from 0.66411 to 0.66391, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6639 - accuracy: 0.5243 - val_loss: 0.6686 - val_accuracy: 0.5171
# Epoch 85/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6639 - accuracy: 0.5233
# Epoch 85: loss did not improve from 0.66391
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6642 - accuracy: 0.5250 - val_loss: 0.6714 - val_accuracy: 0.5280
# Epoch 86/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.5369
# Epoch 86: loss improved from 0.66391 to 0.66296, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6630 - accuracy: 0.5369 - val_loss: 0.6664 - val_accuracy: 0.5109
# Epoch 87/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.5263
# Epoch 87: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6643 - accuracy: 0.5262 - val_loss: 0.6698 - val_accuracy: 0.4953
# Epoch 88/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.5286
# Epoch 88: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6678 - accuracy: 0.5296 - val_loss: 0.6790 - val_accuracy: 0.5186
# Epoch 89/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6661 - accuracy: 0.5169
# Epoch 89: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6665 - accuracy: 0.5165 - val_loss: 0.6694 - val_accuracy: 0.5109
# Epoch 90/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6640 - accuracy: 0.5300
# Epoch 90: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6642 - accuracy: 0.5291 - val_loss: 0.6687 - val_accuracy: 0.5186
# Epoch 91/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6642 - accuracy: 0.5243
# Epoch 91: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6642 - accuracy: 0.5243 - val_loss: 0.6695 - val_accuracy: 0.5140
# Epoch 92/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.5220
# Epoch 92: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 14ms/step - loss: 0.6644 - accuracy: 0.5208 - val_loss: 0.6675 - val_accuracy: 0.5248
# Epoch 93/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6638 - accuracy: 0.5196
# Epoch 93: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 14ms/step - loss: 0.6639 - accuracy: 0.5193 - val_loss: 0.6678 - val_accuracy: 0.5155
# Epoch 94/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6637 - accuracy: 0.5215
# Epoch 94: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6636 - accuracy: 0.5222 - val_loss: 0.6692 - val_accuracy: 0.5171
# Epoch 95/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6636 - accuracy: 0.5276
# Epoch 95: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6636 - accuracy: 0.5279 - val_loss: 0.6681 - val_accuracy: 0.5078
# Epoch 96/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6635 - accuracy: 0.5244
# Epoch 96: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6635 - accuracy: 0.5244 - val_loss: 0.6703 - val_accuracy: 0.5295
# Epoch 97/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6633 - accuracy: 0.5307
# Epoch 97: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6632 - accuracy: 0.5313 - val_loss: 0.6694 - val_accuracy: 0.5047
# Epoch 98/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6641 - accuracy: 0.5173
# Epoch 98: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6641 - accuracy: 0.5179 - val_loss: 0.6676 - val_accuracy: 0.5171
# Epoch 99/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6640 - accuracy: 0.5214
# Epoch 99: loss did not improve from 0.66296
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6639 - accuracy: 0.5215 - val_loss: 0.6668 - val_accuracy: 0.5264
# Epoch 100/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6630 - accuracy: 0.5321
# Epoch 100: loss improved from 0.66296 to 0.66294, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6629 - accuracy: 0.5324 - val_loss: 0.6691 - val_accuracy: 0.5016

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model5/model5.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test, oe_test, mle_test, pes_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test, oe_test, mle_test, pes_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(3)
# Out:
# {'loss': [1.5015076398849487, 0.8744490742683411, 0.8058249950408936, 0.7632899880409241, 0.7475754022598267, 0.7371658086776733, 0.7253066897392273, 0.7131375670433044, 0.7085978388786316, 0.7011968493461609, 0.6942271590232849, 0.6954235434532166, 0.6919319033622742, 0.6918119788169861, 0.6858657002449036, 0.68558269739151, 0.6859502196311951, 0.6815438866615295, 0.6800907254219055, 0.6808831691741943, 0.679620623588562, 0.6771450638771057, 0.675444483757019, 0.6770991683006287, 0.676064670085907, 0.6761173009872437, 0.6734427213668823, 0.6743815541267395, 0.6742904186248779, 0.67376309633255, 0.6752564311027527, 0.6718370318412781, 0.6750488877296448, 0.6724839806556702, 0.6731125116348267, 0.6701216697692871, 0.6715318560600281, 0.6708789467811584, 0.6710616946220398, 0.6704797744750977, 0.6690531373023987, 0.6702630519866943, 0.6703897714614868, 0.6676865220069885, 0.6698853969573975, 0.668691873550415, 0.6685929894447327, 0.6687564849853516, 0.6693800687789917, 0.668232262134552, 0.6679642796516418, 0.6680447459220886, 0.6662189364433289, 0.6671102046966553, 0.666888415813446, 0.6669281721115112, 0.6657999157905579, 0.6670647263526917, 0.6683751344680786, 0.6657947301864624, 0.6667550802230835, 0.6658201217651367, 0.6654840707778931, 0.665797233581543, 0.6657019257545471, 0.6662732362747192, 0.6665686368942261, 0.6645580530166626, 0.665555477142334, 0.6647862195968628, 0.664814293384552, 0.6650235652923584, 0.666191816329956, 0.6677941083908081, 0.6664420366287231, 0.6650395393371582, 0.66432124376297, 0.6647974848747253, 0.6642683148384094, 0.664394199848175, 0.6641406416893005, 0.664339005947113, 0.6641072630882263, 0.663914680480957, 0.6641954779624939, 0.6629595756530762, 0.6642993688583374, 0.6677812933921814, 0.6665169596672058, 0.6641595959663391, 0.6642086505889893, 0.6644221544265747, 0.6639103889465332, 0.6635967493057251, 0.6635574102401733, 0.6635467410087585, 0.6632336974143982, 0.6640538573265076, 0.663862943649292, 0.662935733795166], 'accuracy': [0.4184078872203827, 0.48730790615081787, 0.5090658068656921, 0.5088931322097778, 0.5011224150657654, 0.5154550075531006, 0.5050941109657288, 0.523052990436554, 0.5156276822090149, 0.5220169425010681, 0.5152823328971863, 0.527370035648346, 0.5168364644050598, 0.5332412123680115, 0.5251252055168152, 0.5213261842727661, 0.5140735507011414, 0.5208081603050232, 0.51441890001297, 0.5152823328971863, 0.5221896171569824, 0.5199447274208069, 0.527370035648346, 0.5149369835853577, 0.5208081603050232, 0.5228803157806396, 0.5202900767326355, 0.5216715335845947, 0.5284061431884766, 0.5244344472885132, 0.5118287205696106, 0.5247798562049866, 0.5199447274208069, 0.5140735507011414, 0.5265066623687744, 0.5344499945640564, 0.5204628109931946, 0.5147643089294434, 0.5183905959129333, 0.5247798562049866, 0.5178725719451904, 0.5192540287971497, 0.5221896171569824, 0.5223622918128967, 0.5292695760726929, 0.5221896171569824, 0.5249525308609009, 0.518735945224762, 0.5247798562049866, 0.5299602746963501, 0.5247798562049866, 0.5227076411247253, 0.534795343875885, 0.5318597555160522, 0.5202900767326355, 0.518217921257019, 0.5316870808601379, 0.5206354856491089, 0.5221896171569824, 0.5287514925003052, 0.5322051644325256, 0.5308237075805664, 0.5261613130569458, 0.5346226692199707, 0.5152823328971863, 0.5192540287971497, 0.5175272226333618, 0.5275427103042603, 0.5223622918128967, 0.5287514925003052, 0.5297876000404358, 0.523052990436554, 0.5218442678451538, 0.5239164233207703, 0.5183905959129333, 0.5235710740089417, 0.5292695760726929, 0.5220169425010681, 0.5284061431884766, 0.5270246863365173, 0.5140735507011414, 0.5313417315483093, 0.5242617726325989, 0.5242617726325989, 0.5249525308609009, 0.5368675589561462, 0.5261613130569458, 0.5296149253845215, 0.5164911150932312, 0.5290969014167786, 0.5242617726325989, 0.5208081603050232, 0.5192540287971497, 0.5221896171569824, 0.5278881192207336, 0.5244344472885132, 0.5313417315483093, 0.5178725719451904, 0.5214988589286804, 0.5323778390884399], 'val ...
# 41/41 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.5016
# 21/21 [==============================] - 0s 5ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Standard_deviation  Risk_factor  Standard_confidence  High_confidence  \
# 0                0.17         0.01                15.83            15.92
# 1                0.17         0.04                 3.83             3.92
# 2                0.33         0.08                 4.00             4.17
#
#    Higher_confidence  Highest_confidence  Final_estimate  Variance  \
# 0              16.05               16.23              15      6561
# 1               4.05                4.23               3       441
# 2               4.42                4.77               4       729
#
#    Risk_factor_int  Ai_estimate
# 0                1           17
# 1                4            4
# 2                8            4
#
# [3 rows x 23 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           16  ...                0.17         0.01                15.83
# 1            4  ...                0.17         0.04                 3.83
# 2            5  ...                0.33         0.08                 4.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      6561                1           17
# 1       441                4            4
# 2       729                8            4
#
# [3 rows x 21 columns]

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model5/Model5_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.83                0.17         0.01
# 1  ...              5.00                0.33         0.07
# 2  ...              8.67                0.00         0.00
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.83            16.92              17.05
# 1                 5.00             5.17               5.42
# 2                 8.67             8.67               8.67
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.23              16      7396                1
# 1                5.77               5      1024                7
# 2                8.67               8      1600                0
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)

rfi_testdata = df_test["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_testdata = rfi_enc.transform(rfi_testdata)
print(rfi_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)
# (21, 11)

# %%
import tensorflow as tf

# %%
model4 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5')
model4.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  input_layer_6 (InputLayer)  [(None, 11)]                 0         []
#
#  dense_10 (Dense)            (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_11 (Dense)            (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_12 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_13 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_14 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  dense_15 (Dense)            (None, 16)                   192       ['input_layer_6[0][0]']
#
#  concatenate_1 (Concatenate  (None, 324)                  0         ['dense_10[0][0]',
#  )                                                                   'dense_11[0][0]',
#                                                                      'dense_12[0][0]',
#                                                                      'dense_13[0][0]',
#                                                                      'dense_14[0][0]',
#                                                                      'dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 384)                  124800    ['concatenate_1[0][0]']
#
#  dense_17 (Dense)            (None, 128)                  49280     ['dense_16[0][0]']
#
#  dense_18 (Dense)            (None, 26)                   3354      ['dense_17[0][0]']
#
# ==================================================================================================
# Total params: 375694 (1.43 MB)
# Trainable params: 375694 (1.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model4.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata, rfi_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/Model4_results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            6  ...                0.33         0.07                 5.00
# 2            8  ...                0.00         0.00                 8.67
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             5.17               5.42                5.77               5
# 2             8.67               8.67                8.67               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1      1024                7            0
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
