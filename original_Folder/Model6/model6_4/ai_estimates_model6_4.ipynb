# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=300,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/300
# 171/181 [===========================>..] - ETA: 0s - loss: 2.1285 - accuracy: 0.2792
# Epoch 1: loss improved from inf to 2.07829, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - 8s 8ms/step - loss: 2.0783 - accuracy: 0.2896 - val_loss: 1.1918 - val_accuracy: 0.4534
# Epoch 2/300
# 175/181 [============================>.] - ETA: 0s - loss: 1.0075 - accuracy: 0.4725
# Epoch 2: loss improved from 2.07829 to 1.00390, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 1.0039 - accuracy: 0.4731 - val_loss: 0.9623 - val_accuracy: 0.4627
# Epoch 3/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.8699 - accuracy: 0.4946
# Epoch 3: loss improved from 1.00390 to 0.86749, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.8675 - accuracy: 0.4942 - val_loss: 0.8539 - val_accuracy: 0.4783
# Epoch 4/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.8327 - accuracy: 0.4924
# Epoch 4: loss improved from 0.86749 to 0.82812, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.8281 - accuracy: 0.4939 - val_loss: 0.8413 - val_accuracy: 0.4829
# Epoch 5/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.8062 - accuracy: 0.5042
# Epoch 5: loss improved from 0.82812 to 0.80700, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.8070 - accuracy: 0.5046 - val_loss: 0.8101 - val_accuracy: 0.4938
# Epoch 6/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7908 - accuracy: 0.5082
# Epoch 6: loss improved from 0.80700 to 0.79049, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7905 - accuracy: 0.5079 - val_loss: 0.8045 - val_accuracy: 0.5016
# Epoch 7/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7770 - accuracy: 0.5122
# Epoch 7: loss improved from 0.79049 to 0.77698, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7770 - accuracy: 0.5122 - val_loss: 0.8004 - val_accuracy: 0.4938
# Epoch 8/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7723 - accuracy: 0.5087
# Epoch 8: loss improved from 0.77698 to 0.77136, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7714 - accuracy: 0.5099 - val_loss: 0.7810 - val_accuracy: 0.4907
# Epoch 9/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7588 - accuracy: 0.5148
# Epoch 9: loss improved from 0.77136 to 0.75884, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7588 - accuracy: 0.5148 - val_loss: 0.7662 - val_accuracy: 0.4938
# Epoch 10/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7572 - accuracy: 0.5122
# Epoch 10: loss improved from 0.75884 to 0.75807, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7581 - accuracy: 0.5096 - val_loss: 0.7604 - val_accuracy: 0.4829
# Epoch 11/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7525 - accuracy: 0.4986
# Epoch 11: loss improved from 0.75807 to 0.75254, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7525 - accuracy: 0.4982 - val_loss: 0.7514 - val_accuracy: 0.5171
# Epoch 12/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7427 - accuracy: 0.5160
# Epoch 12: loss improved from 0.75254 to 0.74267, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7427 - accuracy: 0.5160 - val_loss: 0.7579 - val_accuracy: 0.4860
# Epoch 13/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7333 - accuracy: 0.5161
# Epoch 13: loss improved from 0.74267 to 0.73591, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7359 - accuracy: 0.5160 - val_loss: 0.7535 - val_accuracy: 0.4860
# Epoch 14/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7341 - accuracy: 0.5045
# Epoch 14: loss improved from 0.73591 to 0.73487, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7349 - accuracy: 0.5053 - val_loss: 0.7436 - val_accuracy: 0.4783
# Epoch 15/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7331 - accuracy: 0.4956
# Epoch 15: loss improved from 0.73487 to 0.73308, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7331 - accuracy: 0.4947 - val_loss: 0.7592 - val_accuracy: 0.4953
# Epoch 16/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7310 - accuracy: 0.5046
# Epoch 16: loss improved from 0.73308 to 0.73051, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7305 - accuracy: 0.5053 - val_loss: 0.7344 - val_accuracy: 0.4984
# Epoch 17/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7286 - accuracy: 0.5135
# Epoch 17: loss improved from 0.73051 to 0.72788, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7279 - accuracy: 0.5134 - val_loss: 0.7416 - val_accuracy: 0.5155
# Epoch 18/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7241 - accuracy: 0.5136
# Epoch 18: loss improved from 0.72788 to 0.72390, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7239 - accuracy: 0.5136 - val_loss: 0.7302 - val_accuracy: 0.5124
# Epoch 19/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7225 - accuracy: 0.5040
# Epoch 19: loss did not improve from 0.72390
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7242 - accuracy: 0.5042 - val_loss: 0.7377 - val_accuracy: 0.5357
# Epoch 20/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7212 - accuracy: 0.5185
# Epoch 20: loss improved from 0.72390 to 0.72161, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7216 - accuracy: 0.5189 - val_loss: 0.7455 - val_accuracy: 0.5186
# Epoch 21/300
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7200 - accuracy: 0.5147
# Epoch 21: loss improved from 0.72161 to 0.72045, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7205 - accuracy: 0.5130 - val_loss: 0.7452 - val_accuracy: 0.5000
# Epoch 22/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7183 - accuracy: 0.5192
# Epoch 22: loss improved from 0.72045 to 0.71787, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7179 - accuracy: 0.5201 - val_loss: 0.7343 - val_accuracy: 0.5233
# Epoch 23/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7180 - accuracy: 0.5090
# Epoch 23: loss did not improve from 0.71787
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7190 - accuracy: 0.5092 - val_loss: 0.7385 - val_accuracy: 0.4953
# Epoch 24/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7198 - accuracy: 0.5130
# Epoch 24: loss did not improve from 0.71787
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7191 - accuracy: 0.5123 - val_loss: 0.7299 - val_accuracy: 0.4984
# Epoch 25/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7166 - accuracy: 0.5136
# Epoch 25: loss improved from 0.71787 to 0.71663, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7166 - accuracy: 0.5136 - val_loss: 0.7272 - val_accuracy: 0.5047
# Epoch 26/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7173 - accuracy: 0.5120
# Epoch 26: loss did not improve from 0.71663
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7173 - accuracy: 0.5120 - val_loss: 0.7547 - val_accuracy: 0.4720
# Epoch 27/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5034
# Epoch 27: loss did not improve from 0.71663
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7175 - accuracy: 0.5037 - val_loss: 0.7358 - val_accuracy: 0.5031
# Epoch 28/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7165 - accuracy: 0.5132
# Epoch 28: loss improved from 0.71663 to 0.71646, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7165 - accuracy: 0.5132 - val_loss: 0.7295 - val_accuracy: 0.5264
# Epoch 29/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7155 - accuracy: 0.5133
# Epoch 29: loss improved from 0.71646 to 0.71609, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7161 - accuracy: 0.5141 - val_loss: 0.7346 - val_accuracy: 0.5031
# Epoch 30/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7156 - accuracy: 0.5170
# Epoch 30: loss did not improve from 0.71609
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7173 - accuracy: 0.5155 - val_loss: 0.7317 - val_accuracy: 0.4783
# Epoch 31/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7135 - accuracy: 0.5120
# Epoch 31: loss improved from 0.71609 to 0.71394, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7139 - accuracy: 0.5113 - val_loss: 0.7303 - val_accuracy: 0.5031
# Epoch 32/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7138 - accuracy: 0.5066
# Epoch 32: loss improved from 0.71394 to 0.71369, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7137 - accuracy: 0.5072 - val_loss: 0.7321 - val_accuracy: 0.4969
# Epoch 33/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.5117
# Epoch 33: loss did not improve from 0.71369
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7149 - accuracy: 0.5117 - val_loss: 0.7319 - val_accuracy: 0.4876
# Epoch 34/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7146 - accuracy: 0.5110
# Epoch 34: loss did not improve from 0.71369
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7144 - accuracy: 0.5110 - val_loss: 0.7424 - val_accuracy: 0.4891
# Epoch 35/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7136 - accuracy: 0.5120
# Epoch 35: loss improved from 0.71369 to 0.71363, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7136 - accuracy: 0.5120 - val_loss: 0.7248 - val_accuracy: 0.5186
# Epoch 36/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7135 - accuracy: 0.5165
# Epoch 36: loss improved from 0.71363 to 0.71351, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7135 - accuracy: 0.5165 - val_loss: 0.7316 - val_accuracy: 0.5031
# Epoch 37/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7134 - accuracy: 0.5168
# Epoch 37: loss did not improve from 0.71351
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7139 - accuracy: 0.5170 - val_loss: 0.7399 - val_accuracy: 0.4891
# Epoch 38/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7139 - accuracy: 0.5175
# Epoch 38: loss did not improve from 0.71351
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7136 - accuracy: 0.5179 - val_loss: 0.7295 - val_accuracy: 0.5171
# Epoch 39/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7149 - accuracy: 0.5100
# Epoch 39: loss did not improve from 0.71351
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7145 - accuracy: 0.5108 - val_loss: 0.7306 - val_accuracy: 0.5062
# Epoch 40/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7129 - accuracy: 0.5167
# Epoch 40: loss did not improve from 0.71351
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7140 - accuracy: 0.5146 - val_loss: 0.7221 - val_accuracy: 0.5093
# Epoch 41/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5187
# Epoch 41: loss improved from 0.71351 to 0.71148, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7115 - accuracy: 0.5189 - val_loss: 0.7274 - val_accuracy: 0.5202
# Epoch 42/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5197
# Epoch 42: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7123 - accuracy: 0.5191 - val_loss: 0.7322 - val_accuracy: 0.4829
# Epoch 43/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7118 - accuracy: 0.5224
# Epoch 43: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7118 - accuracy: 0.5222 - val_loss: 0.7247 - val_accuracy: 0.5062
# Epoch 44/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5095
# Epoch 44: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7119 - accuracy: 0.5091 - val_loss: 0.7352 - val_accuracy: 0.4969
# Epoch 45/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.5096
# Epoch 45: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7125 - accuracy: 0.5096 - val_loss: 0.7275 - val_accuracy: 0.5078
# Epoch 46/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7118 - accuracy: 0.5114
# Epoch 46: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7118 - accuracy: 0.5113 - val_loss: 0.7325 - val_accuracy: 0.5000
# Epoch 47/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7113 - accuracy: 0.5095
# Epoch 47: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7129 - accuracy: 0.5070 - val_loss: 0.7301 - val_accuracy: 0.4969
# Epoch 48/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5124
# Epoch 48: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7115 - accuracy: 0.5136 - val_loss: 0.7334 - val_accuracy: 0.4860
# Epoch 49/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7114 - accuracy: 0.5165
# Epoch 49: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7116 - accuracy: 0.5167 - val_loss: 0.7311 - val_accuracy: 0.5357
# Epoch 50/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7126 - accuracy: 0.5172
# Epoch 50: loss did not improve from 0.71148
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7116 - accuracy: 0.5155 - val_loss: 0.7256 - val_accuracy: 0.5016
# Epoch 51/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7100 - accuracy: 0.5153
# Epoch 51: loss improved from 0.71148 to 0.71085, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7108 - accuracy: 0.5136 - val_loss: 0.7263 - val_accuracy: 0.5202
# Epoch 52/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.5145
# Epoch 52: loss did not improve from 0.71085
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7111 - accuracy: 0.5148 - val_loss: 0.7301 - val_accuracy: 0.4953
# Epoch 53/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7118 - accuracy: 0.5108
# Epoch 53: loss did not improve from 0.71085
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7117 - accuracy: 0.5108 - val_loss: 0.7286 - val_accuracy: 0.4876
# Epoch 54/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5155
# Epoch 54: loss improved from 0.71085 to 0.70980, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7098 - accuracy: 0.5146 - val_loss: 0.7278 - val_accuracy: 0.5155
# Epoch 55/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5195
# Epoch 55: loss did not improve from 0.70980
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.5189 - val_loss: 0.7288 - val_accuracy: 0.4938
# Epoch 56/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.5096
# Epoch 56: loss did not improve from 0.70980
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7112 - accuracy: 0.5096 - val_loss: 0.7307 - val_accuracy: 0.4814
# Epoch 57/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7100 - accuracy: 0.5107
# Epoch 57: loss improved from 0.70980 to 0.70967, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7097 - accuracy: 0.5099 - val_loss: 0.7282 - val_accuracy: 0.4891
# Epoch 58/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5044
# Epoch 58: loss did not improve from 0.70967
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7104 - accuracy: 0.5046 - val_loss: 0.7310 - val_accuracy: 0.4938
# Epoch 59/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7091 - accuracy: 0.5220
# Epoch 59: loss did not improve from 0.70967
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7104 - accuracy: 0.5215 - val_loss: 0.7217 - val_accuracy: 0.5186
# Epoch 60/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5080
# Epoch 60: loss did not improve from 0.70967
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7104 - accuracy: 0.5080 - val_loss: 0.7261 - val_accuracy: 0.4953
# Epoch 61/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7085 - accuracy: 0.5138
# Epoch 61: loss did not improve from 0.70967
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7098 - accuracy: 0.5142 - val_loss: 0.7276 - val_accuracy: 0.4922
# Epoch 62/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7102 - accuracy: 0.5105
# Epoch 62: loss did not improve from 0.70967
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7110 - accuracy: 0.5101 - val_loss: 0.7304 - val_accuracy: 0.4907
# Epoch 63/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7096 - accuracy: 0.5130
# Epoch 63: loss improved from 0.70967 to 0.70957, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7096 - accuracy: 0.5130 - val_loss: 0.7293 - val_accuracy: 0.5062
# Epoch 64/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5205
# Epoch 64: loss improved from 0.70957 to 0.70851, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7085 - accuracy: 0.5208 - val_loss: 0.7353 - val_accuracy: 0.4767
# Epoch 65/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.5127
# Epoch 65: loss did not improve from 0.70851
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7095 - accuracy: 0.5130 - val_loss: 0.7252 - val_accuracy: 0.4922
# Epoch 66/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7091 - accuracy: 0.5206
# Epoch 66: loss did not improve from 0.70851
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7091 - accuracy: 0.5206 - val_loss: 0.7292 - val_accuracy: 0.4860
# Epoch 67/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5123
# Epoch 67: loss did not improve from 0.70851
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7089 - accuracy: 0.5130 - val_loss: 0.7220 - val_accuracy: 0.5000
# Epoch 68/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7088 - accuracy: 0.5190
# Epoch 68: loss did not improve from 0.70851
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7092 - accuracy: 0.5189 - val_loss: 0.7220 - val_accuracy: 0.5264
# Epoch 69/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5154
# Epoch 69: loss did not improve from 0.70851
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7096 - accuracy: 0.5144 - val_loss: 0.7225 - val_accuracy: 0.5109
# Epoch 70/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7084 - accuracy: 0.5171
# Epoch 70: loss improved from 0.70851 to 0.70804, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7080 - accuracy: 0.5172 - val_loss: 0.7257 - val_accuracy: 0.5280
# Epoch 71/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7093 - accuracy: 0.5165
# Epoch 71: loss did not improve from 0.70804
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.5155 - val_loss: 0.7423 - val_accuracy: 0.5093
# Epoch 72/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5211
# Epoch 72: loss did not improve from 0.70804
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7086 - accuracy: 0.5224 - val_loss: 0.7203 - val_accuracy: 0.5171
# Epoch 73/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.5162
# Epoch 73: loss did not improve from 0.70804
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7086 - accuracy: 0.5160 - val_loss: 0.7269 - val_accuracy: 0.4876
# Epoch 74/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5240
# Epoch 74: loss did not improve from 0.70804
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7084 - accuracy: 0.5237 - val_loss: 0.7243 - val_accuracy: 0.5140
# Epoch 75/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7063 - accuracy: 0.5223
# Epoch 75: loss improved from 0.70804 to 0.70772, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7077 - accuracy: 0.5206 - val_loss: 0.7265 - val_accuracy: 0.4953
# Epoch 76/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5194
# Epoch 76: loss improved from 0.70772 to 0.70750, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7075 - accuracy: 0.5194 - val_loss: 0.7277 - val_accuracy: 0.5124
# Epoch 77/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5178
# Epoch 77: loss did not improve from 0.70750
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7094 - accuracy: 0.5179 - val_loss: 0.7203 - val_accuracy: 0.5124
# Epoch 78/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.5097
# Epoch 78: loss did not improve from 0.70750
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7091 - accuracy: 0.5108 - val_loss: 0.7254 - val_accuracy: 0.5031
# Epoch 79/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5105
# Epoch 79: loss did not improve from 0.70750
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7089 - accuracy: 0.5110 - val_loss: 0.7218 - val_accuracy: 0.5140
# Epoch 80/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5114
# Epoch 80: loss did not improve from 0.70750
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7081 - accuracy: 0.5141 - val_loss: 0.7245 - val_accuracy: 0.5047
# Epoch 81/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5237
# Epoch 81: loss improved from 0.70750 to 0.70701, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7070 - accuracy: 0.5231 - val_loss: 0.7230 - val_accuracy: 0.5264
# Epoch 82/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5129
# Epoch 82: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5122 - val_loss: 0.7254 - val_accuracy: 0.4922
# Epoch 83/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5176
# Epoch 83: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7084 - accuracy: 0.5179 - val_loss: 0.7216 - val_accuracy: 0.5280
# Epoch 84/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.5146
# Epoch 84: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5146 - val_loss: 0.7216 - val_accuracy: 0.5093
# Epoch 85/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7091 - accuracy: 0.5204
# Epoch 85: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7077 - accuracy: 0.5213 - val_loss: 0.7251 - val_accuracy: 0.5140
# Epoch 86/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5160
# Epoch 86: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7084 - accuracy: 0.5153 - val_loss: 0.7238 - val_accuracy: 0.5000
# Epoch 87/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5144
# Epoch 87: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7074 - accuracy: 0.5146 - val_loss: 0.7235 - val_accuracy: 0.4938
# Epoch 88/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7079 - accuracy: 0.5056
# Epoch 88: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7079 - accuracy: 0.5072 - val_loss: 0.7234 - val_accuracy: 0.4938
# Epoch 89/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7087 - accuracy: 0.5153
# Epoch 89: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5153 - val_loss: 0.7248 - val_accuracy: 0.5000
# Epoch 90/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.5170
# Epoch 90: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7075 - accuracy: 0.5170 - val_loss: 0.7197 - val_accuracy: 0.5171
# Epoch 91/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5132
# Epoch 91: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5123 - val_loss: 0.7241 - val_accuracy: 0.4938
# Epoch 92/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5215
# Epoch 92: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7076 - accuracy: 0.5198 - val_loss: 0.7231 - val_accuracy: 0.5202
# Epoch 93/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.5186
# Epoch 93: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7071 - accuracy: 0.5186 - val_loss: 0.7281 - val_accuracy: 0.4876
# Epoch 94/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5098
# Epoch 94: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5123 - val_loss: 0.7258 - val_accuracy: 0.4938
# Epoch 95/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5220
# Epoch 95: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5229 - val_loss: 0.7199 - val_accuracy: 0.5062
# Epoch 96/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5191
# Epoch 96: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5184 - val_loss: 0.7313 - val_accuracy: 0.4876
# Epoch 97/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5172
# Epoch 97: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7077 - accuracy: 0.5165 - val_loss: 0.7278 - val_accuracy: 0.5062
# Epoch 98/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5125
# Epoch 98: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7072 - accuracy: 0.5101 - val_loss: 0.7250 - val_accuracy: 0.5047
# Epoch 99/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5089
# Epoch 99: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5098 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 100/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5153
# Epoch 100: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5168 - val_loss: 0.7215 - val_accuracy: 0.4984
# Epoch 101/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7068 - accuracy: 0.5154
# Epoch 101: loss did not improve from 0.70701
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7070 - accuracy: 0.5146 - val_loss: 0.7241 - val_accuracy: 0.4907
# Epoch 102/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7077 - accuracy: 0.5216
# Epoch 102: loss improved from 0.70701 to 0.70688, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 14ms/step - loss: 0.7069 - accuracy: 0.5175 - val_loss: 0.7233 - val_accuracy: 0.5140
# Epoch 103/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5167
# Epoch 103: loss did not improve from 0.70688
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7069 - accuracy: 0.5174 - val_loss: 0.7255 - val_accuracy: 0.5078
# Epoch 104/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5183
# Epoch 104: loss improved from 0.70688 to 0.70671, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7067 - accuracy: 0.5177 - val_loss: 0.7226 - val_accuracy: 0.5357
# Epoch 105/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5193
# Epoch 105: loss did not improve from 0.70671
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7068 - accuracy: 0.5191 - val_loss: 0.7211 - val_accuracy: 0.4938
# Epoch 106/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5105
# Epoch 106: loss did not improve from 0.70671
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7072 - accuracy: 0.5106 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 107/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.5225
# Epoch 107: loss did not improve from 0.70671
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7074 - accuracy: 0.5225 - val_loss: 0.7222 - val_accuracy: 0.5140
# Epoch 108/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5190
# Epoch 108: loss did not improve from 0.70671
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5175 - val_loss: 0.7229 - val_accuracy: 0.5264
# Epoch 109/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7073 - accuracy: 0.5113
# Epoch 109: loss did not improve from 0.70671
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7075 - accuracy: 0.5151 - val_loss: 0.7238 - val_accuracy: 0.4907
# Epoch 110/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5108
# Epoch 110: loss improved from 0.70671 to 0.70655, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7066 - accuracy: 0.5110 - val_loss: 0.7217 - val_accuracy: 0.4984
# Epoch 111/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7065 - accuracy: 0.5141
# Epoch 111: loss did not improve from 0.70655
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5137 - val_loss: 0.7229 - val_accuracy: 0.5093
# Epoch 112/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.5099
# Epoch 112: loss did not improve from 0.70655
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5099 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 113/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7062 - accuracy: 0.5266
# Epoch 113: loss improved from 0.70655 to 0.70652, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7065 - accuracy: 0.5246 - val_loss: 0.7233 - val_accuracy: 0.5078
# Epoch 114/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5190
# Epoch 114: loss did not improve from 0.70652
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7068 - accuracy: 0.5172 - val_loss: 0.7218 - val_accuracy: 0.5171
# Epoch 115/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7071 - accuracy: 0.5170
# Epoch 115: loss improved from 0.70652 to 0.70652, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7065 - accuracy: 0.5160 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 116/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5224
# Epoch 116: loss did not improve from 0.70652
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7066 - accuracy: 0.5234 - val_loss: 0.7205 - val_accuracy: 0.5000
# Epoch 117/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5257
# Epoch 117: loss improved from 0.70652 to 0.70628, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7063 - accuracy: 0.5244 - val_loss: 0.7218 - val_accuracy: 0.5062
# Epoch 118/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5247
# Epoch 118: loss did not improve from 0.70628
# 181/181 [==============================] - 3s 17ms/step - loss: 0.7065 - accuracy: 0.5246 - val_loss: 0.7244 - val_accuracy: 0.5062
# Epoch 119/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5188
# Epoch 119: loss improved from 0.70628 to 0.70618, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7062 - accuracy: 0.5180 - val_loss: 0.7229 - val_accuracy: 0.5124
# Epoch 120/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5207
# Epoch 120: loss did not improve from 0.70618
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5206 - val_loss: 0.7236 - val_accuracy: 0.4922
# Epoch 121/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5167
# Epoch 121: loss did not improve from 0.70618
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5167 - val_loss: 0.7245 - val_accuracy: 0.5062
# Epoch 122/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5210
# Epoch 122: loss did not improve from 0.70618
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5208 - val_loss: 0.7212 - val_accuracy: 0.4922
# Epoch 123/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5197
# Epoch 123: loss did not improve from 0.70618
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7076 - accuracy: 0.5191 - val_loss: 0.7236 - val_accuracy: 0.5078
# Epoch 124/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5194
# Epoch 124: loss did not improve from 0.70618
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7063 - accuracy: 0.5206 - val_loss: 0.7241 - val_accuracy: 0.5016
# Epoch 125/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5165
# Epoch 125: loss improved from 0.70618 to 0.70601, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7060 - accuracy: 0.5167 - val_loss: 0.7197 - val_accuracy: 0.5357
# Epoch 126/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5094
# Epoch 126: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5089 - val_loss: 0.7213 - val_accuracy: 0.5078
# Epoch 127/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5183
# Epoch 127: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5203 - val_loss: 0.7223 - val_accuracy: 0.4938
# Epoch 128/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5249
# Epoch 128: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5244 - val_loss: 0.7217 - val_accuracy: 0.5078
# Epoch 129/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5167
# Epoch 129: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7066 - accuracy: 0.5165 - val_loss: 0.7225 - val_accuracy: 0.4922
# Epoch 130/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5233
# Epoch 130: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7062 - accuracy: 0.5244 - val_loss: 0.7225 - val_accuracy: 0.4984
# Epoch 131/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5226
# Epoch 131: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7065 - accuracy: 0.5208 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 132/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5169
# Epoch 132: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7062 - accuracy: 0.5153 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 133/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7063 - accuracy: 0.5124
# Epoch 133: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7064 - accuracy: 0.5142 - val_loss: 0.7225 - val_accuracy: 0.5093
# Epoch 134/300
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7067 - accuracy: 0.5222
# Epoch 134: loss did not improve from 0.70601
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5218 - val_loss: 0.7212 - val_accuracy: 0.5093
# Epoch 135/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5104
# Epoch 135: loss improved from 0.70601 to 0.70561, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7056 - accuracy: 0.5106 - val_loss: 0.7237 - val_accuracy: 0.5078
# Epoch 136/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.5194
# Epoch 136: loss did not improve from 0.70561
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5187 - val_loss: 0.7224 - val_accuracy: 0.5093
# Epoch 137/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5275
# Epoch 137: loss did not improve from 0.70561
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5263 - val_loss: 0.7223 - val_accuracy: 0.5124
# Epoch 138/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7036 - accuracy: 0.5205
# Epoch 138: loss improved from 0.70561 to 0.70540, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5199 - val_loss: 0.7209 - val_accuracy: 0.5171
# Epoch 139/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7062 - accuracy: 0.5240
# Epoch 139: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5222 - val_loss: 0.7213 - val_accuracy: 0.5078
# Epoch 140/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7058 - accuracy: 0.5164
# Epoch 140: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5175 - val_loss: 0.7215 - val_accuracy: 0.5078
# Epoch 141/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5173
# Epoch 141: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5160 - val_loss: 0.7232 - val_accuracy: 0.5031
# Epoch 142/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5144
# Epoch 142: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5148 - val_loss: 0.7241 - val_accuracy: 0.5031
# Epoch 143/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5199
# Epoch 143: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7062 - accuracy: 0.5191 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 144/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5153
# Epoch 144: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7082 - accuracy: 0.5136 - val_loss: 0.7274 - val_accuracy: 0.4922
# Epoch 145/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5206
# Epoch 145: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7080 - accuracy: 0.5215 - val_loss: 0.7208 - val_accuracy: 0.5357
# Epoch 146/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5131
# Epoch 146: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7065 - accuracy: 0.5122 - val_loss: 0.7225 - val_accuracy: 0.5264
# Epoch 147/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5140
# Epoch 147: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5142 - val_loss: 0.7236 - val_accuracy: 0.5062
# Epoch 148/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7068 - accuracy: 0.5240
# Epoch 148: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5227 - val_loss: 0.7231 - val_accuracy: 0.5248
# Epoch 149/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5196
# Epoch 149: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7060 - accuracy: 0.5199 - val_loss: 0.7218 - val_accuracy: 0.4922
# Epoch 150/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5167
# Epoch 150: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5174 - val_loss: 0.7219 - val_accuracy: 0.5093
# Epoch 151/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.5228
# Epoch 151: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5250 - val_loss: 0.7226 - val_accuracy: 0.5078
# Epoch 152/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5233
# Epoch 152: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5225 - val_loss: 0.7225 - val_accuracy: 0.5078
# Epoch 153/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5173
# Epoch 153: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7063 - accuracy: 0.5165 - val_loss: 0.7221 - val_accuracy: 0.5047
# Epoch 154/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.5195
# Epoch 154: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5196 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 155/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5203
# Epoch 155: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5208 - val_loss: 0.7231 - val_accuracy: 0.4922
# Epoch 156/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5163
# Epoch 156: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5163 - val_loss: 0.7209 - val_accuracy: 0.4922
# Epoch 157/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5196
# Epoch 157: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7058 - accuracy: 0.5196 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 158/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.5225
# Epoch 158: loss did not improve from 0.70540
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7055 - accuracy: 0.5225 - val_loss: 0.7248 - val_accuracy: 0.5078
# Epoch 159/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5279
# Epoch 159: loss did not improve from 0.70540
# ...
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7079 - accuracy: 0.5193 - val_loss: 0.7206 - val_accuracy: 0.5264
# Epoch 244/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5102
# Epoch 244: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5103 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 245/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7067 - accuracy: 0.5208
# Epoch 245: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5222 - val_loss: 0.7203 - val_accuracy: 0.5264
# Epoch 246/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5190
# Epoch 246: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5186 - val_loss: 0.7248 - val_accuracy: 0.5078
# Epoch 247/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.5127
# Epoch 247: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7053 - accuracy: 0.5127 - val_loss: 0.7241 - val_accuracy: 0.5078
# Epoch 248/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7035 - accuracy: 0.5269
# Epoch 248: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5255 - val_loss: 0.7221 - val_accuracy: 0.5186
# Epoch 249/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7051 - accuracy: 0.5253
# Epoch 249: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7052 - accuracy: 0.5255 - val_loss: 0.7226 - val_accuracy: 0.5186
# Epoch 250/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7042 - accuracy: 0.5232
# Epoch 250: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7050 - accuracy: 0.5232 - val_loss: 0.7211 - val_accuracy: 0.5264
# Epoch 251/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5217
# Epoch 251: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7051 - accuracy: 0.5213 - val_loss: 0.7254 - val_accuracy: 0.5062
# Epoch 252/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5208
# Epoch 252: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7053 - accuracy: 0.5208 - val_loss: 0.7232 - val_accuracy: 0.5093
# Epoch 253/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5206
# Epoch 253: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7055 - accuracy: 0.5213 - val_loss: 0.7246 - val_accuracy: 0.5078
# Epoch 254/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5273
# Epoch 254: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7055 - accuracy: 0.5263 - val_loss: 0.7229 - val_accuracy: 0.4922
# Epoch 255/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5291
# Epoch 255: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7052 - accuracy: 0.5288 - val_loss: 0.7211 - val_accuracy: 0.5264
# Epoch 256/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.5242
# Epoch 256: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7053 - accuracy: 0.5241 - val_loss: 0.7235 - val_accuracy: 0.4984
# Epoch 257/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.5256
# Epoch 257: loss did not improve from 0.70484
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7049 - accuracy: 0.5256 - val_loss: 0.7222 - val_accuracy: 0.5109
# Epoch 258/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5272
# Epoch 258: loss improved from 0.70484 to 0.70473, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7047 - accuracy: 0.5258 - val_loss: 0.7243 - val_accuracy: 0.4938
# Epoch 259/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5160
# Epoch 259: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5156 - val_loss: 0.7229 - val_accuracy: 0.5171
# Epoch 260/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5163
# Epoch 260: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5165 - val_loss: 0.7228 - val_accuracy: 0.5093
# Epoch 261/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5233
# Epoch 261: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7063 - accuracy: 0.5244 - val_loss: 0.7221 - val_accuracy: 0.5264
# Epoch 262/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7051 - accuracy: 0.5255
# Epoch 262: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7052 - accuracy: 0.5231 - val_loss: 0.7228 - val_accuracy: 0.5264
# Epoch 263/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5205
# Epoch 263: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7048 - accuracy: 0.5218 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 264/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7049 - accuracy: 0.5207
# Epoch 264: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7049 - accuracy: 0.5196 - val_loss: 0.7230 - val_accuracy: 0.4922
# Epoch 265/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7060 - accuracy: 0.5180
# Epoch 265: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7051 - accuracy: 0.5180 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 266/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.5272
# Epoch 266: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7049 - accuracy: 0.5272 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 267/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7058 - accuracy: 0.5178
# Epoch 267: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7048 - accuracy: 0.5187 - val_loss: 0.7207 - val_accuracy: 0.5078
# Epoch 268/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.5246
# Epoch 268: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7048 - accuracy: 0.5237 - val_loss: 0.7235 - val_accuracy: 0.5078
# Epoch 269/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5272
# Epoch 269: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5281 - val_loss: 0.7236 - val_accuracy: 0.4922
# Epoch 270/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5234
# Epoch 270: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5225 - val_loss: 0.7229 - val_accuracy: 0.4922
# Epoch 271/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5231
# Epoch 271: loss did not improve from 0.70473
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7050 - accuracy: 0.5231 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 272/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.5231
# Epoch 272: loss improved from 0.70473 to 0.70457, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7046 - accuracy: 0.5232 - val_loss: 0.7225 - val_accuracy: 0.5078
# Epoch 273/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7046 - accuracy: 0.5291
# Epoch 273: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7049 - accuracy: 0.5277 - val_loss: 0.7232 - val_accuracy: 0.5062
# Epoch 274/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.5212
# Epoch 274: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7049 - accuracy: 0.5212 - val_loss: 0.7226 - val_accuracy: 0.5264
# Epoch 275/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7055 - accuracy: 0.5195
# Epoch 275: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7051 - accuracy: 0.5186 - val_loss: 0.7222 - val_accuracy: 0.5078
# Epoch 276/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5275
# Epoch 276: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.5267 - val_loss: 0.7237 - val_accuracy: 0.4938
# Epoch 277/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7065 - accuracy: 0.5219
# Epoch 277: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7058 - accuracy: 0.5218 - val_loss: 0.7238 - val_accuracy: 0.5062
# Epoch 278/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.5213
# Epoch 278: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7052 - accuracy: 0.5213 - val_loss: 0.7239 - val_accuracy: 0.5078
# Epoch 279/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5213
# Epoch 279: loss did not improve from 0.70457
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7051 - accuracy: 0.5229 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 280/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7042 - accuracy: 0.5208
# Epoch 280: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7048 - accuracy: 0.5213 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 281/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7034 - accuracy: 0.5232
# Epoch 281: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7048 - accuracy: 0.5232 - val_loss: 0.7233 - val_accuracy: 0.5062
# Epoch 282/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.5201
# Epoch 282: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7047 - accuracy: 0.5201 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 283/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7041 - accuracy: 0.5210
# Epoch 283: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7051 - accuracy: 0.5201 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 284/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7034 - accuracy: 0.5271
# Epoch 284: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7050 - accuracy: 0.5256 - val_loss: 0.7226 - val_accuracy: 0.4922
# Epoch 285/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5247
# Epoch 285: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5229 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 286/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.5245
# Epoch 286: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5255 - val_loss: 0.7234 - val_accuracy: 0.4907
# Epoch 287/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5253
# Epoch 287: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5253 - val_loss: 0.7241 - val_accuracy: 0.4922
# Epoch 288/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5186
# Epoch 288: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7047 - accuracy: 0.5193 - val_loss: 0.7225 - val_accuracy: 0.5078
# Epoch 289/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.5300
# Epoch 289: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7047 - accuracy: 0.5300 - val_loss: 0.7223 - val_accuracy: 0.4922
# Epoch 290/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5211
# Epoch 290: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5224 - val_loss: 0.7228 - val_accuracy: 0.4922
# Epoch 291/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5201
# Epoch 291: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7048 - accuracy: 0.5203 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 292/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5236
# Epoch 292: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7051 - accuracy: 0.5236 - val_loss: 0.7217 - val_accuracy: 0.5078
# Epoch 293/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5219
# Epoch 293: loss did not improve from 0.70457
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7051 - accuracy: 0.5213 - val_loss: 0.7239 - val_accuracy: 0.4922
# Epoch 294/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7038 - accuracy: 0.5174
# Epoch 294: loss did not improve from 0.70457
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7051 - accuracy: 0.5179 - val_loss: 0.7241 - val_accuracy: 0.5078
# Epoch 295/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5236
# Epoch 295: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7049 - accuracy: 0.5224 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 296/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7058 - accuracy: 0.5208
# Epoch 296: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7049 - accuracy: 0.5201 - val_loss: 0.7233 - val_accuracy: 0.5031
# Epoch 297/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7057 - accuracy: 0.5122
# Epoch 297: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7050 - accuracy: 0.5144 - val_loss: 0.7235 - val_accuracy: 0.5078
# Epoch 298/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.5225
# Epoch 298: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7052 - accuracy: 0.5212 - val_loss: 0.7231 - val_accuracy: 0.4922
# Epoch 299/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5233
# Epoch 299: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7055 - accuracy: 0.5248 - val_loss: 0.7217 - val_accuracy: 0.5093
# Epoch 300/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5232
# Epoch 300: loss did not improve from 0.70457
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7057 - accuracy: 0.5241 - val_loss: 0.7214 - val_accuracy: 0.5078

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# {'loss': [2.0782923698425293, 1.0038965940475464, 0.8674878478050232, 0.8281247615814209, 0.8069963455200195, 0.790489137172699, 0.776984453201294, 0.7713629007339478, 0.7588399052619934, 0.7580738663673401, 0.7525431513786316, 0.7426678538322449, 0.7359126210212708, 0.7348692417144775, 0.7330760359764099, 0.7305078506469727, 0.727882981300354, 0.723901629447937, 0.7242490649223328, 0.721610963344574, 0.7204534411430359, 0.7178653478622437, 0.7189547419548035, 0.7190621495246887, 0.7166305184364319, 0.7173474431037903, 0.7175479531288147, 0.7164589166641235, 0.7160918116569519, 0.717339813709259, 0.7139442563056946, 0.7136931419372559, 0.7148635387420654, 0.7144376635551453, 0.7136330604553223, 0.7135141491889954, 0.7138811945915222, 0.7135521173477173, 0.7145411372184753, 0.7139768600463867, 0.7114841938018799, 0.7122925519943237, 0.711842954158783, 0.7118540406227112, 0.7124862670898438, 0.7117542624473572, 0.7129117846488953, 0.7115299105644226, 0.7116423845291138, 0.7115893363952637, 0.710847020149231, 0.711058497428894, 0.7116913199424744, 0.7098028659820557, 0.7103132009506226, 0.711171567440033, 0.7096686959266663, 0.710372805595398, 0.7103721499443054, 0.7103835344314575, 0.7098397612571716, 0.7110103368759155, 0.7095682621002197, 0.7085140347480774, 0.709490954875946, 0.7091028690338135, 0.7089168429374695, 0.7092485427856445, 0.7095585465431213, 0.7080356478691101, 0.7103111743927002, 0.708601176738739, 0.7086260318756104, 0.7083767056465149, 0.7077211141586304, 0.7074958086013794, 0.7093774676322937, 0.7090970277786255, 0.7089481353759766, 0.7081316113471985, 0.7070059776306152, 0.7094370126724243, 0.7083798050880432, 0.7079761028289795, 0.7077139019966125, 0.7084349393844604, 0.7074495553970337, 0.7079482674598694, 0.7080018520355225, 0.7075433135032654, 0.7074956893920898, 0.7076123356819153, 0.7070883512496948, 0.7074894905090332, 0.7073439955711365, 0.7079820036888123, 0.707653820514679, 0.7071578502655029, 0.7078121900558472, 0.7070280313491821, 0.7070140242576599, 0.7068800926208496, 0.7069372534751892, 0.706714928150177, 0.7067875266075134, 0.7071502804756165, 0.7074199318885803, 0.7070283889770508, 0.7074563503265381, 0.7065500617027283, 0.7069886922836304, 0.7067259550094604, 0.7065229415893555, 0.7068241238594055, 0.7065198421478271, 0.7066409587860107, 0.7062841057777405, 0.7064875960350037, 0.7061766982078552, 0.7069665193557739, 0.7066057324409485, 0.7069560885429382, 0.7075895071029663, 0.7063115835189819, 0.7060094475746155, 0.7067416906356812, 0.7061381340026855, 0.7060757875442505, 0.7065805196762085, 0.7061886191368103, 0.7065040469169617, 0.7062376737594604, 0.7063576579093933, 0.7061663866043091, 0.7056106925010681, 0.7062205672264099, 0.7061876058578491, 0.7053998112678528, 0.7061597108840942, 0.706216037273407, 0.7057700157165527, 0.7058166861534119, 0.7062438726425171, 0.7081837058067322, 0.7079683542251587, 0.7065003514289856, 0.7058613300323486, 0.7056199312210083, 0.7060474157333374, 0.7057570815086365, 0.7054868936538696, 0.705947756767273, 0.706335186958313, 0.7057532668113708, 0.7055946588516235, 0.7057449221611023, 0.7058215737342834, 0.7054985165596008, 0.7054062485694885, 0.7053412199020386, 0.7058378458023071, 0.7054923176765442, 0.7060685753822327, 0.7055158615112305, 0.7060449719429016, 0.705693781375885, 0.7057340145111084, 0.7054644823074341, 0.7057495713233948, 0.7053604125976562, 0.7056863307952881, 0.7053325772285461, 0.7055748701095581, 0.7060683369636536, 0.7060016393661499, 0.7104488015174866, 0.7057632207870483, 0.7057721614837646, 0.7052657008171082, 0.7055047750473022, 0.705664873123169, 0.705521285533905, 0.7052847743034363, 0.7053927779197693, 0.7057944536209106, 0.7054343819618225, 0.7056010365486145, 0.7054831981658936, 0.70533287525177, 0.7051582932472229, 0.7053391933441162, 0.7051151990890503, 0.7052050232887268, 0.7055578231811523, 0.7053171396255493, 0.7049692869186401, 0.7052208781242371, 0.7050438523292542, 0.7051945924758911, 0.7052216529846191, 0.70511996746 ...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - 0s 7ms/step - loss: 0.7214 - accuracy: 0.5078
# 21/21 [==============================] - 0s 7ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           17
# 1       441            4
# 2       729            4
# 3      6561           17
# 4      1369            7
# 5       121            3
# 6       729            4
# 7       441            4
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           17
# 1                4.23               3       441            4
# 2                4.77               4       729            4

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/Model6_4_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            4
# 2   ET Sprint 4                 8                9           8            8
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.83                0.17         0.01
# 1  ...              4.17                0.17         0.04
# 2  ...              8.17                0.17         0.02
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.83            16.92              17.05
# 1                 4.17             4.26               4.39
# 2                 8.17             8.26               8.39
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.23              16      7396                1
# 1                4.57               4       676                4
# 2                8.57               8      2116                2
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/model6_4.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 93ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_4/Model6_4results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            4
# 2   ET Sprint 4                 8                9           8            8
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            5  ...                0.17         0.04                 4.17
# 2            9  ...                0.17         0.02                 8.17
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             4.26               4.39                4.57               4
# 2             8.26               8.39                8.57               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1       676                4            4
# 2      2116                2            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
