# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=200,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.8943 - accuracy: 0.4977
# Epoch 1: loss improved from 1.00372 to 0.89478, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8948 - accuracy: 0.4972 - val_loss: 0.8904 - val_accuracy: 0.4829
# Epoch 2/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.8506 - accuracy: 0.4835
# Epoch 2: loss improved from 0.89478 to 0.85037, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.8504 - accuracy: 0.4828 - val_loss: 0.8408 - val_accuracy: 0.5062
# Epoch 3/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.8256 - accuracy: 0.4973
# Epoch 3: loss improved from 0.85037 to 0.82484, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.8248 - accuracy: 0.4982 - val_loss: 0.8305 - val_accuracy: 0.5233
# Epoch 4/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7979 - accuracy: 0.5037
# Epoch 4: loss improved from 0.82484 to 0.79786, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7979 - accuracy: 0.5037 - val_loss: 0.8113 - val_accuracy: 0.4798
# Epoch 5/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7849 - accuracy: 0.5079
# Epoch 5: loss improved from 0.79786 to 0.78644, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7864 - accuracy: 0.5070 - val_loss: 0.8053 - val_accuracy: 0.5016
# Epoch 6/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7771 - accuracy: 0.5127
# Epoch 6: loss improved from 0.78644 to 0.77712, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7771 - accuracy: 0.5127 - val_loss: 0.8031 - val_accuracy: 0.4860
# Epoch 7/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7713 - accuracy: 0.5125
# Epoch 7: loss improved from 0.77712 to 0.76779, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7678 - accuracy: 0.5134 - val_loss: 0.7824 - val_accuracy: 0.5186
# Epoch 8/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7611 - accuracy: 0.5045
# Epoch 8: loss improved from 0.76779 to 0.76167, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7617 - accuracy: 0.5046 - val_loss: 0.7698 - val_accuracy: 0.4720
# Epoch 9/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7500 - accuracy: 0.5169
# Epoch 9: loss improved from 0.76167 to 0.74993, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7499 - accuracy: 0.5174 - val_loss: 0.7769 - val_accuracy: 0.5047
# Epoch 10/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7464 - accuracy: 0.5118
# Epoch 10: loss improved from 0.74993 to 0.74687, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7469 - accuracy: 0.5115 - val_loss: 0.7589 - val_accuracy: 0.5093
# Epoch 11/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7420 - accuracy: 0.5044
# Epoch 11: loss improved from 0.74687 to 0.74099, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7410 - accuracy: 0.5044 - val_loss: 0.7589 - val_accuracy: 0.5155
# Epoch 12/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7364 - accuracy: 0.5147
# Epoch 12: loss improved from 0.74099 to 0.73589, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7359 - accuracy: 0.5153 - val_loss: 0.7570 - val_accuracy: 0.4969
# Epoch 13/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7366 - accuracy: 0.5131
# Epoch 13: loss did not improve from 0.73589
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7374 - accuracy: 0.5118 - val_loss: 0.7463 - val_accuracy: 0.5264
# Epoch 14/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7327 - accuracy: 0.5061
# Epoch 14: loss improved from 0.73589 to 0.73211, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7321 - accuracy: 0.5068 - val_loss: 0.7425 - val_accuracy: 0.5062
# Epoch 15/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7315 - accuracy: 0.5097
# Epoch 15: loss improved from 0.73211 to 0.73017, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7302 - accuracy: 0.5098 - val_loss: 0.7435 - val_accuracy: 0.5000
# Epoch 16/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7284 - accuracy: 0.5155
# Epoch 16: loss improved from 0.73017 to 0.72948, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7295 - accuracy: 0.5148 - val_loss: 0.7424 - val_accuracy: 0.5047
# Epoch 17/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7224 - accuracy: 0.5242
# Epoch 17: loss improved from 0.72948 to 0.72172, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7217 - accuracy: 0.5243 - val_loss: 0.7467 - val_accuracy: 0.5202
# Epoch 18/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7258 - accuracy: 0.5092
# Epoch 18: loss did not improve from 0.72172
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7260 - accuracy: 0.5108 - val_loss: 0.7349 - val_accuracy: 0.5093
# Epoch 19/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7229 - accuracy: 0.5106
# Epoch 19: loss did not improve from 0.72172
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7225 - accuracy: 0.5115 - val_loss: 0.7398 - val_accuracy: 0.5047
# Epoch 20/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7245 - accuracy: 0.5170
# Epoch 20: loss did not improve from 0.72172
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7242 - accuracy: 0.5168 - val_loss: 0.7361 - val_accuracy: 0.5047
# Epoch 21/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7222 - accuracy: 0.5123
# Epoch 21: loss did not improve from 0.72172
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7222 - accuracy: 0.5123 - val_loss: 0.7305 - val_accuracy: 0.5000
# Epoch 22/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7224 - accuracy: 0.5107
# Epoch 22: loss did not improve from 0.72172
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7225 - accuracy: 0.5106 - val_loss: 0.7294 - val_accuracy: 0.5248
# Epoch 23/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7203 - accuracy: 0.5124
# Epoch 23: loss improved from 0.72172 to 0.71995, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.7199 - accuracy: 0.5125 - val_loss: 0.7358 - val_accuracy: 0.5031
# Epoch 24/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.5128
# Epoch 24: loss improved from 0.71995 to 0.71836, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7184 - accuracy: 0.5132 - val_loss: 0.7378 - val_accuracy: 0.5078
# Epoch 25/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7204 - accuracy: 0.5075
# Epoch 25: loss did not improve from 0.71836
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7204 - accuracy: 0.5085 - val_loss: 0.7324 - val_accuracy: 0.4938
# Epoch 26/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7173 - accuracy: 0.5211
# Epoch 26: loss improved from 0.71836 to 0.71786, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7179 - accuracy: 0.5199 - val_loss: 0.7454 - val_accuracy: 0.5047
# Epoch 27/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7175 - accuracy: 0.5081
# Epoch 27: loss improved from 0.71786 to 0.71733, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7173 - accuracy: 0.5084 - val_loss: 0.7302 - val_accuracy: 0.4907
# Epoch 28/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7183 - accuracy: 0.5087
# Epoch 28: loss did not improve from 0.71733
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7180 - accuracy: 0.5079 - val_loss: 0.7299 - val_accuracy: 0.5186
# Epoch 29/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5127
# Epoch 29: loss improved from 0.71733 to 0.71668, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7167 - accuracy: 0.5148 - val_loss: 0.7295 - val_accuracy: 0.4969
# Epoch 30/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7175 - accuracy: 0.5133
# Epoch 30: loss did not improve from 0.71668
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7171 - accuracy: 0.5158 - val_loss: 0.7286 - val_accuracy: 0.5171
# Epoch 31/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.5166
# Epoch 31: loss did not improve from 0.71668
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7180 - accuracy: 0.5172 - val_loss: 0.7323 - val_accuracy: 0.4938
# Epoch 32/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7183 - accuracy: 0.5152
# Epoch 32: loss did not improve from 0.71668
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7187 - accuracy: 0.5148 - val_loss: 0.7277 - val_accuracy: 0.5202
# Epoch 33/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7188 - accuracy: 0.4991
# Epoch 33: loss did not improve from 0.71668
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7180 - accuracy: 0.5004 - val_loss: 0.7327 - val_accuracy: 0.4969
# Epoch 34/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7176 - accuracy: 0.5096
# Epoch 34: loss did not improve from 0.71668
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7171 - accuracy: 0.5104 - val_loss: 0.7283 - val_accuracy: 0.5031
# Epoch 35/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7169 - accuracy: 0.5079
# Epoch 35: loss improved from 0.71668 to 0.71586, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7159 - accuracy: 0.5091 - val_loss: 0.7339 - val_accuracy: 0.4907
# Epoch 36/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7167 - accuracy: 0.5137
# Epoch 36: loss did not improve from 0.71586
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7162 - accuracy: 0.5148 - val_loss: 0.7346 - val_accuracy: 0.4922
# Epoch 37/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7153 - accuracy: 0.5103
# Epoch 37: loss improved from 0.71586 to 0.71496, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7150 - accuracy: 0.5104 - val_loss: 0.7273 - val_accuracy: 0.5217
# Epoch 38/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7151 - accuracy: 0.5091
# Epoch 38: loss did not improve from 0.71496
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7158 - accuracy: 0.5085 - val_loss: 0.7308 - val_accuracy: 0.4938
# Epoch 39/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7148 - accuracy: 0.5108
# Epoch 39: loss improved from 0.71496 to 0.71459, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7146 - accuracy: 0.5099 - val_loss: 0.7262 - val_accuracy: 0.5155
# Epoch 40/200
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7167 - accuracy: 0.5123
# Epoch 40: loss did not improve from 0.71459
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7157 - accuracy: 0.5108 - val_loss: 0.7328 - val_accuracy: 0.5124
# Epoch 41/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7151 - accuracy: 0.5113
# Epoch 41: loss improved from 0.71459 to 0.71431, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7143 - accuracy: 0.5123 - val_loss: 0.7301 - val_accuracy: 0.5000
# Epoch 42/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7122 - accuracy: 0.5127
# Epoch 42: loss improved from 0.71431 to 0.71368, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7137 - accuracy: 0.5118 - val_loss: 0.7233 - val_accuracy: 0.5202
# Epoch 43/200
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7140 - accuracy: 0.5169
# Epoch 43: loss did not improve from 0.71368
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7141 - accuracy: 0.5167 - val_loss: 0.7313 - val_accuracy: 0.4922
# Epoch 44/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7135 - accuracy: 0.5073
# Epoch 44: loss improved from 0.71368 to 0.71345, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7135 - accuracy: 0.5073 - val_loss: 0.7319 - val_accuracy: 0.4907
# Epoch 45/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7137 - accuracy: 0.5224
# Epoch 45: loss did not improve from 0.71345
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7137 - accuracy: 0.5224 - val_loss: 0.7279 - val_accuracy: 0.5047
# Epoch 46/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7138 - accuracy: 0.5082
# Epoch 46: loss did not improve from 0.71345
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7138 - accuracy: 0.5082 - val_loss: 0.7307 - val_accuracy: 0.5326
# Epoch 47/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7142 - accuracy: 0.5066
# Epoch 47: loss improved from 0.71345 to 0.71314, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7131 - accuracy: 0.5103 - val_loss: 0.7326 - val_accuracy: 0.4953
# Epoch 48/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7120 - accuracy: 0.5087
# Epoch 48: loss improved from 0.71314 to 0.71219, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7122 - accuracy: 0.5091 - val_loss: 0.7316 - val_accuracy: 0.5109
# Epoch 49/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5152
# Epoch 49: loss did not improve from 0.71219
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7130 - accuracy: 0.5149 - val_loss: 0.7256 - val_accuracy: 0.5202
# Epoch 50/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7117 - accuracy: 0.5144
# Epoch 50: loss improved from 0.71219 to 0.71214, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7121 - accuracy: 0.5180 - val_loss: 0.7360 - val_accuracy: 0.5016
# Epoch 51/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7141 - accuracy: 0.5153
# Epoch 51: loss did not improve from 0.71214
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7127 - accuracy: 0.5146 - val_loss: 0.7262 - val_accuracy: 0.4984
# Epoch 52/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.5118
# Epoch 52: loss improved from 0.71214 to 0.71184, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7118 - accuracy: 0.5118 - val_loss: 0.7282 - val_accuracy: 0.5171
# Epoch 53/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7138 - accuracy: 0.5020
# Epoch 53: loss did not improve from 0.71184
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7155 - accuracy: 0.5003 - val_loss: 0.7305 - val_accuracy: 0.4984
# Epoch 54/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7065 - accuracy: 0.5250
# Epoch 54: loss did not improve from 0.71184
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7121 - accuracy: 0.5212 - val_loss: 0.7250 - val_accuracy: 0.5078
# Epoch 55/200
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7104 - accuracy: 0.5164
# Epoch 55: loss improved from 0.71184 to 0.71125, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7113 - accuracy: 0.5160 - val_loss: 0.7273 - val_accuracy: 0.4845
# Epoch 56/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5146
# Epoch 56: loss improved from 0.71125 to 0.71012, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5148 - val_loss: 0.7286 - val_accuracy: 0.5031
# Epoch 57/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7129 - accuracy: 0.5077
# Epoch 57: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7127 - accuracy: 0.5058 - val_loss: 0.7230 - val_accuracy: 0.5264
# Epoch 58/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5152
# Epoch 58: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7114 - accuracy: 0.5137 - val_loss: 0.7271 - val_accuracy: 0.4938
# Epoch 59/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.5049
# Epoch 59: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7112 - accuracy: 0.5049 - val_loss: 0.7363 - val_accuracy: 0.5047
# Epoch 60/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5157
# Epoch 60: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7105 - accuracy: 0.5161 - val_loss: 0.7275 - val_accuracy: 0.5062
# Epoch 61/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5059
# Epoch 61: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7111 - accuracy: 0.5053 - val_loss: 0.7249 - val_accuracy: 0.5078
# Epoch 62/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7116 - accuracy: 0.5099
# Epoch 62: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7115 - accuracy: 0.5094 - val_loss: 0.7223 - val_accuracy: 0.5217
# Epoch 63/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.5130
# Epoch 63: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7107 - accuracy: 0.5141 - val_loss: 0.7294 - val_accuracy: 0.5031
# Epoch 64/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7121 - accuracy: 0.5108
# Epoch 64: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7119 - accuracy: 0.5108 - val_loss: 0.7250 - val_accuracy: 0.5093
# Epoch 65/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7111 - accuracy: 0.5153
# Epoch 65: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7114 - accuracy: 0.5141 - val_loss: 0.7232 - val_accuracy: 0.5031
# Epoch 66/200
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7122 - accuracy: 0.5108
# Epoch 66: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7115 - accuracy: 0.5115 - val_loss: 0.7240 - val_accuracy: 0.5140
# Epoch 67/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5098
# Epoch 67: loss did not improve from 0.71012
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7107 - accuracy: 0.5099 - val_loss: 0.7271 - val_accuracy: 0.4984
# Epoch 68/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7079 - accuracy: 0.5220
# Epoch 68: loss improved from 0.71012 to 0.70897, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7090 - accuracy: 0.5210 - val_loss: 0.7200 - val_accuracy: 0.5155
# Epoch 69/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5166
# Epoch 69: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7107 - accuracy: 0.5163 - val_loss: 0.7247 - val_accuracy: 0.5124
# Epoch 70/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5068
# Epoch 70: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7099 - accuracy: 0.5053 - val_loss: 0.7240 - val_accuracy: 0.4984
# Epoch 71/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5089
# Epoch 71: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7102 - accuracy: 0.5091 - val_loss: 0.7319 - val_accuracy: 0.4891
# Epoch 72/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5127
# Epoch 72: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7096 - accuracy: 0.5134 - val_loss: 0.7207 - val_accuracy: 0.5124
# Epoch 73/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7084 - accuracy: 0.5061
# Epoch 73: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7093 - accuracy: 0.5061 - val_loss: 0.7301 - val_accuracy: 0.4860
# Epoch 74/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.5163
# Epoch 74: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7105 - accuracy: 0.5167 - val_loss: 0.7220 - val_accuracy: 0.5311
# Epoch 75/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7098 - accuracy: 0.5189
# Epoch 75: loss improved from 0.70897 to 0.70893, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7089 - accuracy: 0.5193 - val_loss: 0.7248 - val_accuracy: 0.5047
# Epoch 76/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.5155
# Epoch 76: loss did not improve from 0.70893
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7098 - accuracy: 0.5149 - val_loss: 0.7277 - val_accuracy: 0.4922
# Epoch 77/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5188
# Epoch 77: loss did not improve from 0.70893
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.5193 - val_loss: 0.7299 - val_accuracy: 0.5016
# Epoch 78/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5137
# Epoch 78: loss did not improve from 0.70893
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7098 - accuracy: 0.5146 - val_loss: 0.7243 - val_accuracy: 0.5233
# Epoch 79/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5124
# Epoch 79: loss did not improve from 0.70893
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7097 - accuracy: 0.5130 - val_loss: 0.7229 - val_accuracy: 0.5217
# Epoch 80/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.5184
# Epoch 80: loss did not improve from 0.70893
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7092 - accuracy: 0.5184 - val_loss: 0.7204 - val_accuracy: 0.5217
# Epoch 81/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5221
# Epoch 81: loss improved from 0.70893 to 0.70720, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7072 - accuracy: 0.5225 - val_loss: 0.7289 - val_accuracy: 0.4783
# Epoch 82/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7084 - accuracy: 0.5238
# Epoch 82: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.5210 - val_loss: 0.7236 - val_accuracy: 0.5031
# Epoch 83/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5183
# Epoch 83: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5170 - val_loss: 0.7231 - val_accuracy: 0.4984
# Epoch 84/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7098 - accuracy: 0.5102
# Epoch 84: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7096 - accuracy: 0.5094 - val_loss: 0.7237 - val_accuracy: 0.4969
# Epoch 85/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7087 - accuracy: 0.5191
# Epoch 85: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7085 - accuracy: 0.5201 - val_loss: 0.7228 - val_accuracy: 0.4984
# Epoch 86/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5184
# Epoch 86: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7091 - accuracy: 0.5167 - val_loss: 0.7275 - val_accuracy: 0.5047
# Epoch 87/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5177
# Epoch 87: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7085 - accuracy: 0.5180 - val_loss: 0.7270 - val_accuracy: 0.5047
# Epoch 88/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5169
# Epoch 88: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7098 - accuracy: 0.5163 - val_loss: 0.7259 - val_accuracy: 0.5419
# Epoch 89/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5187
# Epoch 89: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.5186 - val_loss: 0.7237 - val_accuracy: 0.5109
# Epoch 90/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5133
# Epoch 90: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7077 - accuracy: 0.5127 - val_loss: 0.7285 - val_accuracy: 0.5078
# Epoch 91/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5232
# Epoch 91: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7079 - accuracy: 0.5224 - val_loss: 0.7200 - val_accuracy: 0.5171
# Epoch 92/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.5185
# Epoch 92: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7089 - accuracy: 0.5184 - val_loss: 0.7240 - val_accuracy: 0.5093
# Epoch 93/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.5116
# Epoch 93: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7081 - accuracy: 0.5108 - val_loss: 0.7270 - val_accuracy: 0.5000
# Epoch 94/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7102 - accuracy: 0.5165
# Epoch 94: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7088 - accuracy: 0.5151 - val_loss: 0.7226 - val_accuracy: 0.5171
# Epoch 95/200
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7093 - accuracy: 0.5125
# Epoch 95: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7085 - accuracy: 0.5132 - val_loss: 0.7225 - val_accuracy: 0.5326
# Epoch 96/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5178
# Epoch 96: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5172 - val_loss: 0.7197 - val_accuracy: 0.5233
# Epoch 97/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5148
# Epoch 97: loss did not improve from 0.70720
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7081 - accuracy: 0.5139 - val_loss: 0.7255 - val_accuracy: 0.4876
# Epoch 98/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5253
# Epoch 98: loss improved from 0.70720 to 0.70714, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7071 - accuracy: 0.5253 - val_loss: 0.7207 - val_accuracy: 0.5124
# Epoch 99/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5253
# Epoch 99: loss did not improve from 0.70714
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7077 - accuracy: 0.5251 - val_loss: 0.7230 - val_accuracy: 0.5202
# Epoch 100/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7072 - accuracy: 0.5139
# Epoch 100: loss did not improve from 0.70714
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7072 - accuracy: 0.5139 - val_loss: 0.7282 - val_accuracy: 0.4969
# Epoch 101/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5149
# Epoch 101: loss did not improve from 0.70714
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7083 - accuracy: 0.5167 - val_loss: 0.7230 - val_accuracy: 0.5031
# Epoch 102/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5127
# Epoch 102: loss did not improve from 0.70714
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7083 - accuracy: 0.5115 - val_loss: 0.7283 - val_accuracy: 0.4876
# Epoch 103/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5156
# Epoch 103: loss improved from 0.70714 to 0.70687, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7069 - accuracy: 0.5153 - val_loss: 0.7239 - val_accuracy: 0.5062
# Epoch 104/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5174
# Epoch 104: loss did not improve from 0.70687
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7075 - accuracy: 0.5172 - val_loss: 0.7249 - val_accuracy: 0.4984
# Epoch 105/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5200
# Epoch 105: loss did not improve from 0.70687
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5186 - val_loss: 0.7222 - val_accuracy: 0.5000
# Epoch 106/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.5186
# Epoch 106: loss did not improve from 0.70687
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5186 - val_loss: 0.7198 - val_accuracy: 0.5186
# Epoch 107/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.5160
# Epoch 107: loss did not improve from 0.70687
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5160 - val_loss: 0.7217 - val_accuracy: 0.5047
# Epoch 108/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5197
# Epoch 108: loss improved from 0.70687 to 0.70653, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7065 - accuracy: 0.5179 - val_loss: 0.7359 - val_accuracy: 0.4814
# Epoch 109/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5150
# Epoch 109: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5146 - val_loss: 0.7231 - val_accuracy: 0.5264
# Epoch 110/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5159
# Epoch 110: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7071 - accuracy: 0.5144 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 111/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5177
# Epoch 111: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7072 - accuracy: 0.5179 - val_loss: 0.7281 - val_accuracy: 0.4860
# Epoch 112/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7082 - accuracy: 0.5149
# Epoch 112: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7078 - accuracy: 0.5139 - val_loss: 0.7266 - val_accuracy: 0.5062
# Epoch 113/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5148
# Epoch 113: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7073 - accuracy: 0.5148 - val_loss: 0.7225 - val_accuracy: 0.4891
# Epoch 114/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5136
# Epoch 114: loss did not improve from 0.70653
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7070 - accuracy: 0.5134 - val_loss: 0.7218 - val_accuracy: 0.5217
# Epoch 115/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5208
# Epoch 115: loss improved from 0.70653 to 0.70645, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7065 - accuracy: 0.5201 - val_loss: 0.7234 - val_accuracy: 0.4907
# Epoch 116/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7073 - accuracy: 0.5255
# Epoch 116: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5255 - val_loss: 0.7259 - val_accuracy: 0.5031
# Epoch 117/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5191
# Epoch 117: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7074 - accuracy: 0.5201 - val_loss: 0.7242 - val_accuracy: 0.5264
# Epoch 118/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.5175
# Epoch 118: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7081 - accuracy: 0.5163 - val_loss: 0.7238 - val_accuracy: 0.4969
# Epoch 119/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5114
# Epoch 119: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7071 - accuracy: 0.5103 - val_loss: 0.7220 - val_accuracy: 0.5109
# Epoch 120/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5177
# Epoch 120: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7075 - accuracy: 0.5146 - val_loss: 0.7250 - val_accuracy: 0.5233
# Epoch 121/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7080 - accuracy: 0.5239
# Epoch 121: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5222 - val_loss: 0.7227 - val_accuracy: 0.5248
# Epoch 122/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5208
# Epoch 122: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5222 - val_loss: 0.7247 - val_accuracy: 0.5093
# Epoch 123/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5114
# Epoch 123: loss did not improve from 0.70645
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7076 - accuracy: 0.5113 - val_loss: 0.7236 - val_accuracy: 0.4969
# Epoch 124/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7067 - accuracy: 0.5222
# Epoch 124: loss improved from 0.70645 to 0.70640, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7064 - accuracy: 0.5203 - val_loss: 0.7225 - val_accuracy: 0.4922
# Epoch 125/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.5218
# Epoch 125: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5218 - val_loss: 0.7238 - val_accuracy: 0.4938
# Epoch 126/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5176
# Epoch 126: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7065 - accuracy: 0.5177 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 127/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5083
# Epoch 127: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7065 - accuracy: 0.5091 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 128/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5194
# Epoch 128: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7066 - accuracy: 0.5198 - val_loss: 0.7228 - val_accuracy: 0.5016
# Epoch 129/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5134
# Epoch 129: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7068 - accuracy: 0.5136 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 130/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7081 - accuracy: 0.5167
# Epoch 130: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5193 - val_loss: 0.7227 - val_accuracy: 0.5264
# Epoch 131/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5168
# Epoch 131: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5160 - val_loss: 0.7218 - val_accuracy: 0.4984
# Epoch 132/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5018
# Epoch 132: loss did not improve from 0.70640
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5049 - val_loss: 0.7224 - val_accuracy: 0.5031
# Epoch 133/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7068 - accuracy: 0.5215
# Epoch 133: loss improved from 0.70640 to 0.70579, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7058 - accuracy: 0.5229 - val_loss: 0.7248 - val_accuracy: 0.5078
# Epoch 134/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5183
# Epoch 134: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7071 - accuracy: 0.5170 - val_loss: 0.7238 - val_accuracy: 0.4938
# Epoch 135/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5120
# Epoch 135: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7063 - accuracy: 0.5115 - val_loss: 0.7247 - val_accuracy: 0.5264
# Epoch 136/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5216
# Epoch 136: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.5218 - val_loss: 0.7249 - val_accuracy: 0.4922
# Epoch 137/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7083 - accuracy: 0.5237
# Epoch 137: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5224 - val_loss: 0.7225 - val_accuracy: 0.5124
# Epoch 138/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5177
# Epoch 138: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7080 - accuracy: 0.5174 - val_loss: 0.7217 - val_accuracy: 0.5062
# Epoch 139/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5213
# Epoch 139: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7060 - accuracy: 0.5215 - val_loss: 0.7247 - val_accuracy: 0.4922
# Epoch 140/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5187
# Epoch 140: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7061 - accuracy: 0.5180 - val_loss: 0.7231 - val_accuracy: 0.4984
# Epoch 141/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7079 - accuracy: 0.5134
# Epoch 141: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7079 - accuracy: 0.5134 - val_loss: 0.7220 - val_accuracy: 0.5109
# Epoch 142/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7070 - accuracy: 0.5113
# Epoch 142: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7069 - accuracy: 0.5117 - val_loss: 0.7235 - val_accuracy: 0.5109
# Epoch 143/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5169
# Epoch 143: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7064 - accuracy: 0.5180 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 144/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5200
# Epoch 144: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.5205 - val_loss: 0.7236 - val_accuracy: 0.4907
# Epoch 145/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7066 - accuracy: 0.5196
# Epoch 145: loss did not improve from 0.70579
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5229 - val_loss: 0.7233 - val_accuracy: 0.5078
# Epoch 146/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5263
# Epoch 146: loss improved from 0.70579 to 0.70572, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7057 - accuracy: 0.5262 - val_loss: 0.7198 - val_accuracy: 0.5078
# Epoch 147/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5107
# Epoch 147: loss did not improve from 0.70572
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7072 - accuracy: 0.5098 - val_loss: 0.7252 - val_accuracy: 0.4907
# Epoch 148/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.5193
# Epoch 148: loss improved from 0.70572 to 0.70563, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7056 - accuracy: 0.5196 - val_loss: 0.7222 - val_accuracy: 0.5280
# Epoch 149/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5159
# Epoch 149: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5160 - val_loss: 0.7214 - val_accuracy: 0.5171
# Epoch 150/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5185
# Epoch 150: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7063 - accuracy: 0.5179 - val_loss: 0.7228 - val_accuracy: 0.4922
# Epoch 151/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7059 - accuracy: 0.5207
# Epoch 151: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7060 - accuracy: 0.5206 - val_loss: 0.7245 - val_accuracy: 0.4922
# Epoch 152/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7063 - accuracy: 0.5089
# Epoch 152: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7063 - accuracy: 0.5089 - val_loss: 0.7243 - val_accuracy: 0.4922
# Epoch 153/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7058 - accuracy: 0.5155
# Epoch 153: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7063 - accuracy: 0.5155 - val_loss: 0.7222 - val_accuracy: 0.5078
# Epoch 154/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5238
# Epoch 154: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7062 - accuracy: 0.5237 - val_loss: 0.7266 - val_accuracy: 0.5031
# Epoch 155/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5209
# Epoch 155: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7061 - accuracy: 0.5225 - val_loss: 0.7236 - val_accuracy: 0.5078
# Epoch 156/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.5115
# Epoch 156: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5115 - val_loss: 0.7227 - val_accuracy: 0.5109
# Epoch 157/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5251
# Epoch 157: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5253 - val_loss: 0.7222 - val_accuracy: 0.5078
# Epoch 158/200
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5112
# Epoch 158: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5141 - val_loss: 0.7221 - val_accuracy: 0.5264
# Epoch 159/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7076 - accuracy: 0.5239
# Epoch 159: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.5225 - val_loss: 0.7238 - val_accuracy: 0.5078
# Epoch 160/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7062 - accuracy: 0.5145
# Epoch 160: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5132 - val_loss: 0.7229 - val_accuracy: 0.5186
# Epoch 161/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5214
# Epoch 161: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5199 - val_loss: 0.7240 - val_accuracy: 0.5202
# Epoch 162/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7062 - accuracy: 0.5237
# Epoch 162: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5237 - val_loss: 0.7220 - val_accuracy: 0.4922
# Epoch 163/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.5212
# Epoch 163: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7064 - accuracy: 0.5212 - val_loss: 0.7217 - val_accuracy: 0.4922
# Epoch 164/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5176
# Epoch 164: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5167 - val_loss: 0.7235 - val_accuracy: 0.4922
# Epoch 165/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5253
# Epoch 165: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5256 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 166/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5240
# Epoch 166: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7060 - accuracy: 0.5241 - val_loss: 0.7234 - val_accuracy: 0.5171
# Epoch 167/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5137
# Epoch 167: loss did not improve from 0.70563
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7060 - accuracy: 0.5125 - val_loss: 0.7225 - val_accuracy: 0.5078
# Epoch 168/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5194
# Epoch 168: loss improved from 0.70563 to 0.70556, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 3s 17ms/step - loss: 0.7056 - accuracy: 0.5220 - val_loss: 0.7213 - val_accuracy: 0.5078
# Epoch 169/200
# 181/181 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.5267
# Epoch 169: loss did not improve from 0.70556
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5267 - val_loss: 0.7202 - val_accuracy: 0.5357
# Epoch 170/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5205
# Epoch 170: loss improved from 0.70556 to 0.70549, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7055 - accuracy: 0.5210 - val_loss: 0.7241 - val_accuracy: 0.4922
# Epoch 171/200
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7067 - accuracy: 0.5196
# Epoch 171: loss did not improve from 0.70549
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5191 - val_loss: 0.7231 - val_accuracy: 0.4922
# Epoch 172/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5311
# Epoch 172: loss did not improve from 0.70549
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5298 - val_loss: 0.7249 - val_accuracy: 0.4922
# Epoch 173/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5218
# Epoch 173: loss did not improve from 0.70549
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5208 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 174/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5167
# Epoch 174: loss did not improve from 0.70549
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5141 - val_loss: 0.7237 - val_accuracy: 0.4969
# Epoch 175/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5166
# Epoch 175: loss did not improve from 0.70549
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5180 - val_loss: 0.7232 - val_accuracy: 0.5016
# Epoch 176/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5261
# Epoch 176: loss improved from 0.70549 to 0.70548, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7055 - accuracy: 0.5253 - val_loss: 0.7210 - val_accuracy: 0.5031
# Epoch 177/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5233
# Epoch 177: loss did not improve from 0.70548
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5246 - val_loss: 0.7214 - val_accuracy: 0.5109
# Epoch 178/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5115
# Epoch 178: loss did not improve from 0.70548
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7061 - accuracy: 0.5123 - val_loss: 0.7233 - val_accuracy: 0.5062
# Epoch 179/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5178
# Epoch 179: loss did not improve from 0.70548
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7061 - accuracy: 0.5193 - val_loss: 0.7218 - val_accuracy: 0.5109
# Epoch 180/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7045 - accuracy: 0.5250
# Epoch 180: loss did not improve from 0.70548
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7056 - accuracy: 0.5241 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 181/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5119
# Epoch 181: loss improved from 0.70548 to 0.70547, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7055 - accuracy: 0.5125 - val_loss: 0.7235 - val_accuracy: 0.5078
# Epoch 182/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5170
# Epoch 182: loss did not improve from 0.70547
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5168 - val_loss: 0.7238 - val_accuracy: 0.5078
# Epoch 183/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7059 - accuracy: 0.5224
# Epoch 183: loss improved from 0.70547 to 0.70537, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7054 - accuracy: 0.5229 - val_loss: 0.7223 - val_accuracy: 0.4922
# Epoch 184/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7074 - accuracy: 0.5266
# Epoch 184: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.5281 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 185/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7093 - accuracy: 0.5147
# Epoch 185: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.5180 - val_loss: 0.7235 - val_accuracy: 0.4922
# Epoch 186/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7044 - accuracy: 0.5171
# Epoch 186: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5198 - val_loss: 0.7236 - val_accuracy: 0.5078
# Epoch 187/200
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7065 - accuracy: 0.5221
# Epoch 187: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5234 - val_loss: 0.7226 - val_accuracy: 0.4922
# Epoch 188/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5229
# Epoch 188: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5241 - val_loss: 0.7217 - val_accuracy: 0.5264
# Epoch 189/200
# 177/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5240
# Epoch 189: loss did not improve from 0.70537
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7054 - accuracy: 0.5232 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 190/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5200
# Epoch 190: loss improved from 0.70537 to 0.70531, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7053 - accuracy: 0.5212 - val_loss: 0.7206 - val_accuracy: 0.5078
# Epoch 191/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5216
# Epoch 191: loss did not improve from 0.70531
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7055 - accuracy: 0.5212 - val_loss: 0.7213 - val_accuracy: 0.5078
# Epoch 192/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5263
# Epoch 192: loss did not improve from 0.70531
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7054 - accuracy: 0.5246 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 193/200
# 180/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5267
# Epoch 193: loss did not improve from 0.70531
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7053 - accuracy: 0.5279 - val_loss: 0.7231 - val_accuracy: 0.5062
# Epoch 194/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5168
# Epoch 194: loss did not improve from 0.70531
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7058 - accuracy: 0.5161 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 195/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7040 - accuracy: 0.5254
# Epoch 195: loss did not improve from 0.70531
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7056 - accuracy: 0.5241 - val_loss: 0.7234 - val_accuracy: 0.5078
# Epoch 196/200
# 176/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5131
# Epoch 196: loss did not improve from 0.70531
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5125 - val_loss: 0.7222 - val_accuracy: 0.5078
# Epoch 197/200
# 179/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5279
# Epoch 197: loss improved from 0.70531 to 0.70526, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.7053 - accuracy: 0.5284 - val_loss: 0.7226 - val_accuracy: 0.4938
# Epoch 198/200
# 175/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5175
# Epoch 198: loss did not improve from 0.70526
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5153 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 199/200
# 178/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5176
# Epoch 199: loss did not improve from 0.70526
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7057 - accuracy: 0.5175 - val_loss: 0.7211 - val_accuracy: 0.5078
# Epoch 200/200
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7035 - accuracy: 0.5176
# Epoch 200: loss did not improve from 0.70526
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5175 - val_loss: 0.7229 - val_accuracy: 0.5078

# %%
# print(train_sh.history)
# model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6.h5')
model = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# 41/41 [==============================] - 1s 4ms/step - loss: 0.7226 - accuracy: 0.4938
# 21/21 [==============================] - 0s 3ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           17
# 1       441            4
# 2       729            4
# 3      6561           17
# 4      1369            6
# 5       121            3
# 6       729            4
# 7       441            4
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           17
# 1                4.23               3       441            4
# 2                4.77               4       729            4

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/Model6_1results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           16
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            8
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.17                0.17         0.01
# 1  ...              5.00                0.33         0.07
# 2  ...              8.33                0.33         0.04
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.17            16.26              16.39
# 1                 5.00             5.17               5.42
# 2                 8.33             8.50               8.75
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               16.57              16      7396                1
# 1                5.77               5      1024                7
# 2                9.10               8      2704                4
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/model6_1.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 99ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/Model6_1results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            6  ...                0.33         0.07                 5.00
# 2            8  ...                0.00         0.00                 8.67
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             5.17               5.42                5.77               5
# 2             8.67               8.67                8.67               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1      1024                7            0
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
