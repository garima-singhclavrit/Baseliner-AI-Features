# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(256, activation='relu')(inp1)
lay1_1 = tf.keras.layers.Dense(128,activation='relu')(lay1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(256, activation='relu')(inp2)
lay2_1 = tf.keras.layers.Dense(128,activation='relu')(lay2)

concatenate_gpt2 = tf.keras.layers.Concatenate()([lay1_1,lay2_1])
# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([concatenate_gpt2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  dense_8 (Dense)             (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  32896     ['dense_8[0][0]']
#
#  dense_11 (Dense)            (None, 128)                  32896     ['dense_10[0][0]']
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['dense_9[0][0]',
#  )                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_13 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_14 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 308)                  0         ['concatenate_1[0][0]',
#  )                                                                   'dense_12[0][0]',
#                                                                      'dense_13[0][0]',
#                                                                      'dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 384)                  118656    ['concatenate_2[0][0]']
#
#  dense_16 (Dense)            (None, 128)                  49280     ['dense_15[0][0]']
#
#  dense_17 (Dense)            (None, 26)                   3354      ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 632014 (2.41 MB)
# Trainable params: 632014 (2.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=300,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/300
# 354/362 [============================>.] - ETA: 0s - loss: 1.5017 - accuracy: 0.4082
# Epoch 1: loss improved from inf to 1.48780, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 362/362 [==============================] - 6s 7ms/step - loss: 1.4878 - accuracy: 0.4110 - val_loss: 0.9311 - val_accuracy: 0.4627
# Epoch 2/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.8530 - accuracy: 0.5028
# Epoch 2: loss improved from 1.48780 to 0.85201, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.8520 - accuracy: 0.5011 - val_loss: 0.8310 - val_accuracy: 0.4829
# Epoch 3/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.8025 - accuracy: 0.4928
# Epoch 3: loss improved from 0.85201 to 0.80175, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 7ms/step - loss: 0.8018 - accuracy: 0.4942 - val_loss: 0.8011 - val_accuracy: 0.5016
# Epoch 4/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7752 - accuracy: 0.5005
# Epoch 4: loss improved from 0.80175 to 0.77587, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7759 - accuracy: 0.4992 - val_loss: 0.7579 - val_accuracy: 0.5047
# Epoch 5/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7539 - accuracy: 0.5002
# Epoch 5: loss improved from 0.77587 to 0.75457, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7546 - accuracy: 0.5008 - val_loss: 0.7737 - val_accuracy: 0.5000
# Epoch 6/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7433 - accuracy: 0.5132
# Epoch 6: loss improved from 0.75457 to 0.74282, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7428 - accuracy: 0.5125 - val_loss: 0.7475 - val_accuracy: 0.5062
# Epoch 7/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7373 - accuracy: 0.5074
# Epoch 7: loss improved from 0.74282 to 0.73854, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7385 - accuracy: 0.5065 - val_loss: 0.7494 - val_accuracy: 0.5093
# Epoch 8/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7326 - accuracy: 0.5030
# Epoch 8: loss improved from 0.73854 to 0.73265, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7326 - accuracy: 0.5030 - val_loss: 0.7378 - val_accuracy: 0.5295
# Epoch 9/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5021
# Epoch 9: loss improved from 0.73265 to 0.72773, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7277 - accuracy: 0.5030 - val_loss: 0.7593 - val_accuracy: 0.4752
# Epoch 10/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7273 - accuracy: 0.5118
# Epoch 10: loss improved from 0.72773 to 0.72752, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7275 - accuracy: 0.5103 - val_loss: 0.7330 - val_accuracy: 0.4938
# Epoch 11/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7270 - accuracy: 0.5100
# Epoch 11: loss improved from 0.72752 to 0.72668, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7267 - accuracy: 0.5101 - val_loss: 0.7423 - val_accuracy: 0.5078
# Epoch 12/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7228 - accuracy: 0.5214
# Epoch 12: loss improved from 0.72668 to 0.72268, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7227 - accuracy: 0.5217 - val_loss: 0.7333 - val_accuracy: 0.5295
# Epoch 13/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7240 - accuracy: 0.5149
# Epoch 13: loss did not improve from 0.72268
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7233 - accuracy: 0.5155 - val_loss: 0.7372 - val_accuracy: 0.5047
# Epoch 14/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7223 - accuracy: 0.5117
# Epoch 14: loss did not improve from 0.72268
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7227 - accuracy: 0.5111 - val_loss: 0.7351 - val_accuracy: 0.4860
# Epoch 15/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7194 - accuracy: 0.5084
# Epoch 15: loss improved from 0.72268 to 0.71984, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7198 - accuracy: 0.5080 - val_loss: 0.7309 - val_accuracy: 0.5264
# Epoch 16/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7197 - accuracy: 0.5060
# Epoch 16: loss improved from 0.71984 to 0.71955, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7195 - accuracy: 0.5058 - val_loss: 0.7400 - val_accuracy: 0.5264
# Epoch 17/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7212 - accuracy: 0.5110
# Epoch 17: loss did not improve from 0.71955
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7211 - accuracy: 0.5101 - val_loss: 0.7217 - val_accuracy: 0.5202
# Epoch 18/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.5034
# Epoch 18: loss improved from 0.71955 to 0.71814, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7181 - accuracy: 0.5034 - val_loss: 0.7314 - val_accuracy: 0.4969
# Epoch 19/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7181 - accuracy: 0.5102
# Epoch 19: loss did not improve from 0.71814
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7182 - accuracy: 0.5103 - val_loss: 0.7329 - val_accuracy: 0.5016
# Epoch 20/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7167 - accuracy: 0.5212
# Epoch 20: loss improved from 0.71814 to 0.71651, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7165 - accuracy: 0.5212 - val_loss: 0.7306 - val_accuracy: 0.5202
# Epoch 21/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7159 - accuracy: 0.5183
# Epoch 21: loss did not improve from 0.71651
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7167 - accuracy: 0.5170 - val_loss: 0.7267 - val_accuracy: 0.5171
# Epoch 22/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7162 - accuracy: 0.5060
# Epoch 22: loss improved from 0.71651 to 0.71632, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7163 - accuracy: 0.5046 - val_loss: 0.7256 - val_accuracy: 0.5295
# Epoch 23/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7157 - accuracy: 0.5058
# Epoch 23: loss improved from 0.71632 to 0.71524, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7152 - accuracy: 0.5058 - val_loss: 0.7306 - val_accuracy: 0.5093
# Epoch 24/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5093
# Epoch 24: loss did not improve from 0.71524
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7153 - accuracy: 0.5099 - val_loss: 0.7392 - val_accuracy: 0.4720
# Epoch 25/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7150 - accuracy: 0.5224
# Epoch 25: loss improved from 0.71524 to 0.71480, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7148 - accuracy: 0.5220 - val_loss: 0.7268 - val_accuracy: 0.5078
# Epoch 26/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.5137
# Epoch 26: loss improved from 0.71480 to 0.71286, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7129 - accuracy: 0.5144 - val_loss: 0.7296 - val_accuracy: 0.5202
# Epoch 27/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7158 - accuracy: 0.5123
# Epoch 27: loss did not improve from 0.71286
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7150 - accuracy: 0.5136 - val_loss: 0.7359 - val_accuracy: 0.4907
# Epoch 28/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7128 - accuracy: 0.5139
# Epoch 28: loss improved from 0.71286 to 0.71282, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7128 - accuracy: 0.5139 - val_loss: 0.7266 - val_accuracy: 0.5233
# Epoch 29/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.5151
# Epoch 29: loss did not improve from 0.71282
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7129 - accuracy: 0.5139 - val_loss: 0.7263 - val_accuracy: 0.4814
# Epoch 30/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.5148
# Epoch 30: loss improved from 0.71282 to 0.71258, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7126 - accuracy: 0.5160 - val_loss: 0.7241 - val_accuracy: 0.5233
# Epoch 31/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7137 - accuracy: 0.5027
# Epoch 31: loss did not improve from 0.71258
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7137 - accuracy: 0.5027 - val_loss: 0.7231 - val_accuracy: 0.5031
# Epoch 32/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7125 - accuracy: 0.5042
# Epoch 32: loss improved from 0.71258 to 0.71215, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7122 - accuracy: 0.5053 - val_loss: 0.7240 - val_accuracy: 0.5124
# Epoch 33/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7136 - accuracy: 0.5018
# Epoch 33: loss did not improve from 0.71215
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7128 - accuracy: 0.5032 - val_loss: 0.7238 - val_accuracy: 0.5233
# Epoch 34/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5055
# Epoch 34: loss improved from 0.71215 to 0.71067, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7107 - accuracy: 0.5053 - val_loss: 0.7220 - val_accuracy: 0.5124
# Epoch 35/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7119 - accuracy: 0.5162
# Epoch 35: loss did not improve from 0.71067
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7115 - accuracy: 0.5158 - val_loss: 0.7281 - val_accuracy: 0.5171
# Epoch 36/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5028
# Epoch 36: loss did not improve from 0.71067
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7114 - accuracy: 0.5035 - val_loss: 0.7317 - val_accuracy: 0.4689
# Epoch 37/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5193
# Epoch 37: loss did not improve from 0.71067
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7109 - accuracy: 0.5196 - val_loss: 0.7340 - val_accuracy: 0.4876
# Epoch 38/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7116 - accuracy: 0.5180
# Epoch 38: loss did not improve from 0.71067
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7110 - accuracy: 0.5187 - val_loss: 0.7292 - val_accuracy: 0.4984
# Epoch 39/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.5133
# Epoch 39: loss improved from 0.71067 to 0.70991, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7099 - accuracy: 0.5134 - val_loss: 0.7251 - val_accuracy: 0.5155
# Epoch 40/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5056
# Epoch 40: loss did not improve from 0.70991
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7111 - accuracy: 0.5046 - val_loss: 0.7248 - val_accuracy: 0.5140
# Epoch 41/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5073
# Epoch 41: loss did not improve from 0.70991
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7103 - accuracy: 0.5085 - val_loss: 0.7189 - val_accuracy: 0.5404
# Epoch 42/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5197
# Epoch 42: loss did not improve from 0.70991
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7105 - accuracy: 0.5199 - val_loss: 0.7267 - val_accuracy: 0.4860
# Epoch 43/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.5164
# Epoch 43: loss did not improve from 0.70991
# 362/362 [==============================] - 3s 9ms/step - loss: 0.7100 - accuracy: 0.5160 - val_loss: 0.7231 - val_accuracy: 0.5000
# Epoch 44/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5118
# Epoch 44: loss improved from 0.70991 to 0.70899, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 8s 22ms/step - loss: 0.7090 - accuracy: 0.5118 - val_loss: 0.7246 - val_accuracy: 0.5031
# Epoch 45/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.5136
# Epoch 45: loss did not improve from 0.70899
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7100 - accuracy: 0.5136 - val_loss: 0.7224 - val_accuracy: 0.4953
# Epoch 46/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5106
# Epoch 46: loss did not improve from 0.70899
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7102 - accuracy: 0.5120 - val_loss: 0.7249 - val_accuracy: 0.5016
# Epoch 47/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.5162
# Epoch 47: loss did not improve from 0.70899
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7097 - accuracy: 0.5161 - val_loss: 0.7276 - val_accuracy: 0.4860
# Epoch 48/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5037
# Epoch 48: loss did not improve from 0.70899
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7098 - accuracy: 0.5034 - val_loss: 0.7252 - val_accuracy: 0.5062
# Epoch 49/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5184
# Epoch 49: loss did not improve from 0.70899
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7093 - accuracy: 0.5187 - val_loss: 0.7249 - val_accuracy: 0.4876
# Epoch 50/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5161
# Epoch 50: loss improved from 0.70899 to 0.70849, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7085 - accuracy: 0.5165 - val_loss: 0.7336 - val_accuracy: 0.5233
# Epoch 51/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5143
# Epoch 51: loss did not improve from 0.70849
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7110 - accuracy: 0.5139 - val_loss: 0.7301 - val_accuracy: 0.4829
# Epoch 52/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5128
# Epoch 52: loss did not improve from 0.70849
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7114 - accuracy: 0.5123 - val_loss: 0.7282 - val_accuracy: 0.5109
# Epoch 53/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5117
# Epoch 53: loss did not improve from 0.70849
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7092 - accuracy: 0.5111 - val_loss: 0.7211 - val_accuracy: 0.5186
# Epoch 54/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5064
# Epoch 54: loss did not improve from 0.70849
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7085 - accuracy: 0.5073 - val_loss: 0.7199 - val_accuracy: 0.5186
# Epoch 55/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5188
# Epoch 55: loss improved from 0.70849 to 0.70806, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7081 - accuracy: 0.5187 - val_loss: 0.7235 - val_accuracy: 0.5093
# Epoch 56/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5131
# Epoch 56: loss did not improve from 0.70806
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7086 - accuracy: 0.5129 - val_loss: 0.7203 - val_accuracy: 0.5186
# Epoch 57/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5150
# Epoch 57: loss did not improve from 0.70806
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7087 - accuracy: 0.5165 - val_loss: 0.7241 - val_accuracy: 0.4984
# Epoch 58/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5218
# Epoch 58: loss improved from 0.70806 to 0.70805, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7081 - accuracy: 0.5210 - val_loss: 0.7211 - val_accuracy: 0.5217
# Epoch 59/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5160
# Epoch 59: loss improved from 0.70805 to 0.70751, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7075 - accuracy: 0.5161 - val_loss: 0.7272 - val_accuracy: 0.5062
# Epoch 60/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5181
# Epoch 60: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7086 - accuracy: 0.5179 - val_loss: 0.7285 - val_accuracy: 0.4814
# Epoch 61/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5101
# Epoch 61: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7079 - accuracy: 0.5099 - val_loss: 0.7220 - val_accuracy: 0.4922
# Epoch 62/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5136
# Epoch 62: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7085 - accuracy: 0.5127 - val_loss: 0.7255 - val_accuracy: 0.5031
# Epoch 63/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5134
# Epoch 63: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7085 - accuracy: 0.5139 - val_loss: 0.7259 - val_accuracy: 0.4984
# Epoch 64/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5123
# Epoch 64: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7081 - accuracy: 0.5108 - val_loss: 0.7266 - val_accuracy: 0.4984
# Epoch 65/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5180
# Epoch 65: loss did not improve from 0.70751
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7077 - accuracy: 0.5182 - val_loss: 0.7265 - val_accuracy: 0.5047
# Epoch 66/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5153
# Epoch 66: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7082 - accuracy: 0.5149 - val_loss: 0.7227 - val_accuracy: 0.5171
# Epoch 67/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5113
# Epoch 67: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7098 - accuracy: 0.5110 - val_loss: 0.7324 - val_accuracy: 0.5000
# Epoch 68/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5117
# Epoch 68: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7081 - accuracy: 0.5118 - val_loss: 0.7267 - val_accuracy: 0.5217
# Epoch 69/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5130
# Epoch 69: loss did not improve from 0.70751
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7076 - accuracy: 0.5122 - val_loss: 0.7228 - val_accuracy: 0.4922
# Epoch 70/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5133
# Epoch 70: loss improved from 0.70751 to 0.70725, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7073 - accuracy: 0.5136 - val_loss: 0.7220 - val_accuracy: 0.5140
# Epoch 71/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5184
# Epoch 71: loss did not improve from 0.70725
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7073 - accuracy: 0.5165 - val_loss: 0.7227 - val_accuracy: 0.4938
# Epoch 72/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5095
# Epoch 72: loss did not improve from 0.70725
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7078 - accuracy: 0.5094 - val_loss: 0.7240 - val_accuracy: 0.5233
# Epoch 73/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5115
# Epoch 73: loss did not improve from 0.70725
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7075 - accuracy: 0.5113 - val_loss: 0.7210 - val_accuracy: 0.5280
# Epoch 74/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5184
# Epoch 74: loss improved from 0.70725 to 0.70699, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7070 - accuracy: 0.5184 - val_loss: 0.7227 - val_accuracy: 0.4984
# Epoch 75/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5210
# Epoch 75: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7076 - accuracy: 0.5210 - val_loss: 0.7275 - val_accuracy: 0.4891
# Epoch 76/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5134
# Epoch 76: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7087 - accuracy: 0.5139 - val_loss: 0.7224 - val_accuracy: 0.5031
# Epoch 77/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5190
# Epoch 77: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7070 - accuracy: 0.5205 - val_loss: 0.7234 - val_accuracy: 0.5047
# Epoch 78/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5206
# Epoch 78: loss did not improve from 0.70699
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7072 - accuracy: 0.5215 - val_loss: 0.7245 - val_accuracy: 0.5295
# Epoch 79/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.5193
# Epoch 79: loss did not improve from 0.70699
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7070 - accuracy: 0.5193 - val_loss: 0.7305 - val_accuracy: 0.4907
# Epoch 80/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5148
# Epoch 80: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7077 - accuracy: 0.5141 - val_loss: 0.7214 - val_accuracy: 0.5233
# Epoch 81/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5207
# Epoch 81: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7074 - accuracy: 0.5194 - val_loss: 0.7242 - val_accuracy: 0.4922
# Epoch 82/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5062
# Epoch 82: loss did not improve from 0.70699
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7082 - accuracy: 0.5060 - val_loss: 0.7264 - val_accuracy: 0.4891
# Epoch 83/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5189
# Epoch 83: loss improved from 0.70699 to 0.70661, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7066 - accuracy: 0.5196 - val_loss: 0.7236 - val_accuracy: 0.5062
# Epoch 84/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5133
# Epoch 84: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7076 - accuracy: 0.5148 - val_loss: 0.7208 - val_accuracy: 0.5000
# Epoch 85/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5179
# Epoch 85: loss did not improve from 0.70661
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7070 - accuracy: 0.5184 - val_loss: 0.7236 - val_accuracy: 0.5078
# Epoch 86/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5176
# Epoch 86: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7074 - accuracy: 0.5182 - val_loss: 0.7211 - val_accuracy: 0.5171
# Epoch 87/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5190
# Epoch 87: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7071 - accuracy: 0.5199 - val_loss: 0.7235 - val_accuracy: 0.5000
# Epoch 88/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5158
# Epoch 88: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7071 - accuracy: 0.5160 - val_loss: 0.7220 - val_accuracy: 0.5171
# Epoch 89/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5248
# Epoch 89: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7067 - accuracy: 0.5251 - val_loss: 0.7211 - val_accuracy: 0.5078
# Epoch 90/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5168
# Epoch 90: loss did not improve from 0.70661
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7072 - accuracy: 0.5174 - val_loss: 0.7205 - val_accuracy: 0.5078
# Epoch 91/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5204
# Epoch 91: loss improved from 0.70661 to 0.70642, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7064 - accuracy: 0.5196 - val_loss: 0.7228 - val_accuracy: 0.5264
# Epoch 92/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5118
# Epoch 92: loss did not improve from 0.70642
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7083 - accuracy: 0.5113 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 93/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5218
# Epoch 93: loss did not improve from 0.70642
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7073 - accuracy: 0.5210 - val_loss: 0.7224 - val_accuracy: 0.4860
# Epoch 94/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5190
# Epoch 94: loss did not improve from 0.70642
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7065 - accuracy: 0.5186 - val_loss: 0.7219 - val_accuracy: 0.5171
# Epoch 95/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5203
# Epoch 95: loss did not improve from 0.70642
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7066 - accuracy: 0.5187 - val_loss: 0.7258 - val_accuracy: 0.5062
# Epoch 96/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5285
# Epoch 96: loss did not improve from 0.70642
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7064 - accuracy: 0.5279 - val_loss: 0.7231 - val_accuracy: 0.5124
# Epoch 97/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5166
# Epoch 97: loss did not improve from 0.70642
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7069 - accuracy: 0.5172 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 98/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5139
# Epoch 98: loss improved from 0.70642 to 0.70627, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 9ms/step - loss: 0.7063 - accuracy: 0.5142 - val_loss: 0.7238 - val_accuracy: 0.4907
# Epoch 99/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5249
# Epoch 99: loss did not improve from 0.70627
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7073 - accuracy: 0.5243 - val_loss: 0.7228 - val_accuracy: 0.5031
# Epoch 100/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5190
# Epoch 100: loss did not improve from 0.70627
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7077 - accuracy: 0.5191 - val_loss: 0.7244 - val_accuracy: 0.4969
# Epoch 101/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5161
# Epoch 101: loss did not improve from 0.70627
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7075 - accuracy: 0.5161 - val_loss: 0.7222 - val_accuracy: 0.5062
# Epoch 102/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5260
# Epoch 102: loss did not improve from 0.70627
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7069 - accuracy: 0.5256 - val_loss: 0.7233 - val_accuracy: 0.4907
# Epoch 103/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5218
# Epoch 103: loss did not improve from 0.70627
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7064 - accuracy: 0.5215 - val_loss: 0.7222 - val_accuracy: 0.5217
# Epoch 104/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5175
# Epoch 104: loss did not improve from 0.70627
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7065 - accuracy: 0.5170 - val_loss: 0.7219 - val_accuracy: 0.5264
# Epoch 105/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5246
# Epoch 105: loss improved from 0.70627 to 0.70622, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 9ms/step - loss: 0.7062 - accuracy: 0.5241 - val_loss: 0.7244 - val_accuracy: 0.5047
# Epoch 106/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5183
# Epoch 106: loss did not improve from 0.70622
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7066 - accuracy: 0.5182 - val_loss: 0.7228 - val_accuracy: 0.4891
# Epoch 107/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5168
# Epoch 107: loss did not improve from 0.70622
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7073 - accuracy: 0.5163 - val_loss: 0.7216 - val_accuracy: 0.5078
# Epoch 108/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5239
# Epoch 108: loss improved from 0.70622 to 0.70601, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7060 - accuracy: 0.5231 - val_loss: 0.7205 - val_accuracy: 0.5264
# Epoch 109/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5215
# Epoch 109: loss did not improve from 0.70601
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7061 - accuracy: 0.5206 - val_loss: 0.7261 - val_accuracy: 0.5078
# Epoch 110/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5185
# Epoch 110: loss did not improve from 0.70601
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7065 - accuracy: 0.5182 - val_loss: 0.7229 - val_accuracy: 0.5093
# Epoch 111/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5153
# Epoch 111: loss did not improve from 0.70601
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7065 - accuracy: 0.5161 - val_loss: 0.7238 - val_accuracy: 0.4922
# Epoch 112/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5227
# Epoch 112: loss improved from 0.70601 to 0.70569, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7057 - accuracy: 0.5218 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 113/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5205
# Epoch 113: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7066 - accuracy: 0.5199 - val_loss: 0.7238 - val_accuracy: 0.5109
# Epoch 114/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5181
# Epoch 114: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7067 - accuracy: 0.5180 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 115/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5221
# Epoch 115: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7062 - accuracy: 0.5215 - val_loss: 0.7238 - val_accuracy: 0.5124
# Epoch 116/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7059 - accuracy: 0.5277
# Epoch 116: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7059 - accuracy: 0.5277 - val_loss: 0.7235 - val_accuracy: 0.5062
# Epoch 117/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5212
# Epoch 117: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7062 - accuracy: 0.5205 - val_loss: 0.7206 - val_accuracy: 0.5155
# Epoch 118/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5169
# Epoch 118: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7064 - accuracy: 0.5165 - val_loss: 0.7221 - val_accuracy: 0.5109
# Epoch 119/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5103
# Epoch 119: loss did not improve from 0.70569
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7061 - accuracy: 0.5104 - val_loss: 0.7224 - val_accuracy: 0.4922
# Epoch 120/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5131
# Epoch 120: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7062 - accuracy: 0.5132 - val_loss: 0.7223 - val_accuracy: 0.4922
# Epoch 121/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.5192
# Epoch 121: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7065 - accuracy: 0.5186 - val_loss: 0.7229 - val_accuracy: 0.4922
# Epoch 122/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5249
# Epoch 122: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7067 - accuracy: 0.5250 - val_loss: 0.7226 - val_accuracy: 0.5109
# Epoch 123/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5169
# Epoch 123: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7066 - accuracy: 0.5179 - val_loss: 0.7212 - val_accuracy: 0.5078
# Epoch 124/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5177
# Epoch 124: loss did not improve from 0.70569
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7060 - accuracy: 0.5182 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 125/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5209
# Epoch 125: loss improved from 0.70569 to 0.70557, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7056 - accuracy: 0.5218 - val_loss: 0.7245 - val_accuracy: 0.5078
# Epoch 126/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5214
# Epoch 126: loss did not improve from 0.70557
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7065 - accuracy: 0.5220 - val_loss: 0.7260 - val_accuracy: 0.5155
# Epoch 127/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5189
# Epoch 127: loss did not improve from 0.70557
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7064 - accuracy: 0.5193 - val_loss: 0.7222 - val_accuracy: 0.4938
# Epoch 128/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5161
# Epoch 128: loss did not improve from 0.70557
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7059 - accuracy: 0.5172 - val_loss: 0.7242 - val_accuracy: 0.4969
# Epoch 129/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.5127
# Epoch 129: loss did not improve from 0.70557
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7124 - accuracy: 0.5127 - val_loss: 0.7809 - val_accuracy: 0.4876
# Epoch 130/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7093 - accuracy: 0.5183
# Epoch 130: loss did not improve from 0.70557
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7096 - accuracy: 0.5175 - val_loss: 0.7216 - val_accuracy: 0.5264
# Epoch 131/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5146
# Epoch 131: loss improved from 0.70557 to 0.70550, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7055 - accuracy: 0.5149 - val_loss: 0.7243 - val_accuracy: 0.5078
# Epoch 132/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7056 - accuracy: 0.5201
# Epoch 132: loss did not improve from 0.70550
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7056 - accuracy: 0.5201 - val_loss: 0.7219 - val_accuracy: 0.5109
# Epoch 133/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5179
# Epoch 133: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7057 - accuracy: 0.5175 - val_loss: 0.7235 - val_accuracy: 0.5078
# Epoch 134/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5137
# Epoch 134: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7058 - accuracy: 0.5151 - val_loss: 0.7212 - val_accuracy: 0.5171
# Epoch 135/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5232
# Epoch 135: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7057 - accuracy: 0.5222 - val_loss: 0.7217 - val_accuracy: 0.5264
# Epoch 136/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5185
# Epoch 136: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7056 - accuracy: 0.5186 - val_loss: 0.7241 - val_accuracy: 0.4984
# Epoch 137/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.5233
# Epoch 137: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7058 - accuracy: 0.5236 - val_loss: 0.7227 - val_accuracy: 0.5186
# Epoch 138/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7056 - accuracy: 0.5180
# Epoch 138: loss did not improve from 0.70550
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7056 - accuracy: 0.5180 - val_loss: 0.7235 - val_accuracy: 0.4984
# Epoch 139/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5246
# Epoch 139: loss did not improve from 0.70550
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7061 - accuracy: 0.5253 - val_loss: 0.7235 - val_accuracy: 0.5062
# Epoch 140/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5178
# Epoch 140: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7059 - accuracy: 0.5184 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 141/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5225
# Epoch 141: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7061 - accuracy: 0.5215 - val_loss: 0.7265 - val_accuracy: 0.4922
# Epoch 142/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5209
# Epoch 142: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7065 - accuracy: 0.5205 - val_loss: 0.7238 - val_accuracy: 0.4984
# Epoch 143/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5217
# Epoch 143: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7072 - accuracy: 0.5225 - val_loss: 0.7237 - val_accuracy: 0.5078
# Epoch 144/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5184
# Epoch 144: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7057 - accuracy: 0.5174 - val_loss: 0.7245 - val_accuracy: 0.5078
# Epoch 145/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7057 - accuracy: 0.5237
# Epoch 145: loss did not improve from 0.70550
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7057 - accuracy: 0.5237 - val_loss: 0.7240 - val_accuracy: 0.5093
# Epoch 146/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7057 - accuracy: 0.5260
# Epoch 146: loss did not improve from 0.70550
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7057 - accuracy: 0.5260 - val_loss: 0.7248 - val_accuracy: 0.4922
# Epoch 147/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5220
# Epoch 147: loss did not improve from 0.70550
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7058 - accuracy: 0.5218 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 148/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.5223
# Epoch 148: loss improved from 0.70550 to 0.70539, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7054 - accuracy: 0.5212 - val_loss: 0.7300 - val_accuracy: 0.4938
# Epoch 149/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5197
# Epoch 149: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7071 - accuracy: 0.5203 - val_loss: 0.7233 - val_accuracy: 0.5078
# Epoch 150/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5141
# Epoch 150: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7058 - accuracy: 0.5144 - val_loss: 0.7214 - val_accuracy: 0.4922
# Epoch 151/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5201
# Epoch 151: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7060 - accuracy: 0.5205 - val_loss: 0.7239 - val_accuracy: 0.5078
# Epoch 152/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5252
# Epoch 152: loss did not improve from 0.70539
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7055 - accuracy: 0.5251 - val_loss: 0.7201 - val_accuracy: 0.5093
# Epoch 153/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5181
# Epoch 153: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7065 - accuracy: 0.5175 - val_loss: 0.7217 - val_accuracy: 0.5264
# Epoch 154/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5220
# Epoch 154: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7055 - accuracy: 0.5220 - val_loss: 0.7225 - val_accuracy: 0.5155
# Epoch 155/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5184
# Epoch 155: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7059 - accuracy: 0.5184 - val_loss: 0.7234 - val_accuracy: 0.5078
# Epoch 156/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5179
# Epoch 156: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7057 - accuracy: 0.5187 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 157/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5209
# Epoch 157: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7059 - accuracy: 0.5218 - val_loss: 0.7197 - val_accuracy: 0.5078
# Epoch 158/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5239
# Epoch 158: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7058 - accuracy: 0.5239 - val_loss: 0.7219 - val_accuracy: 0.5264
# Epoch 159/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5253
# Epoch 159: loss did not improve from 0.70539
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7058 - accuracy: 0.5258 - val_loss: 0.7218 - val_accuracy: 0.5062
# Epoch 160/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5216
# Epoch 160: loss did not improve from 0.70539
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7068 - accuracy: 0.5208 - val_loss: 0.7231 - val_accuracy: 0.5078
# Epoch 161/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5239
# Epoch 161: loss did not improve from 0.70539
# ...
# Epoch 243: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5205 - val_loss: 0.7223 - val_accuracy: 0.5186
# Epoch 244/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5251
# Epoch 244: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5248 - val_loss: 0.7236 - val_accuracy: 0.5078
# Epoch 245/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5260
# Epoch 245: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7054 - accuracy: 0.5269 - val_loss: 0.7219 - val_accuracy: 0.5078
# Epoch 246/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.5246
# Epoch 246: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7067 - accuracy: 0.5246 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 247/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5245
# Epoch 247: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7049 - accuracy: 0.5258 - val_loss: 0.7241 - val_accuracy: 0.4922
# Epoch 248/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5216
# Epoch 248: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7051 - accuracy: 0.5208 - val_loss: 0.7235 - val_accuracy: 0.4922
# Epoch 249/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5255
# Epoch 249: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7055 - accuracy: 0.5241 - val_loss: 0.7378 - val_accuracy: 0.4922
# Epoch 250/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7072 - accuracy: 0.5225
# Epoch 250: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7072 - accuracy: 0.5218 - val_loss: 0.7218 - val_accuracy: 0.5031
# Epoch 251/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7040 - accuracy: 0.5186
# Epoch 251: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5179 - val_loss: 0.7235 - val_accuracy: 0.5248
# Epoch 252/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5210
# Epoch 252: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5215 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 253/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5219
# Epoch 253: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7050 - accuracy: 0.5222 - val_loss: 0.7215 - val_accuracy: 0.5078
# Epoch 254/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5253
# Epoch 254: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7050 - accuracy: 0.5253 - val_loss: 0.7219 - val_accuracy: 0.5186
# Epoch 255/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5233
# Epoch 255: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5239 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 256/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5263
# Epoch 256: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5265 - val_loss: 0.7226 - val_accuracy: 0.5078
# Epoch 257/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5210
# Epoch 257: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5210 - val_loss: 0.7222 - val_accuracy: 0.5078
# Epoch 258/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5172
# Epoch 258: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7052 - accuracy: 0.5170 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 259/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5248
# Epoch 259: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5256 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 260/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5218
# Epoch 260: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7051 - accuracy: 0.5220 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 261/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5242
# Epoch 261: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7060 - accuracy: 0.5239 - val_loss: 0.7241 - val_accuracy: 0.4876
# Epoch 262/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5163
# Epoch 262: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7053 - accuracy: 0.5161 - val_loss: 0.7237 - val_accuracy: 0.5031
# Epoch 263/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7039 - accuracy: 0.5267
# Epoch 263: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7049 - accuracy: 0.5256 - val_loss: 0.7228 - val_accuracy: 0.5016
# Epoch 264/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5234
# Epoch 264: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7054 - accuracy: 0.5224 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 265/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5203
# Epoch 265: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7059 - accuracy: 0.5198 - val_loss: 0.7260 - val_accuracy: 0.4984
# Epoch 266/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5168
# Epoch 266: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7055 - accuracy: 0.5168 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 267/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5249
# Epoch 267: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7050 - accuracy: 0.5256 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 268/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5250
# Epoch 268: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7051 - accuracy: 0.5244 - val_loss: 0.7235 - val_accuracy: 0.5031
# Epoch 269/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5239
# Epoch 269: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7057 - accuracy: 0.5236 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 270/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5204
# Epoch 270: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7049 - accuracy: 0.5196 - val_loss: 0.7233 - val_accuracy: 0.5078
# Epoch 271/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5225
# Epoch 271: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5225 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 272/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5219
# Epoch 272: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7052 - accuracy: 0.5218 - val_loss: 0.7228 - val_accuracy: 0.4922
# Epoch 273/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5267
# Epoch 273: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7057 - accuracy: 0.5263 - val_loss: 0.7158 - val_accuracy: 0.5062
# Epoch 274/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7295 - accuracy: 0.5201
# Epoch 274: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7295 - accuracy: 0.5201 - val_loss: 0.7381 - val_accuracy: 0.5078
# Epoch 275/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5222
# Epoch 275: loss did not improve from 0.70477
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7064 - accuracy: 0.5224 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 276/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5212
# Epoch 276: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5212 - val_loss: 0.7228 - val_accuracy: 0.5062
# Epoch 277/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5204
# Epoch 277: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7049 - accuracy: 0.5199 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 278/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5145
# Epoch 278: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5156 - val_loss: 0.7240 - val_accuracy: 0.5078
# Epoch 279/300
# 352/362 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.5249
# Epoch 279: loss did not improve from 0.70477
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7049 - accuracy: 0.5255 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 280/300
# 356/362 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5223
# Epoch 280: loss improved from 0.70477 to 0.70475, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7047 - accuracy: 0.5217 - val_loss: 0.7231 - val_accuracy: 0.5078
# Epoch 281/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5218
# Epoch 281: loss did not improve from 0.70475
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7051 - accuracy: 0.5213 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 282/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5196
# Epoch 282: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7051 - accuracy: 0.5193 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 283/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5243
# Epoch 283: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7067 - accuracy: 0.5250 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 284/300
# 354/362 [============================>.] - ETA: 0s - loss: 0.7041 - accuracy: 0.5254
# Epoch 284: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 5ms/step - loss: 0.7048 - accuracy: 0.5243 - val_loss: 0.7248 - val_accuracy: 0.5047
# Epoch 285/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5222
# Epoch 285: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7054 - accuracy: 0.5217 - val_loss: 0.7231 - val_accuracy: 0.5078
# Epoch 286/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5236
# Epoch 286: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7054 - accuracy: 0.5232 - val_loss: 0.7213 - val_accuracy: 0.4969
# Epoch 287/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5235
# Epoch 287: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 7ms/step - loss: 0.7050 - accuracy: 0.5227 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 288/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5240
# Epoch 288: loss did not improve from 0.70475
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7064 - accuracy: 0.5237 - val_loss: 0.7218 - val_accuracy: 0.4922
# Epoch 289/300
# 355/362 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5185
# Epoch 289: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5193 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 290/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5203
# Epoch 290: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7050 - accuracy: 0.5206 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 291/300
# 357/362 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5250
# Epoch 291: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7048 - accuracy: 0.5255 - val_loss: 0.7226 - val_accuracy: 0.5078
# Epoch 292/300
# 362/362 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5213
# Epoch 292: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5213 - val_loss: 0.7237 - val_accuracy: 0.4922
# Epoch 293/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5245
# Epoch 293: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7056 - accuracy: 0.5243 - val_loss: 0.7217 - val_accuracy: 0.4922
# Epoch 294/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5255
# Epoch 294: loss did not improve from 0.70475
# 362/362 [==============================] - 3s 7ms/step - loss: 0.7051 - accuracy: 0.5256 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 295/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5226
# Epoch 295: loss did not improve from 0.70475
# 362/362 [==============================] - 3s 8ms/step - loss: 0.7053 - accuracy: 0.5227 - val_loss: 0.7215 - val_accuracy: 0.5124
# Epoch 296/300
# 361/362 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5255
# Epoch 296: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7051 - accuracy: 0.5260 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 297/300
# 358/362 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5276
# Epoch 297: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7048 - accuracy: 0.5279 - val_loss: 0.7226 - val_accuracy: 0.5264
# Epoch 298/300
# 360/362 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5252
# Epoch 298: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7049 - accuracy: 0.5253 - val_loss: 0.7226 - val_accuracy: 0.5078
# Epoch 299/300
# 359/362 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5200
# Epoch 299: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7048 - accuracy: 0.5194 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 300/300
# 353/362 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5235
# Epoch 300: loss did not improve from 0.70475
# 362/362 [==============================] - 2s 6ms/step - loss: 0.7060 - accuracy: 0.5224 - val_loss: 0.7231 - val_accuracy: 0.4922

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# {'loss': [1.4878028631210327, 0.8520102500915527, 0.801753580570221, 0.775867760181427, 0.7545727491378784, 0.7428168654441833, 0.738537073135376, 0.7326499819755554, 0.727726399898529, 0.727519154548645, 0.7266771793365479, 0.7226800322532654, 0.7233059406280518, 0.7226884365081787, 0.7198386192321777, 0.7195478081703186, 0.7211330533027649, 0.7181409001350403, 0.718194842338562, 0.7165079116821289, 0.7167128920555115, 0.7163211703300476, 0.7152411341667175, 0.7153462171554565, 0.7148006558418274, 0.7128638029098511, 0.7150339484214783, 0.712819516658783, 0.7129400968551636, 0.7125813364982605, 0.7136959433555603, 0.7121528387069702, 0.7127865552902222, 0.710665225982666, 0.7114648818969727, 0.7114292979240417, 0.7109453678131104, 0.7109970450401306, 0.7099125981330872, 0.7111255526542664, 0.7102540135383606, 0.7104984521865845, 0.7100300788879395, 0.7089878916740417, 0.7100301384925842, 0.7101598381996155, 0.7096534371376038, 0.7097927927970886, 0.7093254327774048, 0.7084903717041016, 0.7109531760215759, 0.7114465236663818, 0.7092174887657166, 0.7085430026054382, 0.708061695098877, 0.7086172699928284, 0.7086735963821411, 0.7080503106117249, 0.7075080871582031, 0.708617091178894, 0.7079470157623291, 0.7085442543029785, 0.7084583044052124, 0.7080942392349243, 0.7076738476753235, 0.7082065343856812, 0.7097555994987488, 0.7080610394477844, 0.7076402902603149, 0.7072508931159973, 0.7073052525520325, 0.7077705264091492, 0.7075231671333313, 0.706993043422699, 0.7076287865638733, 0.7086604833602905, 0.7069966197013855, 0.7071962356567383, 0.7070223093032837, 0.7076574563980103, 0.7074296474456787, 0.7082301378250122, 0.7066091299057007, 0.7076250314712524, 0.7070232629776001, 0.7073976993560791, 0.7070741653442383, 0.7071418166160583, 0.7067145705223083, 0.7071577906608582, 0.7064233422279358, 0.7082579135894775, 0.7072783708572388, 0.7064641118049622, 0.7065731883049011, 0.7064358592033386, 0.7068771123886108, 0.7062692046165466, 0.7073113322257996, 0.7076665759086609, 0.7074754238128662, 0.7069248557090759, 0.7063590884208679, 0.7064613699913025, 0.7062205672264099, 0.7066418528556824, 0.7073261141777039, 0.7060058116912842, 0.7060527205467224, 0.706548273563385, 0.7064771056175232, 0.7056946754455566, 0.7065662741661072, 0.7066702246665955, 0.7061983346939087, 0.7058526277542114, 0.7062299251556396, 0.7063957452774048, 0.7060660123825073, 0.7061653137207031, 0.7064531445503235, 0.7066824436187744, 0.7066463828086853, 0.7059866189956665, 0.7055654525756836, 0.7064710259437561, 0.7064350247383118, 0.705859899520874, 0.7124473452568054, 0.7096180319786072, 0.705501139163971, 0.7055901885032654, 0.7057141065597534, 0.7057957649230957, 0.7057481408119202, 0.7056464552879333, 0.7057808041572571, 0.7055543661117554, 0.7060644030570984, 0.7058531045913696, 0.7060839533805847, 0.7064743638038635, 0.7071913480758667, 0.7057216167449951, 0.7057420015335083, 0.705740749835968, 0.7057939171791077, 0.7053887844085693, 0.7071217894554138, 0.705801248550415, 0.7059679627418518, 0.7054622769355774, 0.706469714641571, 0.7054914236068726, 0.7059012055397034, 0.7057268023490906, 0.705861508846283, 0.7058432698249817, 0.7058162093162537, 0.7068381905555725, 0.7063008546829224, 0.7059580683708191, 0.7060179114341736, 0.7055371999740601, 0.7049210071563721, 0.7059552669525146, 0.7062400579452515, 0.7069857716560364, 0.7058078050613403, 0.7058767080307007, 0.7057953476905823, 0.7057198286056519, 0.7057585716247559, 0.7064704895019531, 0.7053614258766174, 0.7063115835189819, 0.7062782049179077, 0.7062361836433411, 0.7054511308670044, 0.7054575681686401, 0.7054151892662048, 0.7055598497390747, 0.7051359415054321, 0.7076643109321594, 0.7052977681159973, 0.7066023945808411, 0.7054350972175598, 0.7053493857383728, 0.7055906057357788, 0.7052332758903503, 0.7052844762802124, 0.7073553800582886, 0.7058839797973633, 0.7055910229682922, 0.7057405710220337, 0.7056431174278259, 0.7058928608894348, 0.7073684930801392, 0.7212766408920288, 0.705558180809021, 0.7051646 ...
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7231 - accuracy: 0.4922
# 21/21 [==============================] - 0s 3ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           17
# 1       441            4
# 2       729            4
# 3      6561           17
# 4      1369            6
# 5       121            3
# 6       729            4
# 7       441            4
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           17
# 1                4.23               3       441            4
# 2                4.77               4       729            4

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/Model6_6_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           16
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.33                0.33         0.02
# 1  ...              4.67                0.00         0.00
# 2  ...              8.67                0.00         0.00
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.33            16.50              16.75
# 1                 4.67             4.67               4.67
# 2                 8.67             8.67               8.67
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.10              16      8464                2
# 1                4.67               4       400                0
# 2                8.67               8      1600                0
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  dense_8 (Dense)             (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  32896     ['dense_8[0][0]']
#
#  dense_11 (Dense)            (None, 128)                  32896     ['dense_10[0][0]']
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['dense_9[0][0]',
#  )                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_13 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_14 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 308)                  0         ['concatenate_1[0][0]',
#  )                                                                   'dense_12[0][0]',
#                                                                      'dense_13[0][0]',
#                                                                      'dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 384)                  118656    ['concatenate_2[0][0]']
#
#  dense_16 (Dense)            (None, 128)                  49280     ['dense_15[0][0]']
#
#  dense_17 (Dense)            (None, 26)                   3354      ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 632014 (2.41 MB)
# Trainable params: 632014 (2.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/Model6_6results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           16
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           18  ...                0.33         0.02                16.33
# 1            4  ...                0.00         0.00                 4.67
# 2            8  ...                0.00         0.00                 8.67
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.50              16.75               17.10              16
# 1             4.67               4.67                4.67               4
# 2             8.67               8.67                8.67               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      8464                2           16
# 1       400                0            4
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
