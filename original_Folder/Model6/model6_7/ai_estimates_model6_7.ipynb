# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(256, activation='relu')(inp1)
lay1_1 = tf.keras.layers.BatchNormalization()(lay1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(256, activation='relu')(inp2)
lay2_1 = tf.keras.layers.BatchNormalization()(lay2)

concatenate_gpt2 = tf.keras.layers.Concatenate()([lay1_1,lay2_1])

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([concatenate_gpt2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
learning_rate = 0.001
clip_value = 0.5
loss_scale_factor = 1.5
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, clipvalue=clip_value)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  dense (Dense)               (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  batch_normalization (Batch  (None, 256)                  1024      ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 256)                  1024      ['dense_1[0][0]']
#  chNormalization)
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  concatenate (Concatenate)   (None, 512)                  0         ['batch_normalization[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate_1 (Concatenate  (None, 564)                  0         ['concatenate[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  216960    ['concatenate_1[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 666574 (2.54 MB)
# Trainable params: 665550 (2.54 MB)
# Non-trainable params: 1024 (4.00 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer= optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=300,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/300
# 175/181 [============================>.] - ETA: 0s - loss: 1.3103 - accuracy: 0.4575
# Epoch 1: loss improved from inf to 1.29504, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - 7s 10ms/step - loss: 1.2950 - accuracy: 0.4588 - val_loss: 2.4197 - val_accuracy: 0.2143
# Epoch 2/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.8223 - accuracy: 0.4943
# Epoch 2: loss improved from 1.29504 to 0.82050, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.8205 - accuracy: 0.4944 - val_loss: 3.5882 - val_accuracy: 0.1258
# Epoch 3/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7806 - accuracy: 0.5089
# Epoch 3: loss improved from 0.82050 to 0.78049, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7805 - accuracy: 0.5087 - val_loss: 26.3008 - val_accuracy: 0.0171
# Epoch 4/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7608 - accuracy: 0.5154
# Epoch 4: loss improved from 0.78049 to 0.76012, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7601 - accuracy: 0.5160 - val_loss: 11.1079 - val_accuracy: 0.0202
# Epoch 5/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7507 - accuracy: 0.5132
# Epoch 5: loss improved from 0.76012 to 0.75086, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7509 - accuracy: 0.5127 - val_loss: 28.3587 - val_accuracy: 0.1537
# Epoch 6/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7445 - accuracy: 0.5102
# Epoch 6: loss improved from 0.75086 to 0.74474, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7447 - accuracy: 0.5089 - val_loss: 34.9199 - val_accuracy: 0.1118
# Epoch 7/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7357 - accuracy: 0.5138
# Epoch 7: loss improved from 0.74474 to 0.73556, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7356 - accuracy: 0.5153 - val_loss: 65.4282 - val_accuracy: 0.1304
# Epoch 8/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7321 - accuracy: 0.5177
# Epoch 8: loss improved from 0.73556 to 0.73228, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7323 - accuracy: 0.5167 - val_loss: 49.2080 - val_accuracy: 0.0171
# Epoch 9/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.5020
# Epoch 9: loss did not improve from 0.73228
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7331 - accuracy: 0.5020 - val_loss: 49.3135 - val_accuracy: 0.0171
# Epoch 10/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7247 - accuracy: 0.5165
# Epoch 10: loss improved from 0.73228 to 0.72427, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7243 - accuracy: 0.5161 - val_loss: 80.1063 - val_accuracy: 0.0171
# Epoch 11/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7255 - accuracy: 0.5210
# Epoch 11: loss did not improve from 0.72427
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7260 - accuracy: 0.5210 - val_loss: 90.8970 - val_accuracy: 0.0435
# Epoch 12/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7208 - accuracy: 0.5173
# Epoch 12: loss improved from 0.72427 to 0.72094, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7209 - accuracy: 0.5168 - val_loss: 97.6174 - val_accuracy: 0.0171
# Epoch 13/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7223 - accuracy: 0.5159
# Epoch 13: loss did not improve from 0.72094
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7242 - accuracy: 0.5149 - val_loss: 61.7672 - val_accuracy: 0.0357
# Epoch 14/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7235 - accuracy: 0.5117
# Epoch 14: loss did not improve from 0.72094
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7233 - accuracy: 0.5113 - val_loss: 97.5303 - val_accuracy: 0.0171
# Epoch 15/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7202 - accuracy: 0.5199
# Epoch 15: loss did not improve from 0.72094
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7218 - accuracy: 0.5193 - val_loss: 86.2792 - val_accuracy: 0.0357
# Epoch 16/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7220 - accuracy: 0.5110
# Epoch 16: loss did not improve from 0.72094
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7216 - accuracy: 0.5111 - val_loss: 69.3975 - val_accuracy: 0.0171
# Epoch 17/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7227 - accuracy: 0.5061
# Epoch 17: loss did not improve from 0.72094
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7219 - accuracy: 0.5046 - val_loss: 84.8713 - val_accuracy: 0.0357
# Epoch 18/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7204 - accuracy: 0.5023
# Epoch 18: loss improved from 0.72094 to 0.71917, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7192 - accuracy: 0.5044 - val_loss: 94.9843 - val_accuracy: 0.0357
# Epoch 19/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.5073
# Epoch 19: loss improved from 0.71917 to 0.71906, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7191 - accuracy: 0.5073 - val_loss: 131.6041 - val_accuracy: 0.0171
# Epoch 20/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7203 - accuracy: 0.5207
# Epoch 20: loss did not improve from 0.71906
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7203 - accuracy: 0.5199 - val_loss: 146.8531 - val_accuracy: 0.0357
# Epoch 21/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7184 - accuracy: 0.5225
# Epoch 21: loss improved from 0.71906 to 0.71842, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7184 - accuracy: 0.5225 - val_loss: 177.9126 - val_accuracy: 0.0388
# Epoch 22/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.4970
# Epoch 22: loss did not improve from 0.71842
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7205 - accuracy: 0.4970 - val_loss: 93.1464 - val_accuracy: 0.1491
# Epoch 23/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7180 - accuracy: 0.5111
# Epoch 23: loss improved from 0.71842 to 0.71725, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7172 - accuracy: 0.5118 - val_loss: 118.2340 - val_accuracy: 0.1056
# Epoch 24/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7178 - accuracy: 0.5147
# Epoch 24: loss improved from 0.71725 to 0.71724, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7172 - accuracy: 0.5141 - val_loss: 63.9727 - val_accuracy: 0.0450
# Epoch 25/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7182 - accuracy: 0.5102
# Epoch 25: loss did not improve from 0.71724
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7178 - accuracy: 0.5098 - val_loss: 194.1127 - val_accuracy: 0.0357
# Epoch 26/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.5072
# Epoch 26: loss did not improve from 0.71724
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7176 - accuracy: 0.5085 - val_loss: 204.5129 - val_accuracy: 0.0357
# Epoch 27/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7170 - accuracy: 0.5100
# Epoch 27: loss improved from 0.71724 to 0.71651, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7165 - accuracy: 0.5106 - val_loss: 166.4017 - val_accuracy: 0.0357
# Epoch 28/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7184 - accuracy: 0.5117
# Epoch 28: loss did not improve from 0.71651
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7179 - accuracy: 0.5104 - val_loss: 111.7273 - val_accuracy: 0.1304
# Epoch 29/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5154
# Epoch 29: loss improved from 0.71651 to 0.71565, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7156 - accuracy: 0.5151 - val_loss: 97.6881 - val_accuracy: 0.0342
# Epoch 30/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7140 - accuracy: 0.5161
# Epoch 30: loss improved from 0.71565 to 0.71420, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7142 - accuracy: 0.5160 - val_loss: 95.3281 - val_accuracy: 0.1522
# Epoch 31/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7151 - accuracy: 0.5042
# Epoch 31: loss did not improve from 0.71420
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7147 - accuracy: 0.5049 - val_loss: 146.6747 - val_accuracy: 0.0171
# Epoch 32/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7149 - accuracy: 0.5113
# Epoch 32: loss did not improve from 0.71420
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7144 - accuracy: 0.5113 - val_loss: 158.9861 - val_accuracy: 0.0357
# Epoch 33/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7138 - accuracy: 0.5146
# Epoch 33: loss improved from 0.71420 to 0.71404, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7140 - accuracy: 0.5144 - val_loss: 214.9692 - val_accuracy: 0.0357
# Epoch 34/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7171 - accuracy: 0.5016
# Epoch 34: loss did not improve from 0.71404
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7158 - accuracy: 0.5008 - val_loss: 141.6057 - val_accuracy: 0.0357
# Epoch 35/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7131 - accuracy: 0.5219
# Epoch 35: loss improved from 0.71404 to 0.71279, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7128 - accuracy: 0.5224 - val_loss: 207.7275 - val_accuracy: 0.0357
# Epoch 36/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7156 - accuracy: 0.5128
# Epoch 36: loss did not improve from 0.71279
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7151 - accuracy: 0.5127 - val_loss: 178.8983 - val_accuracy: 0.0357
# Epoch 37/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7124 - accuracy: 0.5143
# Epoch 37: loss improved from 0.71279 to 0.71267, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7127 - accuracy: 0.5137 - val_loss: 146.8482 - val_accuracy: 0.0357
# Epoch 38/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7121 - accuracy: 0.5114
# Epoch 38: loss did not improve from 0.71267
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7130 - accuracy: 0.5094 - val_loss: 125.5304 - val_accuracy: 0.0373
# Epoch 39/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7143 - accuracy: 0.5173
# Epoch 39: loss did not improve from 0.71267
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7146 - accuracy: 0.5144 - val_loss: 163.9957 - val_accuracy: 0.1211
# Epoch 40/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7129 - accuracy: 0.5108
# Epoch 40: loss did not improve from 0.71267
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7129 - accuracy: 0.5108 - val_loss: 240.6407 - val_accuracy: 0.0357
# Epoch 41/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7131 - accuracy: 0.5182
# Epoch 41: loss did not improve from 0.71267
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7131 - accuracy: 0.5182 - val_loss: 130.0894 - val_accuracy: 0.0357
# Epoch 42/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7133 - accuracy: 0.5133
# Epoch 42: loss did not improve from 0.71267
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7130 - accuracy: 0.5130 - val_loss: 217.7873 - val_accuracy: 0.0357
# Epoch 43/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5167
# Epoch 43: loss improved from 0.71267 to 0.71137, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7114 - accuracy: 0.5170 - val_loss: 140.1349 - val_accuracy: 0.1429
# Epoch 44/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7120 - accuracy: 0.5153
# Epoch 44: loss did not improve from 0.71137
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7126 - accuracy: 0.5141 - val_loss: 289.3962 - val_accuracy: 0.0171
# Epoch 45/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7125 - accuracy: 0.5083
# Epoch 45: loss did not improve from 0.71137
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7117 - accuracy: 0.5098 - val_loss: 173.5747 - val_accuracy: 0.0171
# Epoch 46/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.5114
# Epoch 46: loss did not improve from 0.71137
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7122 - accuracy: 0.5123 - val_loss: 135.6714 - val_accuracy: 0.0171
# Epoch 47/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7123 - accuracy: 0.5105
# Epoch 47: loss did not improve from 0.71137
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7125 - accuracy: 0.5110 - val_loss: 193.8792 - val_accuracy: 0.0171
# Epoch 48/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5205
# Epoch 48: loss improved from 0.71137 to 0.71050, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7105 - accuracy: 0.5184 - val_loss: 179.5682 - val_accuracy: 0.0171
# Epoch 49/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5178
# Epoch 49: loss improved from 0.71050 to 0.71017, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7102 - accuracy: 0.5177 - val_loss: 255.0567 - val_accuracy: 0.0171
# Epoch 50/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5063
# Epoch 50: loss did not improve from 0.71017
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7108 - accuracy: 0.5061 - val_loss: 158.0212 - val_accuracy: 0.0357
# Epoch 51/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.5186
# Epoch 51: loss did not improve from 0.71017
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7115 - accuracy: 0.5187 - val_loss: 198.2599 - val_accuracy: 0.0450
# Epoch 52/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7102 - accuracy: 0.5146
# Epoch 52: loss improved from 0.71017 to 0.71015, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7102 - accuracy: 0.5146 - val_loss: 244.3543 - val_accuracy: 0.0171
# Epoch 53/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7123 - accuracy: 0.5146
# Epoch 53: loss did not improve from 0.71015
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7117 - accuracy: 0.5155 - val_loss: 391.7751 - val_accuracy: 0.0357
# Epoch 54/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.5042
# Epoch 54: loss did not improve from 0.71015
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5042 - val_loss: 117.1995 - val_accuracy: 0.0171
# Epoch 55/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5121
# Epoch 55: loss did not improve from 0.71015
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7110 - accuracy: 0.5103 - val_loss: 178.5301 - val_accuracy: 0.0357
# Epoch 56/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5112
# Epoch 56: loss did not improve from 0.71015
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5117 - val_loss: 106.8844 - val_accuracy: 0.0357
# Epoch 57/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.5040
# Epoch 57: loss did not improve from 0.71015
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7115 - accuracy: 0.5028 - val_loss: 117.5788 - val_accuracy: 0.0373
# Epoch 58/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5065
# Epoch 58: loss did not improve from 0.71015
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5077 - val_loss: 121.0377 - val_accuracy: 0.0357
# Epoch 59/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5241
# Epoch 59: loss improved from 0.71015 to 0.70926, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7093 - accuracy: 0.5246 - val_loss: 175.8303 - val_accuracy: 0.0357
# Epoch 60/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7107 - accuracy: 0.5043
# Epoch 60: loss did not improve from 0.70926
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7104 - accuracy: 0.5061 - val_loss: 212.2535 - val_accuracy: 0.0357
# Epoch 61/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5154
# Epoch 61: loss did not improve from 0.70926
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7100 - accuracy: 0.5148 - val_loss: 478.1392 - val_accuracy: 0.0357
# Epoch 62/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5097
# Epoch 62: loss did not improve from 0.70926
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7112 - accuracy: 0.5099 - val_loss: 537.2968 - val_accuracy: 0.0357
# Epoch 63/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5181
# Epoch 63: loss did not improve from 0.70926
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7094 - accuracy: 0.5172 - val_loss: 159.8251 - val_accuracy: 0.0357
# Epoch 64/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.5105
# Epoch 64: loss did not improve from 0.70926
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7096 - accuracy: 0.5115 - val_loss: 166.9483 - val_accuracy: 0.0450
# Epoch 65/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7090 - accuracy: 0.5160
# Epoch 65: loss improved from 0.70926 to 0.70871, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7087 - accuracy: 0.5170 - val_loss: 182.1236 - val_accuracy: 0.1553
# Epoch 66/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7116 - accuracy: 0.5118
# Epoch 66: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5123 - val_loss: 408.2043 - val_accuracy: 0.0171
# Epoch 67/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5194
# Epoch 67: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5187 - val_loss: 568.5436 - val_accuracy: 0.0357
# Epoch 68/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7100 - accuracy: 0.5054
# Epoch 68: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7111 - accuracy: 0.5063 - val_loss: 258.8786 - val_accuracy: 0.0357
# Epoch 69/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7100 - accuracy: 0.5139
# Epoch 69: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7098 - accuracy: 0.5139 - val_loss: 171.8099 - val_accuracy: 0.0357
# Epoch 70/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.5181
# Epoch 70: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7088 - accuracy: 0.5172 - val_loss: 125.8239 - val_accuracy: 0.0093
# Epoch 71/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5148
# Epoch 71: loss did not improve from 0.70871
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7090 - accuracy: 0.5148 - val_loss: 97.2159 - val_accuracy: 0.0357
# Epoch 72/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.5153
# Epoch 72: loss did not improve from 0.70871
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7088 - accuracy: 0.5153 - val_loss: 79.0671 - val_accuracy: 0.0435
# Epoch 73/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7093 - accuracy: 0.5033
# Epoch 73: loss did not improve from 0.70871
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7088 - accuracy: 0.5032 - val_loss: 180.5241 - val_accuracy: 0.0171
# Epoch 74/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5182
# Epoch 74: loss improved from 0.70871 to 0.70823, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7082 - accuracy: 0.5179 - val_loss: 129.2322 - val_accuracy: 0.0357
# Epoch 75/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5145
# Epoch 75: loss improved from 0.70823 to 0.70741, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7074 - accuracy: 0.5146 - val_loss: 72.0190 - val_accuracy: 0.1475
# Epoch 76/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5184
# Epoch 76: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7085 - accuracy: 0.5172 - val_loss: 179.8357 - val_accuracy: 0.0357
# Epoch 77/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5051
# Epoch 77: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7087 - accuracy: 0.5056 - val_loss: 437.1747 - val_accuracy: 0.0357
# Epoch 78/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5084
# Epoch 78: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7106 - accuracy: 0.5058 - val_loss: 404.8282 - val_accuracy: 0.0357
# Epoch 79/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.5117
# Epoch 79: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7087 - accuracy: 0.5117 - val_loss: 126.4467 - val_accuracy: 0.1273
# Epoch 80/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5111
# Epoch 80: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7083 - accuracy: 0.5108 - val_loss: 143.3837 - val_accuracy: 0.0357
# Epoch 81/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5214
# Epoch 81: loss did not improve from 0.70741
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7076 - accuracy: 0.5225 - val_loss: 140.6035 - val_accuracy: 0.0357
# Epoch 82/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7073 - accuracy: 0.5189
# Epoch 82: loss improved from 0.70741 to 0.70727, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7073 - accuracy: 0.5189 - val_loss: 119.7236 - val_accuracy: 0.0357
# Epoch 83/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.5170
# Epoch 83: loss did not improve from 0.70727
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7078 - accuracy: 0.5170 - val_loss: 197.7015 - val_accuracy: 0.0357
# Epoch 84/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5179
# Epoch 84: loss did not improve from 0.70727
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7075 - accuracy: 0.5180 - val_loss: 262.9406 - val_accuracy: 0.0171
# Epoch 85/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5173
# Epoch 85: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7075 - accuracy: 0.5186 - val_loss: 206.2395 - val_accuracy: 0.0171
# Epoch 86/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5107
# Epoch 86: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7083 - accuracy: 0.5098 - val_loss: 99.4030 - val_accuracy: 0.1320
# Epoch 87/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7085 - accuracy: 0.5109
# Epoch 87: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7073 - accuracy: 0.5110 - val_loss: 236.1726 - val_accuracy: 0.0357
# Epoch 88/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5192
# Epoch 88: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7074 - accuracy: 0.5205 - val_loss: 210.8303 - val_accuracy: 0.0357
# Epoch 89/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5156
# Epoch 89: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7086 - accuracy: 0.5149 - val_loss: 504.9413 - val_accuracy: 0.0155
# Epoch 90/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.5190
# Epoch 90: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7080 - accuracy: 0.5189 - val_loss: 463.8671 - val_accuracy: 0.0357
# Epoch 91/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5176
# Epoch 91: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7079 - accuracy: 0.5179 - val_loss: 189.0118 - val_accuracy: 0.0357
# Epoch 92/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5053
# Epoch 92: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7081 - accuracy: 0.5070 - val_loss: 305.3151 - val_accuracy: 0.0357
# Epoch 93/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7071 - accuracy: 0.5146
# Epoch 93: loss did not improve from 0.70727
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7077 - accuracy: 0.5134 - val_loss: 338.8871 - val_accuracy: 0.0404
# Epoch 94/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5154
# Epoch 94: loss did not improve from 0.70727
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7075 - accuracy: 0.5168 - val_loss: 179.2794 - val_accuracy: 0.0357
# Epoch 95/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5145
# Epoch 95: loss did not improve from 0.70727
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7073 - accuracy: 0.5146 - val_loss: 267.5874 - val_accuracy: 0.0357
# Epoch 96/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5081
# Epoch 96: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5104 - val_loss: 123.4793 - val_accuracy: 0.0481
# Epoch 97/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5152
# Epoch 97: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7078 - accuracy: 0.5160 - val_loss: 365.6519 - val_accuracy: 0.0155
# Epoch 98/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5106
# Epoch 98: loss did not improve from 0.70727
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7079 - accuracy: 0.5108 - val_loss: 100.5696 - val_accuracy: 0.1475
# Epoch 99/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5144
# Epoch 99: loss improved from 0.70727 to 0.70690, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7069 - accuracy: 0.5142 - val_loss: 204.9078 - val_accuracy: 0.0171
# Epoch 100/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7045 - accuracy: 0.5199
# Epoch 100: loss improved from 0.70690 to 0.70675, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7068 - accuracy: 0.5210 - val_loss: 276.8272 - val_accuracy: 0.0357
# Epoch 101/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5089
# Epoch 101: loss did not improve from 0.70675
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7081 - accuracy: 0.5079 - val_loss: 491.1682 - val_accuracy: 0.0357
# Epoch 102/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5200
# Epoch 102: loss improved from 0.70675 to 0.70658, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7066 - accuracy: 0.5191 - val_loss: 100.4879 - val_accuracy: 0.2034
# Epoch 103/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5092
# Epoch 103: loss did not improve from 0.70658
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7075 - accuracy: 0.5096 - val_loss: 219.8313 - val_accuracy: 0.0419
# Epoch 104/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.5117
# Epoch 104: loss did not improve from 0.70658
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7071 - accuracy: 0.5117 - val_loss: 104.1976 - val_accuracy: 0.1398
# Epoch 105/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.5156
# Epoch 105: loss did not improve from 0.70658
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7074 - accuracy: 0.5156 - val_loss: 99.2446 - val_accuracy: 0.1475
# Epoch 106/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5177
# Epoch 106: loss did not improve from 0.70658
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7070 - accuracy: 0.5153 - val_loss: 145.3620 - val_accuracy: 0.0512
# Epoch 107/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.5196
# Epoch 107: loss improved from 0.70658 to 0.70643, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7064 - accuracy: 0.5196 - val_loss: 171.4428 - val_accuracy: 0.0357
# Epoch 108/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.5218
# Epoch 108: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5218 - val_loss: 238.1198 - val_accuracy: 0.0481
# Epoch 109/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5232
# Epoch 109: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7069 - accuracy: 0.5234 - val_loss: 350.7929 - val_accuracy: 0.0357
# Epoch 110/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7072 - accuracy: 0.5135
# Epoch 110: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7081 - accuracy: 0.5134 - val_loss: 573.3726 - val_accuracy: 0.0357
# Epoch 111/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5167
# Epoch 111: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7086 - accuracy: 0.5165 - val_loss: 1174.5386 - val_accuracy: 0.0357
# Epoch 112/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5176
# Epoch 112: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7082 - accuracy: 0.5184 - val_loss: 374.8495 - val_accuracy: 0.1056
# Epoch 113/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5208
# Epoch 113: loss did not improve from 0.70643
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7068 - accuracy: 0.5184 - val_loss: 476.1418 - val_accuracy: 0.0357
# Epoch 114/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5162
# Epoch 114: loss did not improve from 0.70643
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7066 - accuracy: 0.5144 - val_loss: 555.9079 - val_accuracy: 0.0357
# Epoch 115/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.5177
# Epoch 115: loss improved from 0.70643 to 0.70610, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7061 - accuracy: 0.5177 - val_loss: 433.9168 - val_accuracy: 0.0357
# Epoch 116/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5076
# Epoch 116: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7072 - accuracy: 0.5084 - val_loss: 624.8342 - val_accuracy: 0.0357
# Epoch 117/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5159
# Epoch 117: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7068 - accuracy: 0.5167 - val_loss: 968.8151 - val_accuracy: 0.0357
# Epoch 118/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5190
# Epoch 118: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7074 - accuracy: 0.5177 - val_loss: 663.4532 - val_accuracy: 0.0357
# Epoch 119/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5192
# Epoch 119: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7070 - accuracy: 0.5184 - val_loss: 191.3407 - val_accuracy: 0.0357
# Epoch 120/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5205
# Epoch 120: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7063 - accuracy: 0.5206 - val_loss: 568.9675 - val_accuracy: 0.0357
# Epoch 121/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7079 - accuracy: 0.5142
# Epoch 121: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5127 - val_loss: 565.0283 - val_accuracy: 0.0357
# Epoch 122/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5213
# Epoch 122: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7064 - accuracy: 0.5210 - val_loss: 794.2980 - val_accuracy: 0.0357
# Epoch 123/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.5120
# Epoch 123: loss did not improve from 0.70610
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5120 - val_loss: 227.7203 - val_accuracy: 0.0357
# Epoch 124/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5212
# Epoch 124: loss did not improve from 0.70610
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7064 - accuracy: 0.5206 - val_loss: 71.0778 - val_accuracy: 0.2904
# Epoch 125/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5168
# Epoch 125: loss improved from 0.70610 to 0.70599, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 3s 18ms/step - loss: 0.7060 - accuracy: 0.5160 - val_loss: 357.2030 - val_accuracy: 0.0357
# Epoch 126/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5227
# Epoch 126: loss did not improve from 0.70599
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7075 - accuracy: 0.5229 - val_loss: 778.3118 - val_accuracy: 0.0357
# Epoch 127/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5170
# Epoch 127: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7095 - accuracy: 0.5177 - val_loss: 1312.8644 - val_accuracy: 0.0171
# Epoch 128/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.5229
# Epoch 128: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7065 - accuracy: 0.5229 - val_loss: 263.8075 - val_accuracy: 0.1118
# Epoch 129/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7072 - accuracy: 0.5052
# Epoch 129: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7064 - accuracy: 0.5080 - val_loss: 152.4825 - val_accuracy: 0.0342
# Epoch 130/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7063 - accuracy: 0.5191
# Epoch 130: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7063 - accuracy: 0.5191 - val_loss: 136.8096 - val_accuracy: 0.0481
# Epoch 131/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.5270
# Epoch 131: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7070 - accuracy: 0.5270 - val_loss: 139.6602 - val_accuracy: 0.0373
# Epoch 132/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5129
# Epoch 132: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5137 - val_loss: 151.0683 - val_accuracy: 0.0357
# Epoch 133/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5269
# Epoch 133: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7064 - accuracy: 0.5265 - val_loss: 101.1130 - val_accuracy: 0.0171
# Epoch 134/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.5175
# Epoch 134: loss did not improve from 0.70599
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7065 - accuracy: 0.5175 - val_loss: 194.1976 - val_accuracy: 0.0357
# Epoch 135/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5205
# Epoch 135: loss did not improve from 0.70599
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7060 - accuracy: 0.5213 - val_loss: 188.0808 - val_accuracy: 0.0373
# Epoch 136/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5222
# Epoch 136: loss did not improve from 0.70599
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7067 - accuracy: 0.5218 - val_loss: 306.9261 - val_accuracy: 0.0357
# Epoch 137/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5233
# Epoch 137: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5244 - val_loss: 859.4310 - val_accuracy: 0.0016
# Epoch 138/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.5168
# Epoch 138: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7077 - accuracy: 0.5160 - val_loss: 344.3091 - val_accuracy: 0.0357
# Epoch 139/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5237
# Epoch 139: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7065 - accuracy: 0.5232 - val_loss: 290.6209 - val_accuracy: 0.0357
# Epoch 140/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7054 - accuracy: 0.5126
# Epoch 140: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7063 - accuracy: 0.5139 - val_loss: 310.6155 - val_accuracy: 0.1056
# Epoch 141/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7178 - accuracy: 0.5147
# Epoch 141: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7176 - accuracy: 0.5158 - val_loss: 634.0779 - val_accuracy: 0.1071
# Epoch 142/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5144
# Epoch 142: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7075 - accuracy: 0.5153 - val_loss: 208.9192 - val_accuracy: 0.0357
# Epoch 143/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5199
# Epoch 143: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7063 - accuracy: 0.5203 - val_loss: 130.9500 - val_accuracy: 0.0357
# Epoch 144/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5194
# Epoch 144: loss did not improve from 0.70599
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7061 - accuracy: 0.5206 - val_loss: 158.1648 - val_accuracy: 0.0357
# Epoch 145/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5169
# Epoch 145: loss did not improve from 0.70599
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7062 - accuracy: 0.5172 - val_loss: 118.8235 - val_accuracy: 0.1460
# Epoch 146/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5237
# Epoch 146: loss improved from 0.70599 to 0.70558, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7056 - accuracy: 0.5239 - val_loss: 145.5379 - val_accuracy: 0.0357
# Epoch 147/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5173
# Epoch 147: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7065 - accuracy: 0.5170 - val_loss: 75.0012 - val_accuracy: 0.1413
# Epoch 148/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7057 - accuracy: 0.5225
# Epoch 148: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7057 - accuracy: 0.5225 - val_loss: 181.6051 - val_accuracy: 0.0357
# Epoch 149/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5234
# Epoch 149: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7061 - accuracy: 0.5206 - val_loss: 152.6006 - val_accuracy: 0.1134
# Epoch 150/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5172
# Epoch 150: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7056 - accuracy: 0.5177 - val_loss: 118.9214 - val_accuracy: 0.1506
# Epoch 151/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5293
# Epoch 151: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7059 - accuracy: 0.5291 - val_loss: 487.7308 - val_accuracy: 0.0357
# Epoch 152/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5198
# Epoch 152: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7061 - accuracy: 0.5199 - val_loss: 291.5031 - val_accuracy: 0.0357
# Epoch 153/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5181
# Epoch 153: loss did not improve from 0.70558
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7060 - accuracy: 0.5175 - val_loss: 222.5495 - val_accuracy: 0.0357
# Epoch 154/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5147
# Epoch 154: loss did not improve from 0.70558
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7057 - accuracy: 0.5163 - val_loss: 183.7881 - val_accuracy: 0.0186
# Epoch 155/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.5231
# Epoch 155: loss did not improve from 0.70558
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7065 - accuracy: 0.5231 - val_loss: 143.6262 - val_accuracy: 0.0031
# Epoch 156/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5201
# Epoch 156: loss did not improve from 0.70558
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7059 - accuracy: 0.5189 - val_loss: 359.1779 - val_accuracy: 0.1460
# Epoch 157/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5219
# Epoch 157: loss did not improve from 0.70558
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7062 - accuracy: 0.5215 - val_loss: 232.8690 - val_accuracy: 0.2500
# Epoch 158/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5178
# Epoch 158: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7060 - accuracy: 0.5186 - val_loss: 251.8636 - val_accuracy: 0.0357
# Epoch 159/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5129
# Epoch 159: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7058 - accuracy: 0.5129 - val_loss: 79.7572 - val_accuracy: 0.1227
# Epoch 160/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5170
# Epoch 160: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7060 - accuracy: 0.5155 - val_loss: 508.5710 - val_accuracy: 0.0357
# Epoch 161/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5172
# Epoch 161: loss did not improve from 0.70558
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7066 - accuracy: 0.5168 - val_loss: 556.0284 - val_accuracy: 0.0357
# Epoch 162/300
# ...
# Epoch 244/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.5224
# Epoch 244: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5224 - val_loss: 267.0185 - val_accuracy: 0.0373
# Epoch 245/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5128
# Epoch 245: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5141 - val_loss: 231.6459 - val_accuracy: 0.0357
# Epoch 246/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5253
# Epoch 246: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7052 - accuracy: 0.5250 - val_loss: 390.7319 - val_accuracy: 0.0357
# Epoch 247/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5294
# Epoch 247: loss did not improve from 0.70510
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7051 - accuracy: 0.5294 - val_loss: 121.4700 - val_accuracy: 0.0357
# Epoch 248/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.5229
# Epoch 248: loss did not improve from 0.70510
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7055 - accuracy: 0.5229 - val_loss: 373.1323 - val_accuracy: 0.0357
# Epoch 249/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5230
# Epoch 249: loss did not improve from 0.70510
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7051 - accuracy: 0.5227 - val_loss: 273.9603 - val_accuracy: 0.0357
# Epoch 250/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5206
# Epoch 250: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7058 - accuracy: 0.5196 - val_loss: 2856.8789 - val_accuracy: 0.0357
# Epoch 251/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5233
# Epoch 251: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7074 - accuracy: 0.5220 - val_loss: 2155.7009 - val_accuracy: 0.0357
# Epoch 252/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5256
# Epoch 252: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7058 - accuracy: 0.5256 - val_loss: 415.3080 - val_accuracy: 0.0373
# Epoch 253/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5147
# Epoch 253: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7055 - accuracy: 0.5155 - val_loss: 363.5410 - val_accuracy: 0.0404
# Epoch 254/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.5230
# Epoch 254: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7056 - accuracy: 0.5227 - val_loss: 502.1165 - val_accuracy: 0.0357
# Epoch 255/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5161
# Epoch 255: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5165 - val_loss: 184.4116 - val_accuracy: 0.0373
# Epoch 256/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5232
# Epoch 256: loss did not improve from 0.70510
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5237 - val_loss: 187.5066 - val_accuracy: 0.0419
# Epoch 257/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7042 - accuracy: 0.5256
# Epoch 257: loss did not improve from 0.70510
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7052 - accuracy: 0.5262 - val_loss: 385.5356 - val_accuracy: 0.0357
# Epoch 258/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5158
# Epoch 258: loss improved from 0.70510 to 0.70497, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7050 - accuracy: 0.5163 - val_loss: 397.9946 - val_accuracy: 0.0357
# Epoch 259/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.5206
# Epoch 259: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7055 - accuracy: 0.5206 - val_loss: 526.5503 - val_accuracy: 0.0373
# Epoch 260/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.5135
# Epoch 260: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5134 - val_loss: 558.0260 - val_accuracy: 0.0357
# Epoch 261/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5275
# Epoch 261: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5267 - val_loss: 592.0325 - val_accuracy: 0.0357
# Epoch 262/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7043 - accuracy: 0.5233
# Epoch 262: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7050 - accuracy: 0.5232 - val_loss: 384.7495 - val_accuracy: 0.0357
# Epoch 263/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5160
# Epoch 263: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7059 - accuracy: 0.5161 - val_loss: 1287.6058 - val_accuracy: 0.0357
# Epoch 264/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.5262
# Epoch 264: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5262 - val_loss: 553.3847 - val_accuracy: 0.0357
# Epoch 265/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.5234
# Epoch 265: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7086 - accuracy: 0.5234 - val_loss: 4252.7661 - val_accuracy: 0.0357
# Epoch 266/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5170
# Epoch 266: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7054 - accuracy: 0.5180 - val_loss: 1217.4268 - val_accuracy: 0.0357
# Epoch 267/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7059 - accuracy: 0.5244
# Epoch 267: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7059 - accuracy: 0.5244 - val_loss: 839.8250 - val_accuracy: 0.0357
# Epoch 268/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5113
# Epoch 268: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7056 - accuracy: 0.5110 - val_loss: 163.7215 - val_accuracy: 0.0450
# Epoch 269/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5252
# Epoch 269: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7050 - accuracy: 0.5258 - val_loss: 239.2649 - val_accuracy: 0.0388
# Epoch 270/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5233
# Epoch 270: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7053 - accuracy: 0.5215 - val_loss: 211.8138 - val_accuracy: 0.0357
# Epoch 271/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7041 - accuracy: 0.5245
# Epoch 271: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7054 - accuracy: 0.5239 - val_loss: 299.6596 - val_accuracy: 0.0357
# Epoch 272/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5183
# Epoch 272: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5186 - val_loss: 218.5927 - val_accuracy: 0.0528
# Epoch 273/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5206
# Epoch 273: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7054 - accuracy: 0.5212 - val_loss: 402.5367 - val_accuracy: 0.0357
# Epoch 274/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7060 - accuracy: 0.5226
# Epoch 274: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7055 - accuracy: 0.5231 - val_loss: 153.3016 - val_accuracy: 0.0280
# Epoch 275/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7054 - accuracy: 0.5189
# Epoch 275: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7054 - accuracy: 0.5189 - val_loss: 287.5699 - val_accuracy: 0.0093
# Epoch 276/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7049 - accuracy: 0.5183
# Epoch 276: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5186 - val_loss: 502.1090 - val_accuracy: 0.0357
# Epoch 277/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5248
# Epoch 277: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5255 - val_loss: 717.7234 - val_accuracy: 0.1118
# Epoch 278/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5245
# Epoch 278: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7051 - accuracy: 0.5246 - val_loss: 482.1911 - val_accuracy: 0.0357
# Epoch 279/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5242
# Epoch 279: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7062 - accuracy: 0.5236 - val_loss: 1135.2600 - val_accuracy: 0.0155
# Epoch 280/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5257
# Epoch 280: loss did not improve from 0.70497
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7060 - accuracy: 0.5253 - val_loss: 2128.4329 - val_accuracy: 0.0357
# Epoch 281/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5249
# Epoch 281: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7054 - accuracy: 0.5237 - val_loss: 803.3506 - val_accuracy: 0.0357
# Epoch 282/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5175
# Epoch 282: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5186 - val_loss: 572.5409 - val_accuracy: 0.0357
# Epoch 283/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7059 - accuracy: 0.5255
# Epoch 283: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5272 - val_loss: 453.6998 - val_accuracy: 0.0357
# Epoch 284/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7059 - accuracy: 0.5241
# Epoch 284: loss did not improve from 0.70497
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5243 - val_loss: 878.2106 - val_accuracy: 0.0357
# Epoch 285/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5149
# Epoch 285: loss improved from 0.70497 to 0.70496, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7050 - accuracy: 0.5149 - val_loss: 1186.0980 - val_accuracy: 0.0357
# Epoch 286/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5240
# Epoch 286: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7077 - accuracy: 0.5244 - val_loss: 3339.8936 - val_accuracy: 0.0357
# Epoch 287/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5202
# Epoch 287: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7059 - accuracy: 0.5198 - val_loss: 508.1691 - val_accuracy: 0.0357
# Epoch 288/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.5198
# Epoch 288: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7055 - accuracy: 0.5212 - val_loss: 928.7086 - val_accuracy: 0.0357
# Epoch 289/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5190
# Epoch 289: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7054 - accuracy: 0.5193 - val_loss: 484.5580 - val_accuracy: 0.0357
# Epoch 290/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5170
# Epoch 290: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7052 - accuracy: 0.5193 - val_loss: 686.5769 - val_accuracy: 0.0357
# Epoch 291/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5207
# Epoch 291: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7051 - accuracy: 0.5198 - val_loss: 240.3153 - val_accuracy: 0.1304
# Epoch 292/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5161
# Epoch 292: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5167 - val_loss: 241.2286 - val_accuracy: 0.1134
# Epoch 293/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5194
# Epoch 293: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5196 - val_loss: 394.3948 - val_accuracy: 0.0978
# Epoch 294/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5240
# Epoch 294: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5244 - val_loss: 473.2417 - val_accuracy: 0.0357
# Epoch 295/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5248
# Epoch 295: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7050 - accuracy: 0.5272 - val_loss: 549.6711 - val_accuracy: 0.0357
# Epoch 296/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5225
# Epoch 296: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5215 - val_loss: 909.0189 - val_accuracy: 0.0357
# Epoch 297/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.5210
# Epoch 297: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7082 - accuracy: 0.5210 - val_loss: 2801.5107 - val_accuracy: 0.0357
# Epoch 298/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.5233
# Epoch 298: loss did not improve from 0.70496
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7055 - accuracy: 0.5225 - val_loss: 803.8973 - val_accuracy: 0.0357
# Epoch 299/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5187
# Epoch 299: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7051 - accuracy: 0.5172 - val_loss: 268.6965 - val_accuracy: 0.0419
# Epoch 300/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.5217
# Epoch 300: loss did not improve from 0.70496
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7052 - accuracy: 0.5217 - val_loss: 316.9337 - val_accuracy: 0.0357

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/model6_7.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(1)
# Out:
# {'loss': [1.2950364351272583, 0.8205010294914246, 0.7804948687553406, 0.7601162791252136, 0.7508553266525269, 0.7447381615638733, 0.7355563044548035, 0.7322793006896973, 0.7331390976905823, 0.7242713570594788, 0.726020336151123, 0.7209402918815613, 0.7241812944412231, 0.7233171463012695, 0.7218419313430786, 0.721625566482544, 0.72193843126297, 0.7191669344902039, 0.7190560698509216, 0.7203429341316223, 0.7184249758720398, 0.7204611301422119, 0.7172457575798035, 0.7172398567199707, 0.7177561521530151, 0.7176377773284912, 0.7165104746818542, 0.7179416418075562, 0.7156478762626648, 0.7141976952552795, 0.7147333025932312, 0.7143962979316711, 0.7140446901321411, 0.7158315181732178, 0.7127857208251953, 0.715081512928009, 0.7126725912094116, 0.7130398750305176, 0.7145913243293762, 0.7129217386245728, 0.7130739092826843, 0.7129920721054077, 0.7113696336746216, 0.7126337885856628, 0.7116634845733643, 0.712190568447113, 0.7125121355056763, 0.7105047106742859, 0.7101666927337646, 0.7108407020568848, 0.7115380167961121, 0.7101510167121887, 0.7116569876670837, 0.7107391953468323, 0.7109706401824951, 0.7106544375419617, 0.7115343809127808, 0.7106965184211731, 0.7092607617378235, 0.7103825211524963, 0.7100157141685486, 0.711249053478241, 0.7094259262084961, 0.7096126079559326, 0.7087125182151794, 0.710729718208313, 0.7107093930244446, 0.7110538482666016, 0.709825873374939, 0.7088416218757629, 0.7090039253234863, 0.7088289856910706, 0.7088497877120972, 0.7082337141036987, 0.7074068188667297, 0.7085186839103699, 0.7086827158927917, 0.7106208205223083, 0.708662211894989, 0.7083206176757812, 0.707616925239563, 0.7072665095329285, 0.7077698707580566, 0.7075216174125671, 0.7074784636497498, 0.7082797288894653, 0.7072702646255493, 0.7074276208877563, 0.7085599303245544, 0.7080127000808716, 0.7079021334648132, 0.7080698013305664, 0.7077204585075378, 0.7075220346450806, 0.7072904706001282, 0.7075340151786804, 0.7078048586845398, 0.707929253578186, 0.7068960666656494, 0.7067530751228333, 0.7080525755882263, 0.7065792679786682, 0.7074867486953735, 0.7071067094802856, 0.7074457406997681, 0.7069839239120483, 0.7064287662506104, 0.7066903114318848, 0.70693439245224, 0.7081078290939331, 0.7085661888122559, 0.7082171440124512, 0.7068364024162292, 0.7066397070884705, 0.7061018347740173, 0.7071949243545532, 0.7067748308181763, 0.7073692083358765, 0.7070224285125732, 0.706283450126648, 0.7075475454330444, 0.706436038017273, 0.7074846029281616, 0.7064117193222046, 0.7059869766235352, 0.707526683807373, 0.7095381617546082, 0.7065163850784302, 0.7063555121421814, 0.7062845230102539, 0.707015335559845, 0.7067221999168396, 0.7064361572265625, 0.7064937949180603, 0.7060240507125854, 0.7067083716392517, 0.706670343875885, 0.7076913714408875, 0.7064753174781799, 0.7063050270080566, 0.7175946235656738, 0.7074784636497498, 0.7063296437263489, 0.7060781121253967, 0.7061719298362732, 0.7055769562721252, 0.706508457660675, 0.7056747674942017, 0.7060791850090027, 0.7056025862693787, 0.7058556079864502, 0.7061375379562378, 0.7060291767120361, 0.7057421803474426, 0.7064818739891052, 0.7058913707733154, 0.7061900496482849, 0.7060018181800842, 0.705841600894928, 0.7060075402259827, 0.7065889835357666, 0.706464946269989, 0.7061334252357483, 0.7061779499053955, 0.7060444355010986, 0.7062135338783264, 0.7065973877906799, 0.7059190273284912, 0.7056005001068115, 0.7086641192436218, 0.7071879506111145, 0.706555187702179, 0.70636385679245, 0.7056155204772949, 0.706244945526123, 0.705681562423706, 0.7058469653129578, 0.7060930728912354, 0.7056882977485657, 0.7056490182876587, 0.7056788206100464, 0.7055458426475525, 0.7058085799217224, 0.7057497501373291, 0.7064538598060608, 0.7100712060928345, 0.7080401182174683, 0.7061918377876282, 0.7058410048484802, 0.7060273885726929, 0.7058369517326355, 0.7056047916412354, 0.7061538100242615, 0.7062439918518066, 0.7057434916496277, 0.7078841328620911, 0.7065913081169128, 0.705767810344696, 0.7057332992553711, 0.7055824398994446, 0.7054322957992554 ...
# 41/41 [==============================] - 0s 3ms/step - loss: 316.9350 - accuracy: 0.0357
# 21/21 [==============================] - 0s 2ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561            8
# 1       441            8
# 2       729            8
# 3      6561            8
# 4      1369            8
# 5       121            8
# 6       729            8
# 7       441            8
# 8      7569            8
# 9      7569            8
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561            8
# 1                4.23               3       441            8
# 2                4.77               4       729            8

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_7/Model6_7_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           16
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.33                0.33         0.02
# 1  ...              4.67                0.00         0.00
# 2  ...              8.67                0.00         0.00
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.33            16.50              16.75
# 1                 4.67             4.67               4.67
# 2                 8.67             8.67               8.67
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.10              16      8464                2
# 1                4.67               4       400                0
# 2                8.67               8      1600                0
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/model6_6.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  dense_8 (Dense)             (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_10 (Dense)            (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  dense_9 (Dense)             (None, 128)                  32896     ['dense_8[0][0]']
#
#  dense_11 (Dense)            (None, 128)                  32896     ['dense_10[0][0]']
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['dense_9[0][0]',
#  )                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_13 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_14 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 308)                  0         ['concatenate_1[0][0]',
#  )                                                                   'dense_12[0][0]',
#                                                                      'dense_13[0][0]',
#                                                                      'dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 384)                  118656    ['concatenate_2[0][0]']
#
#  dense_16 (Dense)            (None, 128)                  49280     ['dense_15[0][0]']
#
#  dense_17 (Dense)            (None, 26)                   3354      ['dense_16[0][0]']
#
# ==================================================================================================
# Total params: 632014 (2.41 MB)
# Trainable params: 632014 (2.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_6/Model6_6results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           16
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           18  ...                0.33         0.02                16.33
# 1            4  ...                0.00         0.00                 4.67
# 2            8  ...                0.00         0.00                 8.67
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.50              16.75               17.10              16
# 1             4.67               4.67                4.67               4
# 2             8.67               8.67                8.67               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      8464                2           16
# 1       400                0            4
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
