# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=300,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/300
# 177/181 [============================>.] - ETA: 0s - loss: 2.6354 - accuracy: 0.1794
# Epoch 1: loss improved from inf to 2.63008, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - 7s 13ms/step - loss: 2.6301 - accuracy: 0.1818 - val_loss: 2.4178 - val_accuracy: 0.2158
# Epoch 2/300
# 181/181 [==============================] - ETA: 0s - loss: 2.3299 - accuracy: 0.2654
# Epoch 2: loss improved from 2.63008 to 2.32991, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 3s 14ms/step - loss: 2.3299 - accuracy: 0.2654 - val_loss: 2.1777 - val_accuracy: 0.2298
# Epoch 3/300
# 180/181 [============================>.] - ETA: 0s - loss: 2.0639 - accuracy: 0.3583
# Epoch 3: loss improved from 2.32991 to 2.06254, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 2.0625 - accuracy: 0.3587 - val_loss: 1.8662 - val_accuracy: 0.4270
# Epoch 4/300
# 177/181 [============================>.] - ETA: 0s - loss: 1.7654 - accuracy: 0.4190
# Epoch 4: loss improved from 2.06254 to 1.75889, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 1.7589 - accuracy: 0.4191 - val_loss: 1.5749 - val_accuracy: 0.4255
# Epoch 5/300
# 177/181 [============================>.] - ETA: 0s - loss: 1.4855 - accuracy: 0.4423
# Epoch 5: loss improved from 1.75889 to 1.48485, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 1.4848 - accuracy: 0.4422 - val_loss: 1.3416 - val_accuracy: 0.4425
# Epoch 6/300
# 179/181 [============================>.] - ETA: 0s - loss: 1.2894 - accuracy: 0.4518
# Epoch 6: loss improved from 1.48485 to 1.28751, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 1.2875 - accuracy: 0.4526 - val_loss: 1.1953 - val_accuracy: 0.4814
# Epoch 7/300
# 175/181 [============================>.] - ETA: 0s - loss: 1.1678 - accuracy: 0.4598
# Epoch 7: loss improved from 1.28751 to 1.16497, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 1.1650 - accuracy: 0.4581 - val_loss: 1.1287 - val_accuracy: 0.4565
# Epoch 8/300
# 175/181 [============================>.] - ETA: 0s - loss: 1.1034 - accuracy: 0.4614
# Epoch 8: loss improved from 1.16497 to 1.09720, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 1.0972 - accuracy: 0.4626 - val_loss: 1.0417 - val_accuracy: 0.4720
# Epoch 9/300
# 178/181 [============================>.] - ETA: 0s - loss: 1.0310 - accuracy: 0.4626
# Epoch 9: loss improved from 1.09720 to 1.03021, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 1.0302 - accuracy: 0.4638 - val_loss: 1.0128 - val_accuracy: 0.4643
# Epoch 10/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.9997 - accuracy: 0.4759
# Epoch 10: loss improved from 1.03021 to 0.99976, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.9998 - accuracy: 0.4757 - val_loss: 0.9868 - val_accuracy: 0.4798
# Epoch 11/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.9646 - accuracy: 0.4874
# Epoch 11: loss improved from 0.99976 to 0.96648, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.9665 - accuracy: 0.4866 - val_loss: 0.9644 - val_accuracy: 0.4783
# Epoch 12/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.9366 - accuracy: 0.4921
# Epoch 12: loss improved from 0.96648 to 0.93898, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.9390 - accuracy: 0.4928 - val_loss: 0.9457 - val_accuracy: 0.4922
# Epoch 13/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.9198 - accuracy: 0.4869
# Epoch 13: loss improved from 0.93898 to 0.92017, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.9202 - accuracy: 0.4877 - val_loss: 0.9184 - val_accuracy: 0.4845
# Epoch 14/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.9096 - accuracy: 0.5049
# Epoch 14: loss improved from 0.92017 to 0.90755, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.9075 - accuracy: 0.5032 - val_loss: 0.9160 - val_accuracy: 0.4953
# Epoch 15/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.8937 - accuracy: 0.4984
# Epoch 15: loss improved from 0.90755 to 0.89363, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.8936 - accuracy: 0.4978 - val_loss: 0.9043 - val_accuracy: 0.4783
# Epoch 16/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.8754 - accuracy: 0.4977
# Epoch 16: loss improved from 0.89363 to 0.87780, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.8778 - accuracy: 0.4977 - val_loss: 0.8949 - val_accuracy: 0.4984
# Epoch 17/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.8746 - accuracy: 0.4903
# Epoch 17: loss improved from 0.87780 to 0.87388, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.8739 - accuracy: 0.4916 - val_loss: 0.8902 - val_accuracy: 0.5016
# Epoch 18/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.8621 - accuracy: 0.4977
# Epoch 18: loss improved from 0.87388 to 0.86164, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.8616 - accuracy: 0.4975 - val_loss: 0.8803 - val_accuracy: 0.4829
# Epoch 19/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.8538 - accuracy: 0.4889
# Epoch 19: loss improved from 0.86164 to 0.85558, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.8556 - accuracy: 0.4890 - val_loss: 0.8780 - val_accuracy: 0.4907
# Epoch 20/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.5000
# Epoch 20: loss improved from 0.85558 to 0.84596, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8460 - accuracy: 0.4997 - val_loss: 0.8630 - val_accuracy: 0.4752
# Epoch 21/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.8415 - accuracy: 0.5057
# Epoch 21: loss improved from 0.84596 to 0.84215, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.8421 - accuracy: 0.5053 - val_loss: 0.8587 - val_accuracy: 0.4720
# Epoch 22/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.8300 - accuracy: 0.5048
# Epoch 22: loss improved from 0.84215 to 0.83042, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 3s 14ms/step - loss: 0.8304 - accuracy: 0.5032 - val_loss: 0.8565 - val_accuracy: 0.4674
# Epoch 23/300
# 181/181 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.4954
# Epoch 23: loss improved from 0.83042 to 0.82922, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.8292 - accuracy: 0.4954 - val_loss: 0.8443 - val_accuracy: 0.5016
# Epoch 24/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.8207 - accuracy: 0.5030
# Epoch 24: loss improved from 0.82922 to 0.82088, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.8209 - accuracy: 0.5030 - val_loss: 0.8484 - val_accuracy: 0.4984
# Epoch 25/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.8201 - accuracy: 0.4894
# Epoch 25: loss improved from 0.82088 to 0.81958, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8196 - accuracy: 0.4890 - val_loss: 0.8407 - val_accuracy: 0.4814
# Epoch 26/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.8142 - accuracy: 0.5046
# Epoch 26: loss improved from 0.81958 to 0.81202, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8120 - accuracy: 0.5046 - val_loss: 0.8389 - val_accuracy: 0.4876
# Epoch 27/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.8143 - accuracy: 0.5024
# Epoch 27: loss did not improve from 0.81202
# 181/181 [==============================] - 3s 16ms/step - loss: 0.8141 - accuracy: 0.5020 - val_loss: 0.8282 - val_accuracy: 0.5016
# Epoch 28/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.8069 - accuracy: 0.5054
# Epoch 28: loss improved from 0.81202 to 0.80692, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8069 - accuracy: 0.5056 - val_loss: 0.8261 - val_accuracy: 0.5031
# Epoch 29/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.8036 - accuracy: 0.5075
# Epoch 29: loss improved from 0.80692 to 0.80437, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.8044 - accuracy: 0.5070 - val_loss: 0.8201 - val_accuracy: 0.4845
# Epoch 30/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.8010 - accuracy: 0.5043
# Epoch 30: loss improved from 0.80437 to 0.80009, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.8001 - accuracy: 0.5060 - val_loss: 0.8332 - val_accuracy: 0.4876
# Epoch 31/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.8003 - accuracy: 0.5118
# Epoch 31: loss improved from 0.80009 to 0.79966, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7997 - accuracy: 0.5108 - val_loss: 0.8124 - val_accuracy: 0.4922
# Epoch 32/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7953 - accuracy: 0.5035
# Epoch 32: loss improved from 0.79966 to 0.79447, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7945 - accuracy: 0.5041 - val_loss: 0.8296 - val_accuracy: 0.4752
# Epoch 33/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7948 - accuracy: 0.4890
# Epoch 33: loss did not improve from 0.79447
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7948 - accuracy: 0.4890 - val_loss: 0.8190 - val_accuracy: 0.4752
# Epoch 34/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7914 - accuracy: 0.5057
# Epoch 34: loss improved from 0.79447 to 0.79187, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7919 - accuracy: 0.5070 - val_loss: 0.8152 - val_accuracy: 0.4922
# Epoch 35/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7919 - accuracy: 0.5070
# Epoch 35: loss did not improve from 0.79187
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7919 - accuracy: 0.5079 - val_loss: 0.8291 - val_accuracy: 0.4783
# Epoch 36/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7869 - accuracy: 0.4991
# Epoch 36: loss improved from 0.79187 to 0.78687, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 3s 14ms/step - loss: 0.7869 - accuracy: 0.4991 - val_loss: 0.8045 - val_accuracy: 0.4984
# Epoch 37/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7821 - accuracy: 0.5081
# Epoch 37: loss improved from 0.78687 to 0.78216, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7822 - accuracy: 0.5075 - val_loss: 0.8100 - val_accuracy: 0.4891
# Epoch 38/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7844 - accuracy: 0.5085
# Epoch 38: loss did not improve from 0.78216
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7844 - accuracy: 0.5082 - val_loss: 0.7991 - val_accuracy: 0.4891
# Epoch 39/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7815 - accuracy: 0.5000
# Epoch 39: loss did not improve from 0.78216
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7825 - accuracy: 0.4992 - val_loss: 0.8063 - val_accuracy: 0.4907
# Epoch 40/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7783 - accuracy: 0.5067
# Epoch 40: loss improved from 0.78216 to 0.77892, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7789 - accuracy: 0.5060 - val_loss: 0.7955 - val_accuracy: 0.4767
# Epoch 41/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7764 - accuracy: 0.5109
# Epoch 41: loss did not improve from 0.77892
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7791 - accuracy: 0.5099 - val_loss: 0.7953 - val_accuracy: 0.4705
# Epoch 42/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7769 - accuracy: 0.5027
# Epoch 42: loss improved from 0.77892 to 0.77692, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7769 - accuracy: 0.5008 - val_loss: 0.7901 - val_accuracy: 0.5031
# Epoch 43/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7755 - accuracy: 0.5163
# Epoch 43: loss improved from 0.77692 to 0.77525, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7752 - accuracy: 0.5167 - val_loss: 0.8004 - val_accuracy: 0.5016
# Epoch 44/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7761 - accuracy: 0.5122
# Epoch 44: loss did not improve from 0.77525
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7765 - accuracy: 0.5120 - val_loss: 0.7970 - val_accuracy: 0.4783
# Epoch 45/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7733 - accuracy: 0.5082
# Epoch 45: loss improved from 0.77525 to 0.77334, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7733 - accuracy: 0.5082 - val_loss: 0.7952 - val_accuracy: 0.4798
# Epoch 46/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7684 - accuracy: 0.5085
# Epoch 46: loss improved from 0.77334 to 0.76982, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7698 - accuracy: 0.5080 - val_loss: 0.7873 - val_accuracy: 0.5062
# Epoch 47/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7707 - accuracy: 0.5094
# Epoch 47: loss did not improve from 0.76982
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7710 - accuracy: 0.5101 - val_loss: 0.7929 - val_accuracy: 0.4752
# Epoch 48/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7667 - accuracy: 0.5089
# Epoch 48: loss improved from 0.76982 to 0.76692, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7669 - accuracy: 0.5089 - val_loss: 0.7882 - val_accuracy: 0.5093
# Epoch 49/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7665 - accuracy: 0.5047
# Epoch 49: loss improved from 0.76692 to 0.76653, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7665 - accuracy: 0.5047 - val_loss: 0.7904 - val_accuracy: 0.4860
# Epoch 50/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7659 - accuracy: 0.5079
# Epoch 50: loss improved from 0.76653 to 0.76651, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7665 - accuracy: 0.5075 - val_loss: 0.7800 - val_accuracy: 0.5078
# Epoch 51/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7653 - accuracy: 0.5049
# Epoch 51: loss improved from 0.76651 to 0.76572, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7657 - accuracy: 0.5060 - val_loss: 0.7855 - val_accuracy: 0.4814
# Epoch 52/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7627 - accuracy: 0.5063
# Epoch 52: loss improved from 0.76572 to 0.76371, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7637 - accuracy: 0.5046 - val_loss: 0.7871 - val_accuracy: 0.4845
# Epoch 53/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7636 - accuracy: 0.4982
# Epoch 53: loss did not improve from 0.76371
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7653 - accuracy: 0.4999 - val_loss: 0.7815 - val_accuracy: 0.4736
# Epoch 54/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7622 - accuracy: 0.5163
# Epoch 54: loss improved from 0.76371 to 0.76112, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7611 - accuracy: 0.5170 - val_loss: 0.7880 - val_accuracy: 0.4891
# Epoch 55/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7590 - accuracy: 0.5115
# Epoch 55: loss improved from 0.76112 to 0.75895, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7590 - accuracy: 0.5115 - val_loss: 0.7904 - val_accuracy: 0.4643
# Epoch 56/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7605 - accuracy: 0.5085
# Epoch 56: loss did not improve from 0.75895
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7605 - accuracy: 0.5085 - val_loss: 0.7753 - val_accuracy: 0.5186
# Epoch 57/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7611 - accuracy: 0.4937
# Epoch 57: loss did not improve from 0.75895
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7608 - accuracy: 0.4940 - val_loss: 0.7711 - val_accuracy: 0.5109
# Epoch 58/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7594 - accuracy: 0.5046
# Epoch 58: loss did not improve from 0.75895
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7594 - accuracy: 0.5046 - val_loss: 0.7794 - val_accuracy: 0.4752
# Epoch 59/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7562 - accuracy: 0.5071
# Epoch 59: loss improved from 0.75895 to 0.75595, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7559 - accuracy: 0.5061 - val_loss: 0.7874 - val_accuracy: 0.4720
# Epoch 60/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7595 - accuracy: 0.5081
# Epoch 60: loss did not improve from 0.75595
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7608 - accuracy: 0.5068 - val_loss: 0.7803 - val_accuracy: 0.4720
# Epoch 61/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7534 - accuracy: 0.5057
# Epoch 61: loss improved from 0.75595 to 0.75432, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7543 - accuracy: 0.5037 - val_loss: 0.7696 - val_accuracy: 0.4876
# Epoch 62/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7584 - accuracy: 0.5035
# Epoch 62: loss did not improve from 0.75432
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7556 - accuracy: 0.5053 - val_loss: 0.7869 - val_accuracy: 0.4845
# Epoch 63/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7546 - accuracy: 0.5043
# Epoch 63: loss did not improve from 0.75432
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7546 - accuracy: 0.5028 - val_loss: 0.7657 - val_accuracy: 0.5031
# Epoch 64/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7533 - accuracy: 0.4979
# Epoch 64: loss improved from 0.75432 to 0.75221, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7522 - accuracy: 0.4987 - val_loss: 0.7675 - val_accuracy: 0.4705
# Epoch 65/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7519 - accuracy: 0.5094
# Epoch 65: loss improved from 0.75221 to 0.75175, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7518 - accuracy: 0.5096 - val_loss: 0.7703 - val_accuracy: 0.4736
# Epoch 66/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7521 - accuracy: 0.5050
# Epoch 66: loss improved from 0.75175 to 0.75159, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7516 - accuracy: 0.5044 - val_loss: 0.7638 - val_accuracy: 0.4891
# Epoch 67/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7508 - accuracy: 0.5075
# Epoch 67: loss improved from 0.75159 to 0.75078, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7508 - accuracy: 0.5077 - val_loss: 0.7736 - val_accuracy: 0.4783
# Epoch 68/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7476 - accuracy: 0.5018
# Epoch 68: loss improved from 0.75078 to 0.74718, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7472 - accuracy: 0.5041 - val_loss: 0.7759 - val_accuracy: 0.4845
# Epoch 69/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7499 - accuracy: 0.5072
# Epoch 69: loss did not improve from 0.74718
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7508 - accuracy: 0.5058 - val_loss: 0.7832 - val_accuracy: 0.4736
# Epoch 70/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7496 - accuracy: 0.5181
# Epoch 70: loss did not improve from 0.74718
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7494 - accuracy: 0.5184 - val_loss: 0.7849 - val_accuracy: 0.5000
# Epoch 71/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7520 - accuracy: 0.5157
# Epoch 71: loss did not improve from 0.74718
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7504 - accuracy: 0.5146 - val_loss: 0.7665 - val_accuracy: 0.4969
# Epoch 72/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7460 - accuracy: 0.5099
# Epoch 72: loss did not improve from 0.74718
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7476 - accuracy: 0.5104 - val_loss: 0.7707 - val_accuracy: 0.4783
# Epoch 73/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7459 - accuracy: 0.5090
# Epoch 73: loss improved from 0.74718 to 0.74683, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7468 - accuracy: 0.5085 - val_loss: 0.7599 - val_accuracy: 0.4984
# Epoch 74/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7442 - accuracy: 0.5078
# Epoch 74: loss improved from 0.74683 to 0.74453, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7445 - accuracy: 0.5075 - val_loss: 0.7632 - val_accuracy: 0.4845
# Epoch 75/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7470 - accuracy: 0.5052
# Epoch 75: loss did not improve from 0.74453
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7456 - accuracy: 0.5079 - val_loss: 0.7733 - val_accuracy: 0.5016
# Epoch 76/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7441 - accuracy: 0.5144
# Epoch 76: loss did not improve from 0.74453
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7453 - accuracy: 0.5149 - val_loss: 0.7683 - val_accuracy: 0.4984
# Epoch 77/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7438 - accuracy: 0.5072
# Epoch 77: loss improved from 0.74453 to 0.74362, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7436 - accuracy: 0.5063 - val_loss: 0.7586 - val_accuracy: 0.4845
# Epoch 78/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7427 - accuracy: 0.5180
# Epoch 78: loss improved from 0.74362 to 0.74263, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7426 - accuracy: 0.5182 - val_loss: 0.7605 - val_accuracy: 0.5171
# Epoch 79/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7431 - accuracy: 0.5083
# Epoch 79: loss did not improve from 0.74263
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7430 - accuracy: 0.5079 - val_loss: 0.7578 - val_accuracy: 0.5109
# Epoch 80/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7401 - accuracy: 0.5176
# Epoch 80: loss improved from 0.74263 to 0.74039, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7404 - accuracy: 0.5184 - val_loss: 0.7679 - val_accuracy: 0.5202
# Epoch 81/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7387 - accuracy: 0.5062
# Epoch 81: loss did not improve from 0.74039
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7417 - accuracy: 0.5044 - val_loss: 0.7562 - val_accuracy: 0.4938
# Epoch 82/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7426 - accuracy: 0.5099
# Epoch 82: loss did not improve from 0.74039
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7426 - accuracy: 0.5091 - val_loss: 0.7604 - val_accuracy: 0.4829
# Epoch 83/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7409 - accuracy: 0.5044
# Epoch 83: loss improved from 0.74039 to 0.73994, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7399 - accuracy: 0.5053 - val_loss: 0.7524 - val_accuracy: 0.5078
# Epoch 84/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7392 - accuracy: 0.5065
# Epoch 84: loss did not improve from 0.73994
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7402 - accuracy: 0.5061 - val_loss: 0.7593 - val_accuracy: 0.5031
# Epoch 85/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7401 - accuracy: 0.5075
# Epoch 85: loss improved from 0.73994 to 0.73940, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7394 - accuracy: 0.5073 - val_loss: 0.7519 - val_accuracy: 0.5155
# Epoch 86/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7396 - accuracy: 0.5162
# Epoch 86: loss improved from 0.73940 to 0.73912, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7391 - accuracy: 0.5168 - val_loss: 0.7600 - val_accuracy: 0.4938
# Epoch 87/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7404 - accuracy: 0.5083
# Epoch 87: loss improved from 0.73912 to 0.73897, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7390 - accuracy: 0.5085 - val_loss: 0.7550 - val_accuracy: 0.5047
# Epoch 88/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7387 - accuracy: 0.5126
# Epoch 88: loss did not improve from 0.73897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7394 - accuracy: 0.5108 - val_loss: 0.7636 - val_accuracy: 0.4891
# Epoch 89/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7383 - accuracy: 0.5131
# Epoch 89: loss improved from 0.73897 to 0.73783, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7378 - accuracy: 0.5136 - val_loss: 0.7542 - val_accuracy: 0.4891
# Epoch 90/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7366 - accuracy: 0.5120
# Epoch 90: loss improved from 0.73783 to 0.73661, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7366 - accuracy: 0.5120 - val_loss: 0.7440 - val_accuracy: 0.5311
# Epoch 91/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7392 - accuracy: 0.5130
# Epoch 91: loss did not improve from 0.73661
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7383 - accuracy: 0.5144 - val_loss: 0.7568 - val_accuracy: 0.4829
# Epoch 92/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7361 - accuracy: 0.5008
# Epoch 92: loss improved from 0.73661 to 0.73609, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7361 - accuracy: 0.5008 - val_loss: 0.7484 - val_accuracy: 0.5000
# Epoch 93/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7355 - accuracy: 0.5084
# Epoch 93: loss improved from 0.73609 to 0.73593, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7359 - accuracy: 0.5084 - val_loss: 0.7452 - val_accuracy: 0.5202
# Epoch 94/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.5103
# Epoch 94: loss improved from 0.73593 to 0.73503, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7350 - accuracy: 0.5103 - val_loss: 0.7823 - val_accuracy: 0.4953
# Epoch 95/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7375 - accuracy: 0.5130
# Epoch 95: loss did not improve from 0.73503
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7375 - accuracy: 0.5130 - val_loss: 0.7532 - val_accuracy: 0.4938
# Epoch 96/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7354 - accuracy: 0.5168
# Epoch 96: loss did not improve from 0.73503
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7354 - accuracy: 0.5174 - val_loss: 0.7508 - val_accuracy: 0.4969
# Epoch 97/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7347 - accuracy: 0.5075
# Epoch 97: loss improved from 0.73503 to 0.73455, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7346 - accuracy: 0.5075 - val_loss: 0.7461 - val_accuracy: 0.5217
# Epoch 98/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7342 - accuracy: 0.5026
# Epoch 98: loss did not improve from 0.73455
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7347 - accuracy: 0.5023 - val_loss: 0.7609 - val_accuracy: 0.4736
# Epoch 99/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7362 - accuracy: 0.5027
# Epoch 99: loss did not improve from 0.73455
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7369 - accuracy: 0.5022 - val_loss: 0.7542 - val_accuracy: 0.5000
# Epoch 100/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7335 - accuracy: 0.5103
# Epoch 100: loss improved from 0.73455 to 0.73302, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7330 - accuracy: 0.5101 - val_loss: 0.7522 - val_accuracy: 0.5016
# Epoch 101/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7341 - accuracy: 0.5109
# Epoch 101: loss did not improve from 0.73302
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7343 - accuracy: 0.5098 - val_loss: 0.7625 - val_accuracy: 0.4891
# Epoch 102/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7320 - accuracy: 0.5184
# Epoch 102: loss improved from 0.73302 to 0.73244, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7324 - accuracy: 0.5180 - val_loss: 0.7635 - val_accuracy: 0.4798
# Epoch 103/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7326 - accuracy: 0.5100
# Epoch 103: loss did not improve from 0.73244
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7334 - accuracy: 0.5111 - val_loss: 0.7603 - val_accuracy: 0.4938
# Epoch 104/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7301 - accuracy: 0.5075
# Epoch 104: loss improved from 0.73244 to 0.73129, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7313 - accuracy: 0.5056 - val_loss: 0.7472 - val_accuracy: 0.5000
# Epoch 105/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7297 - accuracy: 0.5158
# Epoch 105: loss improved from 0.73129 to 0.72984, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7298 - accuracy: 0.5142 - val_loss: 0.7479 - val_accuracy: 0.5248
# Epoch 106/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7297 - accuracy: 0.5114
# Epoch 106: loss did not improve from 0.72984
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7313 - accuracy: 0.5129 - val_loss: 0.7496 - val_accuracy: 0.5062
# Epoch 107/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7303 - accuracy: 0.5277
# Epoch 107: loss did not improve from 0.72984
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7307 - accuracy: 0.5263 - val_loss: 0.7428 - val_accuracy: 0.5217
# Epoch 108/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7324 - accuracy: 0.5128
# Epoch 108: loss did not improve from 0.72984
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7319 - accuracy: 0.5137 - val_loss: 0.7546 - val_accuracy: 0.4953
# Epoch 109/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7290 - accuracy: 0.5185
# Epoch 109: loss improved from 0.72984 to 0.72931, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7293 - accuracy: 0.5194 - val_loss: 0.7454 - val_accuracy: 0.5031
# Epoch 110/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5207
# Epoch 110: loss improved from 0.72931 to 0.72814, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7281 - accuracy: 0.5212 - val_loss: 0.7411 - val_accuracy: 0.5280
# Epoch 111/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7303 - accuracy: 0.5078
# Epoch 111: loss did not improve from 0.72814
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7291 - accuracy: 0.5079 - val_loss: 0.7483 - val_accuracy: 0.4984
# Epoch 112/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7305 - accuracy: 0.5119
# Epoch 112: loss did not improve from 0.72814
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7304 - accuracy: 0.5104 - val_loss: 0.7425 - val_accuracy: 0.5093
# Epoch 113/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7294 - accuracy: 0.5073
# Epoch 113: loss did not improve from 0.72814
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7294 - accuracy: 0.5073 - val_loss: 0.7433 - val_accuracy: 0.5047
# Epoch 114/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.5059
# Epoch 114: loss did not improve from 0.72814
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7300 - accuracy: 0.5061 - val_loss: 0.7597 - val_accuracy: 0.4876
# Epoch 115/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5099
# Epoch 115: loss improved from 0.72814 to 0.72714, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7271 - accuracy: 0.5117 - val_loss: 0.7423 - val_accuracy: 0.5062
# Epoch 116/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7292 - accuracy: 0.5075
# Epoch 116: loss did not improve from 0.72714
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7294 - accuracy: 0.5079 - val_loss: 0.7411 - val_accuracy: 0.4984
# Epoch 117/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7291 - accuracy: 0.5146
# Epoch 117: loss did not improve from 0.72714
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7284 - accuracy: 0.5142 - val_loss: 0.7395 - val_accuracy: 0.5140
# Epoch 118/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7264 - accuracy: 0.5153
# Epoch 118: loss improved from 0.72714 to 0.72688, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7269 - accuracy: 0.5167 - val_loss: 0.7536 - val_accuracy: 0.4953
# Epoch 119/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7276 - accuracy: 0.5155
# Epoch 119: loss improved from 0.72688 to 0.72635, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7263 - accuracy: 0.5172 - val_loss: 0.7484 - val_accuracy: 0.4922
# Epoch 120/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.5062
# Epoch 120: loss improved from 0.72635 to 0.72626, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7263 - accuracy: 0.5068 - val_loss: 0.7382 - val_accuracy: 0.5280
# Epoch 121/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5023
# Epoch 121: loss did not improve from 0.72626
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7270 - accuracy: 0.5037 - val_loss: 0.7527 - val_accuracy: 0.5078
# Epoch 122/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7242 - accuracy: 0.5203
# Epoch 122: loss improved from 0.72626 to 0.72417, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7242 - accuracy: 0.5203 - val_loss: 0.7445 - val_accuracy: 0.4783
# Epoch 123/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.4988
# Epoch 123: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7269 - accuracy: 0.4978 - val_loss: 0.7505 - val_accuracy: 0.4845
# Epoch 124/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7271 - accuracy: 0.5129
# Epoch 124: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7267 - accuracy: 0.5129 - val_loss: 0.7393 - val_accuracy: 0.5062
# Epoch 125/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.5084
# Epoch 125: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7269 - accuracy: 0.5084 - val_loss: 0.7462 - val_accuracy: 0.4984
# Epoch 126/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7272 - accuracy: 0.5135
# Epoch 126: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7264 - accuracy: 0.5122 - val_loss: 0.7386 - val_accuracy: 0.5264
# Epoch 127/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7248 - accuracy: 0.5149
# Epoch 127: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7248 - accuracy: 0.5149 - val_loss: 0.7463 - val_accuracy: 0.5078
# Epoch 128/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7273 - accuracy: 0.5104
# Epoch 128: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7268 - accuracy: 0.5096 - val_loss: 0.7344 - val_accuracy: 0.5062
# Epoch 129/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7251 - accuracy: 0.5172
# Epoch 129: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7256 - accuracy: 0.5163 - val_loss: 0.7400 - val_accuracy: 0.5031
# Epoch 130/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7261 - accuracy: 0.5044
# Epoch 130: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7258 - accuracy: 0.5035 - val_loss: 0.7388 - val_accuracy: 0.5016
# Epoch 131/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7251 - accuracy: 0.5108
# Epoch 131: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7253 - accuracy: 0.5113 - val_loss: 0.7405 - val_accuracy: 0.4938
# Epoch 132/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7253 - accuracy: 0.5082
# Epoch 132: loss did not improve from 0.72417
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7259 - accuracy: 0.5084 - val_loss: 0.7341 - val_accuracy: 0.5326
# Epoch 133/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7225 - accuracy: 0.5220
# Epoch 133: loss improved from 0.72417 to 0.72231, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.7223 - accuracy: 0.5227 - val_loss: 0.7399 - val_accuracy: 0.5000
# Epoch 134/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7242 - accuracy: 0.5163
# Epoch 134: loss did not improve from 0.72231
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7239 - accuracy: 0.5165 - val_loss: 0.7353 - val_accuracy: 0.4891
# Epoch 135/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7219 - accuracy: 0.5234
# Epoch 135: loss did not improve from 0.72231
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7227 - accuracy: 0.5237 - val_loss: 0.7423 - val_accuracy: 0.4783
# Epoch 136/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7249 - accuracy: 0.5058
# Epoch 136: loss did not improve from 0.72231
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7249 - accuracy: 0.5058 - val_loss: 0.7374 - val_accuracy: 0.5078
# Epoch 137/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7250 - accuracy: 0.5014
# Epoch 137: loss did not improve from 0.72231
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7248 - accuracy: 0.5006 - val_loss: 0.7357 - val_accuracy: 0.5202
# Epoch 138/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7197 - accuracy: 0.5127
# Epoch 138: loss improved from 0.72231 to 0.72175, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7218 - accuracy: 0.5110 - val_loss: 0.7399 - val_accuracy: 0.4938
# Epoch 139/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7233 - accuracy: 0.5153
# Epoch 139: loss did not improve from 0.72175
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7233 - accuracy: 0.5153 - val_loss: 0.7368 - val_accuracy: 0.5093
# Epoch 140/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7217 - accuracy: 0.5061
# Epoch 140: loss improved from 0.72175 to 0.72153, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7215 - accuracy: 0.5077 - val_loss: 0.7477 - val_accuracy: 0.4953
# Epoch 141/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7239 - accuracy: 0.5107
# Epoch 141: loss did not improve from 0.72153
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7233 - accuracy: 0.5110 - val_loss: 0.7360 - val_accuracy: 0.5217
# Epoch 142/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7236 - accuracy: 0.5116
# Epoch 142: loss did not improve from 0.72153
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7230 - accuracy: 0.5122 - val_loss: 0.7369 - val_accuracy: 0.4767
# Epoch 143/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7215 - accuracy: 0.5173
# Epoch 143: loss improved from 0.72153 to 0.72106, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7211 - accuracy: 0.5174 - val_loss: 0.7357 - val_accuracy: 0.5171
# Epoch 144/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7229 - accuracy: 0.5114
# Epoch 144: loss did not improve from 0.72106
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7223 - accuracy: 0.5118 - val_loss: 0.7345 - val_accuracy: 0.5078
# Epoch 145/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7222 - accuracy: 0.5075
# Epoch 145: loss did not improve from 0.72106
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7222 - accuracy: 0.5075 - val_loss: 0.7426 - val_accuracy: 0.5280
# Epoch 146/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7245 - accuracy: 0.5215
# Epoch 146: loss did not improve from 0.72106
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7230 - accuracy: 0.5236 - val_loss: 0.7452 - val_accuracy: 0.4953
# Epoch 147/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7214 - accuracy: 0.5127
# Epoch 147: loss did not improve from 0.72106
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7211 - accuracy: 0.5129 - val_loss: 0.7444 - val_accuracy: 0.5000
# Epoch 148/300
# ...
# Epoch 247/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7146 - accuracy: 0.5081
# Epoch 247: loss did not improve from 0.71187
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7138 - accuracy: 0.5072 - val_loss: 0.7265 - val_accuracy: 0.4907
# Epoch 248/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.5021
# Epoch 248: loss did not improve from 0.71187
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7122 - accuracy: 0.5034 - val_loss: 0.7267 - val_accuracy: 0.5248
# Epoch 249/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.5082
# Epoch 249: loss did not improve from 0.71187
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7120 - accuracy: 0.5080 - val_loss: 0.7230 - val_accuracy: 0.5202
# Epoch 250/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7117 - accuracy: 0.5098
# Epoch 250: loss improved from 0.71187 to 0.71175, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7117 - accuracy: 0.5098 - val_loss: 0.7275 - val_accuracy: 0.5016
# Epoch 251/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7125 - accuracy: 0.5181
# Epoch 251: loss did not improve from 0.71175
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7124 - accuracy: 0.5172 - val_loss: 0.7263 - val_accuracy: 0.4922
# Epoch 252/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7112 - accuracy: 0.5128
# Epoch 252: loss improved from 0.71175 to 0.71165, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7116 - accuracy: 0.5101 - val_loss: 0.7198 - val_accuracy: 0.5342
# Epoch 253/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.5113
# Epoch 253: loss did not improve from 0.71165
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7124 - accuracy: 0.5113 - val_loss: 0.7288 - val_accuracy: 0.5078
# Epoch 254/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7118 - accuracy: 0.5113
# Epoch 254: loss improved from 0.71165 to 0.71154, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7115 - accuracy: 0.5111 - val_loss: 0.7300 - val_accuracy: 0.5062
# Epoch 255/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7128 - accuracy: 0.5091
# Epoch 255: loss did not improve from 0.71154
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7128 - accuracy: 0.5096 - val_loss: 0.7251 - val_accuracy: 0.5078
# Epoch 256/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5077
# Epoch 256: loss improved from 0.71154 to 0.71153, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7115 - accuracy: 0.5073 - val_loss: 0.7250 - val_accuracy: 0.5047
# Epoch 257/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5119
# Epoch 257: loss did not improve from 0.71153
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7119 - accuracy: 0.5122 - val_loss: 0.7252 - val_accuracy: 0.5062
# Epoch 258/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5183
# Epoch 258: loss improved from 0.71153 to 0.71102, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7110 - accuracy: 0.5168 - val_loss: 0.7236 - val_accuracy: 0.5000
# Epoch 259/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.5146
# Epoch 259: loss did not improve from 0.71102
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7117 - accuracy: 0.5158 - val_loss: 0.7299 - val_accuracy: 0.4860
# Epoch 260/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5091
# Epoch 260: loss did not improve from 0.71102
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7112 - accuracy: 0.5080 - val_loss: 0.7300 - val_accuracy: 0.5016
# Epoch 261/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5231
# Epoch 261: loss did not improve from 0.71102
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7111 - accuracy: 0.5210 - val_loss: 0.7281 - val_accuracy: 0.5016
# Epoch 262/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5090
# Epoch 262: loss did not improve from 0.71102
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7111 - accuracy: 0.5101 - val_loss: 0.7286 - val_accuracy: 0.5047
# Epoch 263/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5181
# Epoch 263: loss did not improve from 0.71102
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7113 - accuracy: 0.5179 - val_loss: 0.7290 - val_accuracy: 0.5078
# Epoch 264/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7128 - accuracy: 0.5126
# Epoch 264: loss did not improve from 0.71102
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7124 - accuracy: 0.5125 - val_loss: 0.7274 - val_accuracy: 0.4938
# Epoch 265/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.5241
# Epoch 265: loss improved from 0.71102 to 0.71069, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7107 - accuracy: 0.5241 - val_loss: 0.7259 - val_accuracy: 0.4969
# Epoch 266/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7120 - accuracy: 0.5106
# Epoch 266: loss did not improve from 0.71069
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7113 - accuracy: 0.5092 - val_loss: 0.7271 - val_accuracy: 0.5016
# Epoch 267/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7110 - accuracy: 0.5179
# Epoch 267: loss improved from 0.71069 to 0.71059, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7106 - accuracy: 0.5186 - val_loss: 0.7255 - val_accuracy: 0.5062
# Epoch 268/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5174
# Epoch 268: loss did not improve from 0.71059
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7111 - accuracy: 0.5174 - val_loss: 0.7255 - val_accuracy: 0.5062
# Epoch 269/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7112 - accuracy: 0.5150
# Epoch 269: loss did not improve from 0.71059
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7108 - accuracy: 0.5141 - val_loss: 0.7249 - val_accuracy: 0.4969
# Epoch 270/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5151
# Epoch 270: loss improved from 0.71059 to 0.71037, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7104 - accuracy: 0.5155 - val_loss: 0.7254 - val_accuracy: 0.4984
# Epoch 271/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7116 - accuracy: 0.5119
# Epoch 271: loss did not improve from 0.71037
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7109 - accuracy: 0.5118 - val_loss: 0.7258 - val_accuracy: 0.5031
# Epoch 272/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7105 - accuracy: 0.5154
# Epoch 272: loss improved from 0.71037 to 0.71034, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7103 - accuracy: 0.5144 - val_loss: 0.7270 - val_accuracy: 0.5000
# Epoch 273/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5208
# Epoch 273: loss did not improve from 0.71034
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7113 - accuracy: 0.5205 - val_loss: 0.7259 - val_accuracy: 0.4845
# Epoch 274/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.5135
# Epoch 274: loss did not improve from 0.71034
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7111 - accuracy: 0.5141 - val_loss: 0.7280 - val_accuracy: 0.4814
# Epoch 275/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5107
# Epoch 275: loss did not improve from 0.71034
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7113 - accuracy: 0.5094 - val_loss: 0.7341 - val_accuracy: 0.5109
# Epoch 276/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5245
# Epoch 276: loss did not improve from 0.71034
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7115 - accuracy: 0.5244 - val_loss: 0.7307 - val_accuracy: 0.4922
# Epoch 277/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5323
# Epoch 277: loss improved from 0.71034 to 0.70944, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7094 - accuracy: 0.5312 - val_loss: 0.7255 - val_accuracy: 0.5062
# Epoch 278/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7098 - accuracy: 0.5248
# Epoch 278: loss did not improve from 0.70944
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7100 - accuracy: 0.5250 - val_loss: 0.7287 - val_accuracy: 0.4922
# Epoch 279/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7114 - accuracy: 0.5124
# Epoch 279: loss did not improve from 0.70944
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7103 - accuracy: 0.5156 - val_loss: 0.7224 - val_accuracy: 0.5217
# Epoch 280/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5179
# Epoch 280: loss did not improve from 0.70944
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7108 - accuracy: 0.5177 - val_loss: 0.7215 - val_accuracy: 0.5124
# Epoch 281/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5184
# Epoch 281: loss did not improve from 0.70944
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7108 - accuracy: 0.5172 - val_loss: 0.7264 - val_accuracy: 0.5062
# Epoch 282/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7098 - accuracy: 0.5126
# Epoch 282: loss improved from 0.70944 to 0.70914, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7091 - accuracy: 0.5134 - val_loss: 0.7299 - val_accuracy: 0.5078
# Epoch 283/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7087 - accuracy: 0.5120
# Epoch 283: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7102 - accuracy: 0.5120 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 284/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7104 - accuracy: 0.5157
# Epoch 284: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7102 - accuracy: 0.5158 - val_loss: 0.7203 - val_accuracy: 0.5280
# Epoch 285/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5165
# Epoch 285: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7107 - accuracy: 0.5141 - val_loss: 0.7241 - val_accuracy: 0.5031
# Epoch 286/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7104 - accuracy: 0.5134
# Epoch 286: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7100 - accuracy: 0.5141 - val_loss: 0.7209 - val_accuracy: 0.5093
# Epoch 287/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7112 - accuracy: 0.5173
# Epoch 287: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7111 - accuracy: 0.5165 - val_loss: 0.7241 - val_accuracy: 0.5233
# Epoch 288/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7104 - accuracy: 0.5161
# Epoch 288: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7104 - accuracy: 0.5161 - val_loss: 0.7230 - val_accuracy: 0.5093
# Epoch 289/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5167
# Epoch 289: loss did not improve from 0.70914
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7104 - accuracy: 0.5170 - val_loss: 0.7256 - val_accuracy: 0.5031
# Epoch 290/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5209
# Epoch 290: loss improved from 0.70914 to 0.70896, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7090 - accuracy: 0.5210 - val_loss: 0.7264 - val_accuracy: 0.5047
# Epoch 291/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5207
# Epoch 291: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7100 - accuracy: 0.5196 - val_loss: 0.7242 - val_accuracy: 0.4845
# Epoch 292/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5054
# Epoch 292: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7108 - accuracy: 0.5070 - val_loss: 0.7213 - val_accuracy: 0.5186
# Epoch 293/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.5181
# Epoch 293: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7099 - accuracy: 0.5170 - val_loss: 0.7232 - val_accuracy: 0.5419
# Epoch 294/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7098 - accuracy: 0.5223
# Epoch 294: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7093 - accuracy: 0.5220 - val_loss: 0.7257 - val_accuracy: 0.5078
# Epoch 295/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7110 - accuracy: 0.5145
# Epoch 295: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7107 - accuracy: 0.5141 - val_loss: 0.7232 - val_accuracy: 0.5202
# Epoch 296/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5201
# Epoch 296: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7093 - accuracy: 0.5205 - val_loss: 0.7270 - val_accuracy: 0.5047
# Epoch 297/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5193
# Epoch 297: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7099 - accuracy: 0.5198 - val_loss: 0.7294 - val_accuracy: 0.4984
# Epoch 298/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.5142
# Epoch 298: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7105 - accuracy: 0.5144 - val_loss: 0.7221 - val_accuracy: 0.5264
# Epoch 299/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7101 - accuracy: 0.5148
# Epoch 299: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7102 - accuracy: 0.5141 - val_loss: 0.7243 - val_accuracy: 0.5124
# Epoch 300/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5134
# Epoch 300: loss did not improve from 0.70896
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7101 - accuracy: 0.5134 - val_loss: 0.7242 - val_accuracy: 0.5342

# %%
# print(train_sh.history)
# model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5')
model = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# 41/41 [==============================] - 1s 7ms/step - loss: 0.7242 - accuracy: 0.5342
# 21/21 [==============================] - 1s 6ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           16
# 1       441            5
# 2       729            5
# 3      6561           16
# 4      1369            7
# 5       121            3
# 6       729            5
# 7       441            5
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           16
# 1                4.23               3       441            5
# 2                4.77               4       729            5

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_1/Model6_2_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            8
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.83                0.17         0.01
# 1  ...              5.00                0.33         0.07
# 2  ...              8.00                0.00         0.00
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.83            16.92              17.05
# 1                 5.00             5.17               5.42
# 2                 8.00             8.00               8.00
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.23              16      7396                1
# 1                5.77               5      1024                7
# 2                8.00               8      1600                0
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/model6_2.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 243ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_2/Model6_2results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            8
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            6  ...                0.33         0.07                 5.00
# 2            8  ...                0.00         0.00                 8.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             5.17               5.42                5.77               5
# 2             8.00               8.00                8.00               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1      1024                7            7
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
