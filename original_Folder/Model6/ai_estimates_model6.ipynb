# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Risk_factor_int
rfi_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
rfi_train = train_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_test = test_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_enc.fit(rfi_train)
len_rfi_enc = rfi_enc.categories_[0].shape
print(len_rfi_enc)

rfi_train = rfi_enc.transform(rfi_train)
rfi_test = rfi_enc.transform(rfi_test)
print(rfi_train.shape, rfi_test.shape)
# Out:
# (11,)
# (5791, 11) (644, 11)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=100,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 177/181 [============================>.] - ETA: 0s - loss: 1.9681 - accuracy: 0.3305
# Epoch 1: loss improved from inf to 1.94895, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 6s 7ms/step - loss: 1.9490 - accuracy: 0.3326 - val_loss: 1.1202 - val_accuracy: 0.4845
# Epoch 2/100
#  13/181 [=>............................] - ETA: 0s - loss: 1.1423 - accuracy: 0.4279
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 176/181 [============================>.] - ETA: 0s - loss: 0.9872 - accuracy: 0.4739
# Epoch 2: loss improved from 1.94895 to 0.98262, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.9826 - accuracy: 0.4745 - val_loss: 0.9200 - val_accuracy: 0.4674
# Epoch 3/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.8747 - accuracy: 0.4849
# Epoch 3: loss improved from 0.98262 to 0.87359, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.8736 - accuracy: 0.4845 - val_loss: 0.8506 - val_accuracy: 0.4814
# Epoch 4/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.8237 - accuracy: 0.4920
# Epoch 4: loss improved from 0.87359 to 0.82530, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.8253 - accuracy: 0.4927 - val_loss: 0.8574 - val_accuracy: 0.4938
# Epoch 5/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.4975
# Epoch 5: loss improved from 0.82530 to 0.80465, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.8046 - accuracy: 0.4975 - val_loss: 0.8165 - val_accuracy: 0.4938
# Epoch 6/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7897 - accuracy: 0.5063
# Epoch 6: loss improved from 0.80465 to 0.78879, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7888 - accuracy: 0.5075 - val_loss: 0.8126 - val_accuracy: 0.4814
# Epoch 7/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7803 - accuracy: 0.4998
# Epoch 7: loss improved from 0.78879 to 0.78044, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7804 - accuracy: 0.5004 - val_loss: 0.7932 - val_accuracy: 0.5202
# Epoch 8/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7698 - accuracy: 0.5124
# Epoch 8: loss improved from 0.78044 to 0.77125, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7713 - accuracy: 0.5103 - val_loss: 0.7953 - val_accuracy: 0.4752
# Epoch 9/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7664 - accuracy: 0.5127
# Epoch 9: loss improved from 0.77125 to 0.76708, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7671 - accuracy: 0.5094 - val_loss: 0.7766 - val_accuracy: 0.4736
# Epoch 10/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7574 - accuracy: 0.5128
# Epoch 10: loss improved from 0.76708 to 0.75716, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7572 - accuracy: 0.5141 - val_loss: 0.8129 - val_accuracy: 0.4845
# Epoch 11/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7558 - accuracy: 0.5072
# Epoch 11: loss improved from 0.75716 to 0.75592, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7559 - accuracy: 0.5065 - val_loss: 0.7559 - val_accuracy: 0.5217
# Epoch 12/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7573 - accuracy: 0.4959
# Epoch 12: loss did not improve from 0.75592
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7563 - accuracy: 0.4959 - val_loss: 0.7540 - val_accuracy: 0.5016
# Epoch 13/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7440 - accuracy: 0.5131
# Epoch 13: loss improved from 0.75592 to 0.74501, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7450 - accuracy: 0.5122 - val_loss: 0.7477 - val_accuracy: 0.5000
# Epoch 14/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7404 - accuracy: 0.5099
# Epoch 14: loss improved from 0.74501 to 0.74138, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7414 - accuracy: 0.5091 - val_loss: 0.7557 - val_accuracy: 0.5000
# Epoch 15/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7400 - accuracy: 0.5118
# Epoch 15: loss improved from 0.74138 to 0.73974, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7397 - accuracy: 0.5118 - val_loss: 0.7510 - val_accuracy: 0.5093
# Epoch 16/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7326 - accuracy: 0.5184
# Epoch 16: loss improved from 0.73974 to 0.73268, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7327 - accuracy: 0.5182 - val_loss: 0.7439 - val_accuracy: 0.5295
# Epoch 17/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7315 - accuracy: 0.5061
# Epoch 17: loss improved from 0.73268 to 0.73132, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7313 - accuracy: 0.5066 - val_loss: 0.7432 - val_accuracy: 0.5124
# Epoch 18/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.5079
# Epoch 18: loss improved from 0.73132 to 0.72607, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7261 - accuracy: 0.5084 - val_loss: 0.7397 - val_accuracy: 0.5140
# Epoch 19/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7286 - accuracy: 0.5180
# Epoch 19: loss did not improve from 0.72607
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7279 - accuracy: 0.5187 - val_loss: 0.7447 - val_accuracy: 0.5093
# Epoch 20/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7300 - accuracy: 0.4973
# Epoch 20: loss did not improve from 0.72607
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7294 - accuracy: 0.5001 - val_loss: 0.7440 - val_accuracy: 0.5311
# Epoch 21/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7236 - accuracy: 0.5144
# Epoch 21: loss improved from 0.72607 to 0.72529, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7253 - accuracy: 0.5137 - val_loss: 0.7490 - val_accuracy: 0.5016
# Epoch 22/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7246 - accuracy: 0.5014
# Epoch 22: loss improved from 0.72529 to 0.72427, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7243 - accuracy: 0.5025 - val_loss: 0.7477 - val_accuracy: 0.4860
# Epoch 23/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7245 - accuracy: 0.5166
# Epoch 23: loss did not improve from 0.72427
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7249 - accuracy: 0.5149 - val_loss: 0.7368 - val_accuracy: 0.4938
# Epoch 24/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.5120
# Epoch 24: loss improved from 0.72427 to 0.72080, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7208 - accuracy: 0.5120 - val_loss: 0.7296 - val_accuracy: 0.5342
# Epoch 25/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7198 - accuracy: 0.5099
# Epoch 25: loss improved from 0.72080 to 0.71982, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7198 - accuracy: 0.5099 - val_loss: 0.7393 - val_accuracy: 0.5124
# Epoch 26/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7244 - accuracy: 0.5070
# Epoch 26: loss did not improve from 0.71982
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7232 - accuracy: 0.5063 - val_loss: 0.7382 - val_accuracy: 0.5124
# Epoch 27/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7204 - accuracy: 0.5034
# Epoch 27: loss improved from 0.71982 to 0.71917, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7192 - accuracy: 0.5037 - val_loss: 0.7283 - val_accuracy: 0.5202
# Epoch 28/100
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7184 - accuracy: 0.5232
# Epoch 28: loss improved from 0.71917 to 0.71734, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7173 - accuracy: 0.5255 - val_loss: 0.7402 - val_accuracy: 0.4984
# Epoch 29/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5109
# Epoch 29: loss did not improve from 0.71734
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7179 - accuracy: 0.5092 - val_loss: 0.7388 - val_accuracy: 0.4938
# Epoch 30/100
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7144 - accuracy: 0.5192
# Epoch 30: loss improved from 0.71734 to 0.71697, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7170 - accuracy: 0.5158 - val_loss: 0.7287 - val_accuracy: 0.5326
# Epoch 31/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7207 - accuracy: 0.4969
# Epoch 31: loss did not improve from 0.71697
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7189 - accuracy: 0.4984 - val_loss: 0.7274 - val_accuracy: 0.5062
# Epoch 32/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7152 - accuracy: 0.5126
# Epoch 32: loss improved from 0.71697 to 0.71576, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7158 - accuracy: 0.5101 - val_loss: 0.7291 - val_accuracy: 0.5031
# Epoch 33/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7165 - accuracy: 0.5063
# Epoch 33: loss did not improve from 0.71576
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7164 - accuracy: 0.5063 - val_loss: 0.7246 - val_accuracy: 0.5000
# Epoch 34/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7156 - accuracy: 0.5111
# Epoch 34: loss improved from 0.71576 to 0.71552, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7155 - accuracy: 0.5115 - val_loss: 0.7295 - val_accuracy: 0.5093
# Epoch 35/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7163 - accuracy: 0.5194
# Epoch 35: loss did not improve from 0.71552
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7167 - accuracy: 0.5194 - val_loss: 0.7262 - val_accuracy: 0.5124
# Epoch 36/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7149 - accuracy: 0.5117
# Epoch 36: loss improved from 0.71552 to 0.71462, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7146 - accuracy: 0.5122 - val_loss: 0.7342 - val_accuracy: 0.5062
# Epoch 37/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7147 - accuracy: 0.5153
# Epoch 37: loss did not improve from 0.71462
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7149 - accuracy: 0.5148 - val_loss: 0.7336 - val_accuracy: 0.4845
# Epoch 38/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7142 - accuracy: 0.5203
# Epoch 38: loss improved from 0.71462 to 0.71452, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7145 - accuracy: 0.5229 - val_loss: 0.7312 - val_accuracy: 0.5186
# Epoch 39/100
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7167 - accuracy: 0.5136
# Epoch 39: loss did not improve from 0.71452
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7155 - accuracy: 0.5165 - val_loss: 0.7352 - val_accuracy: 0.4876
# Epoch 40/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5163
# Epoch 40: loss did not improve from 0.71452
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7164 - accuracy: 0.5151 - val_loss: 0.7323 - val_accuracy: 0.4860
# Epoch 41/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7143 - accuracy: 0.5144
# Epoch 41: loss did not improve from 0.71452
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7150 - accuracy: 0.5144 - val_loss: 0.7308 - val_accuracy: 0.4876
# Epoch 42/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7145 - accuracy: 0.5121
# Epoch 42: loss did not improve from 0.71452
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7145 - accuracy: 0.5125 - val_loss: 0.7268 - val_accuracy: 0.5342
# Epoch 43/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7139 - accuracy: 0.5060
# Epoch 43: loss improved from 0.71452 to 0.71342, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7134 - accuracy: 0.5054 - val_loss: 0.7271 - val_accuracy: 0.4938
# Epoch 44/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7140 - accuracy: 0.5009
# Epoch 44: loss did not improve from 0.71342
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7137 - accuracy: 0.5011 - val_loss: 0.7245 - val_accuracy: 0.4845
# Epoch 45/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7145 - accuracy: 0.5132
# Epoch 45: loss improved from 0.71342 to 0.71289, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7129 - accuracy: 0.5146 - val_loss: 0.7335 - val_accuracy: 0.5140
# Epoch 46/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7159 - accuracy: 0.5136
# Epoch 46: loss did not improve from 0.71289
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7149 - accuracy: 0.5137 - val_loss: 0.7287 - val_accuracy: 0.5078
# Epoch 47/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.5129
# Epoch 47: loss improved from 0.71289 to 0.71206, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7121 - accuracy: 0.5132 - val_loss: 0.7327 - val_accuracy: 0.4876
# Epoch 48/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7139 - accuracy: 0.5046
# Epoch 48: loss did not improve from 0.71206
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7126 - accuracy: 0.5051 - val_loss: 0.7299 - val_accuracy: 0.5124
# Epoch 49/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5148
# Epoch 49: loss improved from 0.71206 to 0.71082, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7108 - accuracy: 0.5160 - val_loss: 0.7269 - val_accuracy: 0.4953
# Epoch 50/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7124 - accuracy: 0.5143
# Epoch 50: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7121 - accuracy: 0.5151 - val_loss: 0.7265 - val_accuracy: 0.5171
# Epoch 51/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.5176
# Epoch 51: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7114 - accuracy: 0.5170 - val_loss: 0.7284 - val_accuracy: 0.4922
# Epoch 52/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7124 - accuracy: 0.5111
# Epoch 52: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7122 - accuracy: 0.5111 - val_loss: 0.7230 - val_accuracy: 0.5233
# Epoch 53/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7112 - accuracy: 0.5153
# Epoch 53: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7109 - accuracy: 0.5153 - val_loss: 0.7256 - val_accuracy: 0.5078
# Epoch 54/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7128 - accuracy: 0.5059
# Epoch 54: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7129 - accuracy: 0.5056 - val_loss: 0.7242 - val_accuracy: 0.5000
# Epoch 55/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7131 - accuracy: 0.5065
# Epoch 55: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7130 - accuracy: 0.5077 - val_loss: 0.7309 - val_accuracy: 0.4953
# Epoch 56/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7115 - accuracy: 0.5198
# Epoch 56: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7115 - accuracy: 0.5201 - val_loss: 0.7252 - val_accuracy: 0.5140
# Epoch 57/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7121 - accuracy: 0.5190
# Epoch 57: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7111 - accuracy: 0.5187 - val_loss: 0.7268 - val_accuracy: 0.5280
# Epoch 58/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.5000
# Epoch 58: loss did not improve from 0.71082
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7118 - accuracy: 0.4997 - val_loss: 0.7237 - val_accuracy: 0.5016
# Epoch 59/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7105 - accuracy: 0.5144
# Epoch 59: loss improved from 0.71082 to 0.71073, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7107 - accuracy: 0.5168 - val_loss: 0.7299 - val_accuracy: 0.5140
# Epoch 60/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7117 - accuracy: 0.5080
# Epoch 60: loss did not improve from 0.71073
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7117 - accuracy: 0.5080 - val_loss: 0.7322 - val_accuracy: 0.5016
# Epoch 61/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5194
# Epoch 61: loss did not improve from 0.71073
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7111 - accuracy: 0.5196 - val_loss: 0.7252 - val_accuracy: 0.5016
# Epoch 62/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5143
# Epoch 62: loss improved from 0.71073 to 0.71009, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7101 - accuracy: 0.5155 - val_loss: 0.7237 - val_accuracy: 0.5047
# Epoch 63/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5019
# Epoch 63: loss improved from 0.71009 to 0.71004, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7100 - accuracy: 0.5027 - val_loss: 0.7219 - val_accuracy: 0.5016
# Epoch 64/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7089 - accuracy: 0.5175
# Epoch 64: loss did not improve from 0.71004
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7101 - accuracy: 0.5156 - val_loss: 0.7194 - val_accuracy: 0.5311
# Epoch 65/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.5035
# Epoch 65: loss did not improve from 0.71004
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7111 - accuracy: 0.5039 - val_loss: 0.7242 - val_accuracy: 0.4969
# Epoch 66/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7109 - accuracy: 0.5125
# Epoch 66: loss improved from 0.71004 to 0.70941, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5141 - val_loss: 0.7260 - val_accuracy: 0.5093
# Epoch 67/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7104 - accuracy: 0.5172
# Epoch 67: loss did not improve from 0.70941
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5193 - val_loss: 0.7245 - val_accuracy: 0.4969
# Epoch 68/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7077 - accuracy: 0.5091
# Epoch 68: loss did not improve from 0.70941
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5101 - val_loss: 0.7256 - val_accuracy: 0.4876
# Epoch 69/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5165
# Epoch 69: loss improved from 0.70941 to 0.70897, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7090 - accuracy: 0.5167 - val_loss: 0.7308 - val_accuracy: 0.4922
# Epoch 70/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7088 - accuracy: 0.5163
# Epoch 70: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5151 - val_loss: 0.7263 - val_accuracy: 0.4891
# Epoch 71/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7110 - accuracy: 0.5145
# Epoch 71: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.5151 - val_loss: 0.7215 - val_accuracy: 0.5248
# Epoch 72/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.5056
# Epoch 72: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5068 - val_loss: 0.7223 - val_accuracy: 0.5093
# Epoch 73/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.5170
# Epoch 73: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5170 - val_loss: 0.7258 - val_accuracy: 0.4767
# Epoch 74/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5267
# Epoch 74: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7096 - accuracy: 0.5282 - val_loss: 0.7239 - val_accuracy: 0.4907
# Epoch 75/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7092 - accuracy: 0.5198
# Epoch 75: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7097 - accuracy: 0.5201 - val_loss: 0.7250 - val_accuracy: 0.5109
# Epoch 76/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5078
# Epoch 76: loss did not improve from 0.70897
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7107 - accuracy: 0.5079 - val_loss: 0.7205 - val_accuracy: 0.5186
# Epoch 77/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5059
# Epoch 77: loss improved from 0.70897 to 0.70790, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7079 - accuracy: 0.5065 - val_loss: 0.7265 - val_accuracy: 0.5124
# Epoch 78/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7087 - accuracy: 0.5194
# Epoch 78: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7092 - accuracy: 0.5194 - val_loss: 0.7248 - val_accuracy: 0.5031
# Epoch 79/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7091 - accuracy: 0.5278
# Epoch 79: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5291 - val_loss: 0.7295 - val_accuracy: 0.5093
# Epoch 80/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7093 - accuracy: 0.5040
# Epoch 80: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7092 - accuracy: 0.5030 - val_loss: 0.7236 - val_accuracy: 0.5093
# Epoch 81/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7085 - accuracy: 0.5080
# Epoch 81: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7079 - accuracy: 0.5103 - val_loss: 0.7259 - val_accuracy: 0.4938
# Epoch 82/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7100 - accuracy: 0.5233
# Epoch 82: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7098 - accuracy: 0.5222 - val_loss: 0.7316 - val_accuracy: 0.4876
# Epoch 83/100
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7103 - accuracy: 0.5026
# Epoch 83: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5037 - val_loss: 0.7258 - val_accuracy: 0.5031
# Epoch 84/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7094 - accuracy: 0.5120
# Epoch 84: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7089 - accuracy: 0.5137 - val_loss: 0.7205 - val_accuracy: 0.5078
# Epoch 85/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5147
# Epoch 85: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7083 - accuracy: 0.5144 - val_loss: 0.7247 - val_accuracy: 0.4938
# Epoch 86/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.5148
# Epoch 86: loss did not improve from 0.70790
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7084 - accuracy: 0.5156 - val_loss: 0.7223 - val_accuracy: 0.5047
# Epoch 87/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5220
# Epoch 87: loss improved from 0.70790 to 0.70725, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7072 - accuracy: 0.5225 - val_loss: 0.7275 - val_accuracy: 0.5062
# Epoch 88/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.5087
# Epoch 88: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7086 - accuracy: 0.5087 - val_loss: 0.7245 - val_accuracy: 0.4907
# Epoch 89/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7085 - accuracy: 0.5084
# Epoch 89: loss did not improve from 0.70725
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7083 - accuracy: 0.5091 - val_loss: 0.7263 - val_accuracy: 0.4876
# Epoch 90/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5084
# Epoch 90: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7084 - accuracy: 0.5092 - val_loss: 0.7243 - val_accuracy: 0.4938
# Epoch 91/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5208
# Epoch 91: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7076 - accuracy: 0.5212 - val_loss: 0.7197 - val_accuracy: 0.5124
# Epoch 92/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5054
# Epoch 92: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7082 - accuracy: 0.5058 - val_loss: 0.7267 - val_accuracy: 0.5031
# Epoch 93/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7077 - accuracy: 0.5230
# Epoch 93: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7077 - accuracy: 0.5215 - val_loss: 0.7538 - val_accuracy: 0.5000
# Epoch 94/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5147
# Epoch 94: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7100 - accuracy: 0.5123 - val_loss: 0.7233 - val_accuracy: 0.5016
# Epoch 95/100
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7092 - accuracy: 0.5119
# Epoch 95: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7081 - accuracy: 0.5137 - val_loss: 0.7231 - val_accuracy: 0.4984
# Epoch 96/100
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7090 - accuracy: 0.5101
# Epoch 96: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7082 - accuracy: 0.5104 - val_loss: 0.7282 - val_accuracy: 0.5264
# Epoch 97/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7073 - accuracy: 0.5149
# Epoch 97: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5127 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 98/100
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7097 - accuracy: 0.5142
# Epoch 98: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7074 - accuracy: 0.5132 - val_loss: 0.7265 - val_accuracy: 0.5078
# Epoch 99/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5079
# Epoch 99: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5087 - val_loss: 0.7223 - val_accuracy: 0.4969
# Epoch 100/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.5190
# Epoch 100: loss did not improve from 0.70725
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7083 - accuracy: 0.5172 - val_loss: 0.7243 - val_accuracy: 0.5031

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# {'loss': [1.9489532709121704, 0.982620358467102, 0.8735860586166382, 0.8252958059310913, 0.8046476244926453, 0.7887896299362183, 0.7804428339004517, 0.7712523937225342, 0.7670758366584778, 0.7571631669998169, 0.7559187412261963, 0.7563294172286987, 0.7450149655342102, 0.7413806915283203, 0.7397361993789673, 0.7326823472976685, 0.731319785118103, 0.7260720133781433, 0.7278701663017273, 0.7294201254844666, 0.7252851128578186, 0.7242686748504639, 0.7248712778091431, 0.7207975387573242, 0.7198160886764526, 0.7232303619384766, 0.7191662192344666, 0.7173417210578918, 0.7178618907928467, 0.7169691324234009, 0.7189369201660156, 0.7157590389251709, 0.7163888812065125, 0.7155170440673828, 0.7166929244995117, 0.714615523815155, 0.7148838639259338, 0.7145197987556458, 0.7155489921569824, 0.7163950204849243, 0.7149803638458252, 0.7145438194274902, 0.7134197354316711, 0.7136734127998352, 0.7128875851631165, 0.7149282097816467, 0.7120572924613953, 0.7126097083091736, 0.7108197212219238, 0.712110698223114, 0.7114005088806152, 0.7121588587760925, 0.7109161019325256, 0.7128986120223999, 0.7130016088485718, 0.7115413546562195, 0.7111496329307556, 0.711753785610199, 0.7107335329055786, 0.7116532921791077, 0.7111487984657288, 0.7100927829742432, 0.7100441455841064, 0.7100500464439392, 0.711103618144989, 0.709408164024353, 0.7100605964660645, 0.7094252109527588, 0.7089689373970032, 0.7101425528526306, 0.7103238105773926, 0.7101222276687622, 0.7094257473945618, 0.7096263766288757, 0.7097452282905579, 0.7106987833976746, 0.7078953981399536, 0.7092200517654419, 0.7079882621765137, 0.7092483043670654, 0.7079413533210754, 0.709800660610199, 0.7100988030433655, 0.708928108215332, 0.7082970142364502, 0.7084123492240906, 0.7072471976280212, 0.7086053490638733, 0.7083492875099182, 0.7084174156188965, 0.7075711488723755, 0.7082292437553406, 0.7077372670173645, 0.7100206613540649, 0.7081010937690735, 0.7082479596138, 0.7078233361244202, 0.7073899507522583, 0.7072810530662537, 0.7083410620689392], 'accuracy': [0.33258503675460815, 0.4745294451713562, 0.4845449924468994, 0.4926610291004181, 0.4974961280822754, 0.5075116753578186, 0.5004317164421082, 0.5102745890617371, 0.5094111561775208, 0.5140735507011414, 0.506475567817688, 0.49594196677207947, 0.5121740698814392, 0.5090658068656921, 0.5118287205696106, 0.518217921257019, 0.5066482424736023, 0.5083750486373901, 0.518735945224762, 0.5000863671302795, 0.5137282013893127, 0.5025038719177246, 0.5149369835853577, 0.5120013952255249, 0.5099291801452637, 0.5063028931617737, 0.5037126541137695, 0.5254705548286438, 0.5092384815216064, 0.5158003568649292, 0.4983595311641693, 0.510101854801178, 0.5063028931617737, 0.5114833116531372, 0.519426703453064, 0.5121740698814392, 0.5147643089294434, 0.5228803157806396, 0.5164911150932312, 0.515109658241272, 0.51441890001297, 0.5125194191932678, 0.5054394602775574, 0.5011224150657654, 0.514591634273529, 0.5137282013893127, 0.5132101774215698, 0.5050941109657288, 0.5159730911254883, 0.515109658241272, 0.5170091390609741, 0.5111379623413086, 0.5152823328971863, 0.5056121349334717, 0.5076843500137329, 0.5201174020767212, 0.518735945224762, 0.49974098801612854, 0.5168364644050598, 0.5080296993255615, 0.5195993781089783, 0.5154550075531006, 0.5026765465736389, 0.5156276822090149, 0.5038853287696838, 0.5140735507011414, 0.5192540287971497, 0.510101854801178, 0.5166637897491455, 0.515109658241272, 0.515109658241272, 0.5068209171295166, 0.5170091390609741, 0.5282334685325623, 0.5201174020767212, 0.5078570246696472, 0.506475567817688, 0.519426703453064, 0.5290969014167786, 0.5030219554901123, 0.5102745890617371, 0.5221896171569824, 0.5037126541137695, 0.5137282013893127, 0.51441890001297, 0.5156276822090149, 0.522534966468811, 0.5087204575538635, 0.5090658068656921, 0.5092384815216064, 0.5211535096168518, 0.505784809589386, 0.5214988589286804, 0.5123467445373535, 0.5137282013893127, 0.5104472637176514, 0.5126920938491821, 0.5132101774215698, 0.5087204575538635, 0.5171818137168884], 'val ...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - 0s 4ms/step - loss: 0.7243 - accuracy: 0.5031
# 21/21 [==============================] - 0s 4ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           17
# 1       441            4
# 2       729            4
# 3      6561           17
# 4      1369            7
# 5       121            3
# 6       729            4
# 7       441            4
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           17
# 1                4.23               3       441            4
# 2                4.77               4       729            4

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/Model6_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.83                0.17         0.01
# 1  ...              5.00                0.33         0.07
# 2  ...              8.67                0.00         0.00
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.83            16.92              17.05
# 1                 5.00             5.17               5.42
# 2                 8.67             8.67               8.67
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.23              16      7396                1
# 1                5.77               5      1024                7
# 2                8.67               8      1600                0
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)

# rfi_testdata = df_test["Risk_factor_int"].to_numpy().reshape(-1,1)
# rfi_testdata = rfi_enc.transform(rfi_testdata)
# print(rfi_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6.h5')
model6.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 308)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  118656    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 369358 (1.41 MB)
# Trainable params: 369358 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 296ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/Model6_results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            6  ...                0.33         0.07                 5.00
# 2            8  ...                0.00         0.00                 8.67
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             5.17               5.42                5.77               5
# 2             8.67               8.67                8.67               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1      1024                7            0
# 2      1600                0            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
