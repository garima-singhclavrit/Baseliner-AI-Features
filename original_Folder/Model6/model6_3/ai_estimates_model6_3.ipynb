# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance
# 0               16.23              15      6561
# 1                4.23               3       441
# 2                4.77               4       729
#
# [3 rows x 21 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(256, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(256, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)


# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense (Dense)               (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 564)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 384)                  216960    ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  49280     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 26)                   3354      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 664526 (2.53 MB)
# Trainable params: 664526 (2.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train], ae_train,
    epochs=300,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/300
# 175/181 [============================>.] - ETA: 0s - loss: 2.2809 - accuracy: 0.2912
# Epoch 1: loss improved from inf to 2.25257, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - 5s 10ms/step - loss: 2.2526 - accuracy: 0.2948 - val_loss: 1.3362 - val_accuracy: 0.4286
# Epoch 2/300
# 174/181 [===========================>..] - ETA: 0s - loss: 1.0955 - accuracy: 0.4637
# Epoch 2: loss improved from 2.25257 to 1.09244, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 1.0924 - accuracy: 0.4628 - val_loss: 0.9583 - val_accuracy: 0.4736
# Epoch 3/300
# 181/181 [==============================] - ETA: 0s - loss: 0.9178 - accuracy: 0.4925
# Epoch 3: loss improved from 1.09244 to 0.91776, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.9178 - accuracy: 0.4925 - val_loss: 0.8879 - val_accuracy: 0.4922
# Epoch 4/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.8552 - accuracy: 0.4983
# Epoch 4: loss improved from 0.91776 to 0.85430, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.8543 - accuracy: 0.4985 - val_loss: 0.8654 - val_accuracy: 0.4736
# Epoch 5/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.8215 - accuracy: 0.5027
# Epoch 5: loss improved from 0.85430 to 0.82176, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.8218 - accuracy: 0.5035 - val_loss: 0.8257 - val_accuracy: 0.4938
# Epoch 6/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7954 - accuracy: 0.5162
# Epoch 6: loss improved from 0.82176 to 0.79443, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7944 - accuracy: 0.5130 - val_loss: 0.8244 - val_accuracy: 0.5000
# Epoch 7/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7840 - accuracy: 0.5074
# Epoch 7: loss improved from 0.79443 to 0.78487, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7849 - accuracy: 0.5066 - val_loss: 0.7965 - val_accuracy: 0.5078
# Epoch 8/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7801 - accuracy: 0.4929
# Epoch 8: loss improved from 0.78487 to 0.77904, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7790 - accuracy: 0.4913 - val_loss: 0.7891 - val_accuracy: 0.4845
# Epoch 9/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7649 - accuracy: 0.5032
# Epoch 9: loss improved from 0.77904 to 0.76577, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7658 - accuracy: 0.5047 - val_loss: 0.7857 - val_accuracy: 0.4860
# Epoch 10/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7593 - accuracy: 0.5046
# Epoch 10: loss improved from 0.76577 to 0.76136, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7614 - accuracy: 0.5053 - val_loss: 0.8020 - val_accuracy: 0.4814
# Epoch 11/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7563 - accuracy: 0.5059
# Epoch 11: loss improved from 0.76136 to 0.75551, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7555 - accuracy: 0.5072 - val_loss: 0.7803 - val_accuracy: 0.4860
# Epoch 12/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7468 - accuracy: 0.5129
# Epoch 12: loss improved from 0.75551 to 0.74618, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7462 - accuracy: 0.5130 - val_loss: 0.7512 - val_accuracy: 0.5062
# Epoch 13/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7457 - accuracy: 0.5002
# Epoch 13: loss improved from 0.74618 to 0.74598, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7460 - accuracy: 0.5006 - val_loss: 0.7700 - val_accuracy: 0.5140
# Epoch 14/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7415 - accuracy: 0.5163
# Epoch 14: loss improved from 0.74598 to 0.74090, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7409 - accuracy: 0.5168 - val_loss: 0.7442 - val_accuracy: 0.5078
# Epoch 15/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7368 - accuracy: 0.5205
# Epoch 15: loss improved from 0.74090 to 0.73659, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7366 - accuracy: 0.5186 - val_loss: 0.7400 - val_accuracy: 0.4767
# Epoch 16/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7352 - accuracy: 0.5143
# Epoch 16: loss improved from 0.73659 to 0.73435, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7344 - accuracy: 0.5158 - val_loss: 0.7586 - val_accuracy: 0.4845
# Epoch 17/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.5125
# Epoch 17: loss improved from 0.73435 to 0.73078, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7308 - accuracy: 0.5108 - val_loss: 0.7401 - val_accuracy: 0.5078
# Epoch 18/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7310 - accuracy: 0.5043
# Epoch 18: loss improved from 0.73078 to 0.73049, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7305 - accuracy: 0.5054 - val_loss: 0.7647 - val_accuracy: 0.4829
# Epoch 19/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.5150
# Epoch 19: loss improved from 0.73049 to 0.72687, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7269 - accuracy: 0.5155 - val_loss: 0.7434 - val_accuracy: 0.5186
# Epoch 20/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7264 - accuracy: 0.5208
# Epoch 20: loss improved from 0.72687 to 0.72642, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7264 - accuracy: 0.5198 - val_loss: 0.7390 - val_accuracy: 0.5171
# Epoch 21/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7233 - accuracy: 0.5177
# Epoch 21: loss improved from 0.72642 to 0.72254, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7225 - accuracy: 0.5175 - val_loss: 0.7393 - val_accuracy: 0.4860
# Epoch 22/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7268 - accuracy: 0.5089
# Epoch 22: loss did not improve from 0.72254
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7258 - accuracy: 0.5080 - val_loss: 0.7384 - val_accuracy: 0.5264
# Epoch 23/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7253 - accuracy: 0.5080
# Epoch 23: loss did not improve from 0.72254
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7255 - accuracy: 0.5072 - val_loss: 0.7450 - val_accuracy: 0.4845
# Epoch 24/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7265 - accuracy: 0.5108
# Epoch 24: loss did not improve from 0.72254
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7251 - accuracy: 0.5122 - val_loss: 0.7410 - val_accuracy: 0.5000
# Epoch 25/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.5195
# Epoch 25: loss improved from 0.72254 to 0.71873, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7187 - accuracy: 0.5189 - val_loss: 0.7419 - val_accuracy: 0.5062
# Epoch 26/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7233 - accuracy: 0.5059
# Epoch 26: loss did not improve from 0.71873
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7233 - accuracy: 0.5061 - val_loss: 0.7338 - val_accuracy: 0.4907
# Epoch 27/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7217 - accuracy: 0.5072
# Epoch 27: loss did not improve from 0.71873
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7205 - accuracy: 0.5085 - val_loss: 0.7411 - val_accuracy: 0.5078
# Epoch 28/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7190 - accuracy: 0.5053
# Epoch 28: loss improved from 0.71873 to 0.71803, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7180 - accuracy: 0.5061 - val_loss: 0.7361 - val_accuracy: 0.5000
# Epoch 29/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7189 - accuracy: 0.5161
# Epoch 29: loss did not improve from 0.71803
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7189 - accuracy: 0.5153 - val_loss: 0.7325 - val_accuracy: 0.5155
# Epoch 30/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7200 - accuracy: 0.5109
# Epoch 30: loss did not improve from 0.71803
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7198 - accuracy: 0.5101 - val_loss: 0.7327 - val_accuracy: 0.4953
# Epoch 31/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.5182
# Epoch 31: loss did not improve from 0.71803
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7189 - accuracy: 0.5175 - val_loss: 0.7470 - val_accuracy: 0.4938
# Epoch 32/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7199 - accuracy: 0.5204
# Epoch 32: loss did not improve from 0.71803
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7205 - accuracy: 0.5193 - val_loss: 0.7332 - val_accuracy: 0.5109
# Epoch 33/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7185 - accuracy: 0.5123
# Epoch 33: loss did not improve from 0.71803
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7181 - accuracy: 0.5098 - val_loss: 0.7317 - val_accuracy: 0.5140
# Epoch 34/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.5096
# Epoch 34: loss improved from 0.71803 to 0.71646, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7165 - accuracy: 0.5108 - val_loss: 0.7444 - val_accuracy: 0.4907
# Epoch 35/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7168 - accuracy: 0.5149
# Epoch 35: loss did not improve from 0.71646
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7169 - accuracy: 0.5141 - val_loss: 0.7277 - val_accuracy: 0.5326
# Epoch 36/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7168 - accuracy: 0.5132
# Epoch 36: loss improved from 0.71646 to 0.71597, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7160 - accuracy: 0.5132 - val_loss: 0.7300 - val_accuracy: 0.5124
# Epoch 37/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7165 - accuracy: 0.5125
# Epoch 37: loss improved from 0.71597 to 0.71561, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7156 - accuracy: 0.5118 - val_loss: 0.7428 - val_accuracy: 0.5016
# Epoch 38/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.5118
# Epoch 38: loss improved from 0.71561 to 0.71490, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7149 - accuracy: 0.5118 - val_loss: 0.7243 - val_accuracy: 0.5280
# Epoch 39/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7171 - accuracy: 0.5016
# Epoch 39: loss did not improve from 0.71490
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7172 - accuracy: 0.5022 - val_loss: 0.7325 - val_accuracy: 0.5186
# Epoch 40/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7148 - accuracy: 0.5056
# Epoch 40: loss did not improve from 0.71490
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7162 - accuracy: 0.5054 - val_loss: 0.7305 - val_accuracy: 0.5093
# Epoch 41/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7150 - accuracy: 0.5116
# Epoch 41: loss did not improve from 0.71490
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7158 - accuracy: 0.5113 - val_loss: 0.7281 - val_accuracy: 0.4907
# Epoch 42/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7150 - accuracy: 0.5139
# Epoch 42: loss improved from 0.71490 to 0.71405, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7140 - accuracy: 0.5149 - val_loss: 0.7340 - val_accuracy: 0.4984
# Epoch 43/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7147 - accuracy: 0.5063
# Epoch 43: loss did not improve from 0.71405
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7146 - accuracy: 0.5091 - val_loss: 0.7346 - val_accuracy: 0.5016
# Epoch 44/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7143 - accuracy: 0.5112
# Epoch 44: loss did not improve from 0.71405
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7141 - accuracy: 0.5099 - val_loss: 0.7296 - val_accuracy: 0.4984
# Epoch 45/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5218
# Epoch 45: loss improved from 0.71405 to 0.71303, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7130 - accuracy: 0.5218 - val_loss: 0.7335 - val_accuracy: 0.5047
# Epoch 46/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7131 - accuracy: 0.5064
# Epoch 46: loss did not improve from 0.71303
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7139 - accuracy: 0.5066 - val_loss: 0.7313 - val_accuracy: 0.5140
# Epoch 47/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.5142
# Epoch 47: loss did not improve from 0.71303
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7137 - accuracy: 0.5127 - val_loss: 0.7286 - val_accuracy: 0.4953
# Epoch 48/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7126 - accuracy: 0.5205
# Epoch 48: loss improved from 0.71303 to 0.71257, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7126 - accuracy: 0.5213 - val_loss: 0.7341 - val_accuracy: 0.5217
# Epoch 49/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7155 - accuracy: 0.5145
# Epoch 49: loss did not improve from 0.71257
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7153 - accuracy: 0.5149 - val_loss: 0.7284 - val_accuracy: 0.5186
# Epoch 50/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7138 - accuracy: 0.5068
# Epoch 50: loss did not improve from 0.71257
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7136 - accuracy: 0.5072 - val_loss: 0.7283 - val_accuracy: 0.4752
# Epoch 51/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7149 - accuracy: 0.5028
# Epoch 51: loss did not improve from 0.71257
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7146 - accuracy: 0.5037 - val_loss: 0.7288 - val_accuracy: 0.5047
# Epoch 52/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7126 - accuracy: 0.5124
# Epoch 52: loss did not improve from 0.71257
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7127 - accuracy: 0.5125 - val_loss: 0.7232 - val_accuracy: 0.5171
# Epoch 53/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7137 - accuracy: 0.5143
# Epoch 53: loss did not improve from 0.71257
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7126 - accuracy: 0.5163 - val_loss: 0.7337 - val_accuracy: 0.4876
# Epoch 54/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.5102
# Epoch 54: loss improved from 0.71257 to 0.71149, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7115 - accuracy: 0.5104 - val_loss: 0.7263 - val_accuracy: 0.5016
# Epoch 55/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7115 - accuracy: 0.5086
# Epoch 55: loss did not improve from 0.71149
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7118 - accuracy: 0.5065 - val_loss: 0.7261 - val_accuracy: 0.4860
# Epoch 56/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5151
# Epoch 56: loss improved from 0.71149 to 0.71045, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7104 - accuracy: 0.5160 - val_loss: 0.7327 - val_accuracy: 0.4984
# Epoch 57/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5153
# Epoch 57: loss did not improve from 0.71045
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7110 - accuracy: 0.5142 - val_loss: 0.7269 - val_accuracy: 0.5124
# Epoch 58/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7137 - accuracy: 0.4933
# Epoch 58: loss did not improve from 0.71045
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7133 - accuracy: 0.4946 - val_loss: 0.7247 - val_accuracy: 0.5217
# Epoch 59/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.5226
# Epoch 59: loss did not improve from 0.71045
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7109 - accuracy: 0.5217 - val_loss: 0.7299 - val_accuracy: 0.5155
# Epoch 60/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.5234
# Epoch 60: loss improved from 0.71045 to 0.71017, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7102 - accuracy: 0.5246 - val_loss: 0.7340 - val_accuracy: 0.4953
# Epoch 61/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7108 - accuracy: 0.5140
# Epoch 61: loss did not improve from 0.71017
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7102 - accuracy: 0.5151 - val_loss: 0.7301 - val_accuracy: 0.5078
# Epoch 62/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7122 - accuracy: 0.5077
# Epoch 62: loss did not improve from 0.71017
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7121 - accuracy: 0.5085 - val_loss: 0.7286 - val_accuracy: 0.4969
# Epoch 63/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.5109
# Epoch 63: loss did not improve from 0.71017
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.5118 - val_loss: 0.7255 - val_accuracy: 0.5109
# Epoch 64/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5147
# Epoch 64: loss did not improve from 0.71017
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7103 - accuracy: 0.5165 - val_loss: 0.7290 - val_accuracy: 0.4891
# Epoch 65/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.5215
# Epoch 65: loss improved from 0.71017 to 0.71002, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7100 - accuracy: 0.5215 - val_loss: 0.7290 - val_accuracy: 0.5000
# Epoch 66/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7115 - accuracy: 0.5151
# Epoch 66: loss did not improve from 0.71002
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7115 - accuracy: 0.5151 - val_loss: 0.7292 - val_accuracy: 0.4907
# Epoch 67/300
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7093 - accuracy: 0.5094
# Epoch 67: loss improved from 0.71002 to 0.70966, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7097 - accuracy: 0.5113 - val_loss: 0.7235 - val_accuracy: 0.5124
# Epoch 68/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7088 - accuracy: 0.5182
# Epoch 68: loss improved from 0.70966 to 0.70963, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7096 - accuracy: 0.5180 - val_loss: 0.7194 - val_accuracy: 0.5264
# Epoch 69/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7105 - accuracy: 0.5062
# Epoch 69: loss did not improve from 0.70963
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7098 - accuracy: 0.5063 - val_loss: 0.7281 - val_accuracy: 0.4891
# Epoch 70/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.5146
# Epoch 70: loss did not improve from 0.70963
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7097 - accuracy: 0.5144 - val_loss: 0.7215 - val_accuracy: 0.5202
# Epoch 71/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7104 - accuracy: 0.5113
# Epoch 71: loss improved from 0.70963 to 0.70951, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7095 - accuracy: 0.5122 - val_loss: 0.7230 - val_accuracy: 0.5016
# Epoch 72/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.5099
# Epoch 72: loss improved from 0.70951 to 0.70931, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7093 - accuracy: 0.5106 - val_loss: 0.7284 - val_accuracy: 0.4953
# Epoch 73/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5162
# Epoch 73: loss improved from 0.70931 to 0.70885, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7088 - accuracy: 0.5160 - val_loss: 0.7227 - val_accuracy: 0.5357
# Epoch 74/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.5035
# Epoch 74: loss did not improve from 0.70885
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7093 - accuracy: 0.5030 - val_loss: 0.7290 - val_accuracy: 0.5078
# Epoch 75/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7093 - accuracy: 0.5176
# Epoch 75: loss did not improve from 0.70885
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7097 - accuracy: 0.5180 - val_loss: 0.7252 - val_accuracy: 0.4984
# Epoch 76/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7091 - accuracy: 0.5061
# Epoch 76: loss improved from 0.70885 to 0.70873, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7087 - accuracy: 0.5073 - val_loss: 0.7330 - val_accuracy: 0.4829
# Epoch 77/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7104 - accuracy: 0.5094
# Epoch 77: loss did not improve from 0.70873
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.5096 - val_loss: 0.7287 - val_accuracy: 0.5109
# Epoch 78/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7096 - accuracy: 0.5180
# Epoch 78: loss did not improve from 0.70873
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7092 - accuracy: 0.5198 - val_loss: 0.7261 - val_accuracy: 0.5078
# Epoch 79/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5131
# Epoch 79: loss improved from 0.70873 to 0.70870, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7087 - accuracy: 0.5148 - val_loss: 0.7260 - val_accuracy: 0.5280
# Epoch 80/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7082 - accuracy: 0.5194
# Epoch 80: loss did not improve from 0.70870
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7091 - accuracy: 0.5174 - val_loss: 0.7225 - val_accuracy: 0.5202
# Epoch 81/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7100 - accuracy: 0.5069
# Epoch 81: loss did not improve from 0.70870
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7094 - accuracy: 0.5084 - val_loss: 0.7289 - val_accuracy: 0.4922
# Epoch 82/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5045
# Epoch 82: loss improved from 0.70870 to 0.70863, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7086 - accuracy: 0.5049 - val_loss: 0.7258 - val_accuracy: 0.5109
# Epoch 83/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7082 - accuracy: 0.5164
# Epoch 83: loss improved from 0.70863 to 0.70775, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7078 - accuracy: 0.5165 - val_loss: 0.7253 - val_accuracy: 0.4907
# Epoch 84/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7089 - accuracy: 0.5160
# Epoch 84: loss did not improve from 0.70775
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7089 - accuracy: 0.5160 - val_loss: 0.7205 - val_accuracy: 0.5248
# Epoch 85/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.5155
# Epoch 85: loss did not improve from 0.70775
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7081 - accuracy: 0.5161 - val_loss: 0.7233 - val_accuracy: 0.5093
# Epoch 86/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.5156
# Epoch 86: loss did not improve from 0.70775
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7087 - accuracy: 0.5160 - val_loss: 0.7239 - val_accuracy: 0.5031
# Epoch 87/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5171
# Epoch 87: loss did not improve from 0.70775
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7086 - accuracy: 0.5177 - val_loss: 0.7204 - val_accuracy: 0.5155
# Epoch 88/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7071 - accuracy: 0.5172
# Epoch 88: loss improved from 0.70775 to 0.70695, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7070 - accuracy: 0.5175 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 89/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.5207
# Epoch 89: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7073 - accuracy: 0.5203 - val_loss: 0.7237 - val_accuracy: 0.5016
# Epoch 90/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7089 - accuracy: 0.5115
# Epoch 90: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5137 - val_loss: 0.7218 - val_accuracy: 0.5171
# Epoch 91/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.5138
# Epoch 91: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7084 - accuracy: 0.5139 - val_loss: 0.7240 - val_accuracy: 0.4860
# Epoch 92/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7082 - accuracy: 0.5171
# Epoch 92: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5170 - val_loss: 0.7263 - val_accuracy: 0.4845
# Epoch 93/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7072 - accuracy: 0.5199
# Epoch 93: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7079 - accuracy: 0.5184 - val_loss: 0.7229 - val_accuracy: 0.5233
# Epoch 94/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.5092
# Epoch 94: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7078 - accuracy: 0.5092 - val_loss: 0.7228 - val_accuracy: 0.5202
# Epoch 95/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7073 - accuracy: 0.5061
# Epoch 95: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7077 - accuracy: 0.5085 - val_loss: 0.7225 - val_accuracy: 0.5062
# Epoch 96/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5213
# Epoch 96: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7075 - accuracy: 0.5191 - val_loss: 0.7228 - val_accuracy: 0.5093
# Epoch 97/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5145
# Epoch 97: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7082 - accuracy: 0.5137 - val_loss: 0.7234 - val_accuracy: 0.5171
# Epoch 98/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7076 - accuracy: 0.5144
# Epoch 98: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7081 - accuracy: 0.5165 - val_loss: 0.7220 - val_accuracy: 0.5093
# Epoch 99/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7076 - accuracy: 0.5099
# Epoch 99: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7076 - accuracy: 0.5099 - val_loss: 0.7250 - val_accuracy: 0.5047
# Epoch 100/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.5166
# Epoch 100: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7078 - accuracy: 0.5160 - val_loss: 0.7217 - val_accuracy: 0.5186
# Epoch 101/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.5096
# Epoch 101: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7081 - accuracy: 0.5099 - val_loss: 0.7239 - val_accuracy: 0.5078
# Epoch 102/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7063 - accuracy: 0.5180
# Epoch 102: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7077 - accuracy: 0.5179 - val_loss: 0.7214 - val_accuracy: 0.5047
# Epoch 103/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7080 - accuracy: 0.5214
# Epoch 103: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7087 - accuracy: 0.5208 - val_loss: 0.7248 - val_accuracy: 0.4829
# Epoch 104/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7078 - accuracy: 0.5133
# Epoch 104: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5148 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 105/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7091 - accuracy: 0.5135
# Epoch 105: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7087 - accuracy: 0.5123 - val_loss: 0.7237 - val_accuracy: 0.5093
# Epoch 106/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7080 - accuracy: 0.5159
# Epoch 106: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7070 - accuracy: 0.5153 - val_loss: 0.7252 - val_accuracy: 0.4829
# Epoch 107/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5166
# Epoch 107: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5158 - val_loss: 0.7229 - val_accuracy: 0.4845
# Epoch 108/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7081 - accuracy: 0.5128
# Epoch 108: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7076 - accuracy: 0.5120 - val_loss: 0.7242 - val_accuracy: 0.4829
# Epoch 109/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7089 - accuracy: 0.5173
# Epoch 109: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7089 - accuracy: 0.5151 - val_loss: 0.7233 - val_accuracy: 0.5078
# Epoch 110/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5160
# Epoch 110: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7075 - accuracy: 0.5165 - val_loss: 0.7263 - val_accuracy: 0.4829
# Epoch 111/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.5145
# Epoch 111: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5148 - val_loss: 0.7224 - val_accuracy: 0.5171
# Epoch 112/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7082 - accuracy: 0.5145
# Epoch 112: loss did not improve from 0.70695
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7073 - accuracy: 0.5144 - val_loss: 0.7226 - val_accuracy: 0.5248
# Epoch 113/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5221
# Epoch 113: loss improved from 0.70695 to 0.70636, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7064 - accuracy: 0.5198 - val_loss: 0.7258 - val_accuracy: 0.5047
# Epoch 114/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5177
# Epoch 114: loss did not improve from 0.70636
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7069 - accuracy: 0.5174 - val_loss: 0.7212 - val_accuracy: 0.4984
# Epoch 115/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5190
# Epoch 115: loss improved from 0.70636 to 0.70625, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7062 - accuracy: 0.5193 - val_loss: 0.7215 - val_accuracy: 0.5031
# Epoch 116/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7064 - accuracy: 0.5172
# Epoch 116: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7065 - accuracy: 0.5165 - val_loss: 0.7220 - val_accuracy: 0.4984
# Epoch 117/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5168
# Epoch 117: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7066 - accuracy: 0.5168 - val_loss: 0.7229 - val_accuracy: 0.5280
# Epoch 118/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5079
# Epoch 118: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7068 - accuracy: 0.5084 - val_loss: 0.7237 - val_accuracy: 0.5093
# Epoch 119/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5218
# Epoch 119: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7071 - accuracy: 0.5203 - val_loss: 0.7243 - val_accuracy: 0.5031
# Epoch 120/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7049 - accuracy: 0.5229
# Epoch 120: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7072 - accuracy: 0.5241 - val_loss: 0.7259 - val_accuracy: 0.4876
# Epoch 121/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7068 - accuracy: 0.5117
# Epoch 121: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7069 - accuracy: 0.5136 - val_loss: 0.7246 - val_accuracy: 0.5047
# Epoch 122/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.5172
# Epoch 122: loss did not improve from 0.70625
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5172 - val_loss: 0.7219 - val_accuracy: 0.5124
# Epoch 123/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7069 - accuracy: 0.5202
# Epoch 123: loss improved from 0.70625 to 0.70614, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5189 - val_loss: 0.7251 - val_accuracy: 0.4907
# Epoch 124/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5193
# Epoch 124: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.5193 - val_loss: 0.7247 - val_accuracy: 0.5109
# Epoch 125/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5268
# Epoch 125: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7064 - accuracy: 0.5263 - val_loss: 0.7241 - val_accuracy: 0.5078
# Epoch 126/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7060 - accuracy: 0.5194
# Epoch 126: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5194 - val_loss: 0.7257 - val_accuracy: 0.5078
# Epoch 127/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5177
# Epoch 127: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7068 - accuracy: 0.5168 - val_loss: 0.7254 - val_accuracy: 0.4922
# Epoch 128/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7076 - accuracy: 0.5102
# Epoch 128: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7071 - accuracy: 0.5115 - val_loss: 0.7283 - val_accuracy: 0.4876
# Epoch 129/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7087 - accuracy: 0.5124
# Epoch 129: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7083 - accuracy: 0.5111 - val_loss: 0.7230 - val_accuracy: 0.5062
# Epoch 130/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.5205
# Epoch 130: loss did not improve from 0.70614
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7068 - accuracy: 0.5206 - val_loss: 0.7222 - val_accuracy: 0.5016
# Epoch 131/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5198
# Epoch 131: loss improved from 0.70614 to 0.70581, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 2s 8ms/step - loss: 0.7058 - accuracy: 0.5198 - val_loss: 0.7263 - val_accuracy: 0.5016
# Epoch 132/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7060 - accuracy: 0.5079
# Epoch 132: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7066 - accuracy: 0.5099 - val_loss: 0.7232 - val_accuracy: 0.5217
# Epoch 133/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5210
# Epoch 133: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7060 - accuracy: 0.5205 - val_loss: 0.7231 - val_accuracy: 0.4876
# Epoch 134/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7051 - accuracy: 0.5218
# Epoch 134: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5217 - val_loss: 0.7235 - val_accuracy: 0.5264
# Epoch 135/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5233
# Epoch 135: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5231 - val_loss: 0.7244 - val_accuracy: 0.5062
# Epoch 136/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5256
# Epoch 136: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5267 - val_loss: 0.7229 - val_accuracy: 0.5311
# Epoch 137/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5184
# Epoch 137: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5182 - val_loss: 0.7224 - val_accuracy: 0.5062
# Epoch 138/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5204
# Epoch 138: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7060 - accuracy: 0.5210 - val_loss: 0.7237 - val_accuracy: 0.4922
# Epoch 139/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7080 - accuracy: 0.5163
# Epoch 139: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.5163 - val_loss: 0.7234 - val_accuracy: 0.5078
# Epoch 140/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7052 - accuracy: 0.5256
# Epoch 140: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5220 - val_loss: 0.7230 - val_accuracy: 0.5248
# Epoch 141/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.5196
# Epoch 141: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.5196 - val_loss: 0.7274 - val_accuracy: 0.5233
# Epoch 142/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7054 - accuracy: 0.5210
# Epoch 142: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5184 - val_loss: 0.7228 - val_accuracy: 0.4984
# Epoch 143/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5248
# Epoch 143: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7060 - accuracy: 0.5244 - val_loss: 0.7238 - val_accuracy: 0.4922
# Epoch 144/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5075
# Epoch 144: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7061 - accuracy: 0.5077 - val_loss: 0.7227 - val_accuracy: 0.4922
# Epoch 145/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7070 - accuracy: 0.5203
# Epoch 145: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7067 - accuracy: 0.5215 - val_loss: 0.7261 - val_accuracy: 0.5062
# Epoch 146/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.5210
# Epoch 146: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7064 - accuracy: 0.5210 - val_loss: 0.7250 - val_accuracy: 0.5078
# Epoch 147/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.5194
# Epoch 147: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7063 - accuracy: 0.5205 - val_loss: 0.7219 - val_accuracy: 0.5078
# Epoch 148/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.5149
# Epoch 148: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5149 - val_loss: 0.7208 - val_accuracy: 0.5078
# Epoch 149/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7044 - accuracy: 0.5177
# Epoch 149: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5177 - val_loss: 0.7208 - val_accuracy: 0.5124
# Epoch 150/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.5171
# Epoch 150: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5165 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 151/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7066 - accuracy: 0.5146
# Epoch 151: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5151 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 152/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.5189
# Epoch 152: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5189 - val_loss: 0.7209 - val_accuracy: 0.5078
# Epoch 153/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5182
# Epoch 153: loss did not improve from 0.70581
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7059 - accuracy: 0.5179 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 154/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.5224
# Epoch 154: loss improved from 0.70581 to 0.70523, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7052 - accuracy: 0.5224 - val_loss: 0.7250 - val_accuracy: 0.5078
# Epoch 155/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7065 - accuracy: 0.5205
# Epoch 155: loss did not improve from 0.70523
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5206 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 156/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5254
# Epoch 156: loss did not improve from 0.70523
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7059 - accuracy: 0.5243 - val_loss: 0.7231 - val_accuracy: 0.5280
# Epoch 157/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.5161
# Epoch 157: loss did not improve from 0.70523
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7062 - accuracy: 0.5151 - val_loss: 0.7221 - val_accuracy: 0.5093
# Epoch 158/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5216
# Epoch 158: loss did not improve from 0.70523
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7063 - accuracy: 0.5212 - val_loss: 0.7212 - val_accuracy: 0.5264
# Epoch 159/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7112 - accuracy: 0.5217
# ...
# Epoch 244/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5244
# Epoch 244: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7052 - accuracy: 0.5243 - val_loss: 0.7258 - val_accuracy: 0.5078
# Epoch 245/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7060 - accuracy: 0.5217
# Epoch 245: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7053 - accuracy: 0.5208 - val_loss: 0.7227 - val_accuracy: 0.5078
# Epoch 246/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7097 - accuracy: 0.5230
# Epoch 246: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7095 - accuracy: 0.5220 - val_loss: 0.7246 - val_accuracy: 0.5171
# Epoch 247/300
# 170/181 [===========================>..] - ETA: 0s - loss: 0.7051 - accuracy: 0.5233
# Epoch 247: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7061 - accuracy: 0.5225 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 248/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7057 - accuracy: 0.5221
# Epoch 248: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5236 - val_loss: 0.7214 - val_accuracy: 0.4938
# Epoch 249/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5241
# Epoch 249: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7053 - accuracy: 0.5231 - val_loss: 0.7233 - val_accuracy: 0.4922
# Epoch 250/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7054 - accuracy: 0.5176
# Epoch 250: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7053 - accuracy: 0.5174 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 251/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5269
# Epoch 251: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5269 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 252/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5225
# Epoch 252: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5222 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 253/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5258
# Epoch 253: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5275 - val_loss: 0.7221 - val_accuracy: 0.4922
# Epoch 254/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5239
# Epoch 254: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7049 - accuracy: 0.5241 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 255/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7058 - accuracy: 0.5210
# Epoch 255: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7064 - accuracy: 0.5212 - val_loss: 0.7244 - val_accuracy: 0.5078
# Epoch 256/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.5179
# Epoch 256: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5179 - val_loss: 0.7233 - val_accuracy: 0.5109
# Epoch 257/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.5232
# Epoch 257: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5244 - val_loss: 0.7238 - val_accuracy: 0.4922
# Epoch 258/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.5243
# Epoch 258: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7050 - accuracy: 0.5258 - val_loss: 0.7243 - val_accuracy: 0.4907
# Epoch 259/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5221
# Epoch 259: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7068 - accuracy: 0.5222 - val_loss: 0.7270 - val_accuracy: 0.5186
# Epoch 260/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.5229
# Epoch 260: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7063 - accuracy: 0.5227 - val_loss: 0.7219 - val_accuracy: 0.5078
# Epoch 261/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.5224
# Epoch 261: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7053 - accuracy: 0.5224 - val_loss: 0.7226 - val_accuracy: 0.5171
# Epoch 262/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5215
# Epoch 262: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5203 - val_loss: 0.7231 - val_accuracy: 0.5078
# Epoch 263/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5161
# Epoch 263: loss did not improve from 0.70486
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5163 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 264/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7055 - accuracy: 0.5177
# Epoch 264: loss improved from 0.70486 to 0.70472, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7047 - accuracy: 0.5191 - val_loss: 0.7227 - val_accuracy: 0.5264
# Epoch 265/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7069 - accuracy: 0.5172
# Epoch 265: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7064 - accuracy: 0.5170 - val_loss: 0.7308 - val_accuracy: 0.5078
# Epoch 266/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5239
# Epoch 266: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7048 - accuracy: 0.5244 - val_loss: 0.7224 - val_accuracy: 0.5031
# Epoch 267/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5248
# Epoch 267: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7051 - accuracy: 0.5250 - val_loss: 0.7235 - val_accuracy: 0.5078
# Epoch 268/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.5253
# Epoch 268: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5262 - val_loss: 0.7231 - val_accuracy: 0.5078
# Epoch 269/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7044 - accuracy: 0.5231
# Epoch 269: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.5213 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 270/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5251
# Epoch 270: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7048 - accuracy: 0.5239 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 271/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5270
# Epoch 271: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5263 - val_loss: 0.7226 - val_accuracy: 0.4984
# Epoch 272/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.5169
# Epoch 272: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7050 - accuracy: 0.5180 - val_loss: 0.7228 - val_accuracy: 0.4922
# Epoch 273/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5260
# Epoch 273: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7051 - accuracy: 0.5244 - val_loss: 0.7229 - val_accuracy: 0.4922
# Epoch 274/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5197
# Epoch 274: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7051 - accuracy: 0.5187 - val_loss: 0.7221 - val_accuracy: 0.4922
# Epoch 275/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.5226
# Epoch 275: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 6ms/step - loss: 0.7048 - accuracy: 0.5244 - val_loss: 0.7227 - val_accuracy: 0.5171
# Epoch 276/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5219
# Epoch 276: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7048 - accuracy: 0.5213 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 277/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.5176
# Epoch 277: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5163 - val_loss: 0.7221 - val_accuracy: 0.5155
# Epoch 278/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7062 - accuracy: 0.5194
# Epoch 278: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7056 - accuracy: 0.5203 - val_loss: 0.7228 - val_accuracy: 0.4984
# Epoch 279/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7053 - accuracy: 0.5252
# Epoch 279: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5255 - val_loss: 0.7220 - val_accuracy: 0.5078
# Epoch 280/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5266
# Epoch 280: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7049 - accuracy: 0.5250 - val_loss: 0.7223 - val_accuracy: 0.5264
# Epoch 281/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7050 - accuracy: 0.5224
# Epoch 281: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5222 - val_loss: 0.7222 - val_accuracy: 0.4984
# Epoch 282/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.5206
# Epoch 282: loss did not improve from 0.70472
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7049 - accuracy: 0.5198 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 283/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7031 - accuracy: 0.5238
# Epoch 283: loss improved from 0.70472 to 0.70471, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7047 - accuracy: 0.5239 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 284/300
# 172/181 [===========================>..] - ETA: 0s - loss: 0.7038 - accuracy: 0.5205
# Epoch 284: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7049 - accuracy: 0.5229 - val_loss: 0.7225 - val_accuracy: 0.5078
# Epoch 285/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7056 - accuracy: 0.5196
# Epoch 285: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7049 - accuracy: 0.5234 - val_loss: 0.7223 - val_accuracy: 0.5078
# Epoch 286/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7045 - accuracy: 0.5260
# Epoch 286: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7055 - accuracy: 0.5250 - val_loss: 0.7221 - val_accuracy: 0.5078
# Epoch 287/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7058 - accuracy: 0.5241
# Epoch 287: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7048 - accuracy: 0.5236 - val_loss: 0.7223 - val_accuracy: 0.5062
# Epoch 288/300
# 173/181 [===========================>..] - ETA: 0s - loss: 0.7059 - accuracy: 0.5253
# Epoch 288: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7051 - accuracy: 0.5244 - val_loss: 0.7218 - val_accuracy: 0.5078
# Epoch 289/300
# 171/181 [===========================>..] - ETA: 0s - loss: 0.7040 - accuracy: 0.5192
# Epoch 289: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7050 - accuracy: 0.5194 - val_loss: 0.7224 - val_accuracy: 0.5078
# Epoch 290/300
# 178/181 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.5226
# Epoch 290: loss did not improve from 0.70471
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7051 - accuracy: 0.5225 - val_loss: 0.7227 - val_accuracy: 0.4984
# Epoch 291/300
# 175/181 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.5234
# Epoch 291: loss improved from 0.70471 to 0.70455, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7046 - accuracy: 0.5232 - val_loss: 0.7228 - val_accuracy: 0.5078
# Epoch 292/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5256
# Epoch 292: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7046 - accuracy: 0.5258 - val_loss: 0.7238 - val_accuracy: 0.5078
# Epoch 293/300
# 176/181 [============================>.] - ETA: 0s - loss: 0.7067 - accuracy: 0.5210
# Epoch 293: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.5218 - val_loss: 0.7263 - val_accuracy: 0.5078
# Epoch 294/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5197
# Epoch 294: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7053 - accuracy: 0.5201 - val_loss: 0.7229 - val_accuracy: 0.5078
# Epoch 295/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.5179
# Epoch 295: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7058 - accuracy: 0.5179 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 296/300
# 181/181 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5161
# Epoch 296: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7050 - accuracy: 0.5161 - val_loss: 0.7230 - val_accuracy: 0.5078
# Epoch 297/300
# 180/181 [============================>.] - ETA: 0s - loss: 0.7052 - accuracy: 0.5245
# Epoch 297: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7052 - accuracy: 0.5241 - val_loss: 0.7231 - val_accuracy: 0.4922
# Epoch 298/300
# 174/181 [===========================>..] - ETA: 0s - loss: 0.7044 - accuracy: 0.5273
# Epoch 298: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 5ms/step - loss: 0.7049 - accuracy: 0.5265 - val_loss: 0.7232 - val_accuracy: 0.5078
# Epoch 299/300
# 179/181 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.5297
# Epoch 299: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 7ms/step - loss: 0.7048 - accuracy: 0.5289 - val_loss: 0.7234 - val_accuracy: 0.5078
# Epoch 300/300
# 177/181 [============================>.] - ETA: 0s - loss: 0.7039 - accuracy: 0.5267
# Epoch 300: loss did not improve from 0.70455
# 181/181 [==============================] - 1s 8ms/step - loss: 0.7048 - accuracy: 0.5262 - val_loss: 0.7221 - val_accuracy: 0.5078

# %%
print(train_sh.history)
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(10)
# Out:
# {'loss': [2.2525668144226074, 1.0924394130706787, 0.9177595376968384, 0.8543021082878113, 0.8217580318450928, 0.7944280505180359, 0.7848669290542603, 0.7790402770042419, 0.7657651901245117, 0.7613561153411865, 0.7555058598518372, 0.7461755275726318, 0.7459767460823059, 0.7409022450447083, 0.7365943789482117, 0.7343546152114868, 0.7307803630828857, 0.7304882407188416, 0.7268712520599365, 0.726421594619751, 0.7225419878959656, 0.7258297801017761, 0.7254573702812195, 0.725142776966095, 0.7187331318855286, 0.7233347296714783, 0.7205422520637512, 0.7180302739143372, 0.7188964486122131, 0.7198005318641663, 0.7189074754714966, 0.7204810380935669, 0.7180870175361633, 0.7164600491523743, 0.7169163823127747, 0.7159678936004639, 0.7156093716621399, 0.7148979902267456, 0.7171545624732971, 0.716243326663971, 0.7157670259475708, 0.7140463590621948, 0.7146243453025818, 0.7140974402427673, 0.713026225566864, 0.7139077186584473, 0.7136828899383545, 0.7125711441040039, 0.7153477072715759, 0.7135556936264038, 0.7145895957946777, 0.7127084732055664, 0.7125922441482544, 0.7114862203598022, 0.7118284702301025, 0.710448145866394, 0.7110206484794617, 0.7132837176322937, 0.7108791470527649, 0.7101747393608093, 0.7102479338645935, 0.7121188640594482, 0.7103379368782043, 0.710316002368927, 0.7100239396095276, 0.7115195989608765, 0.7096629738807678, 0.709625244140625, 0.7098197937011719, 0.7097270488739014, 0.7095085978507996, 0.7093119621276855, 0.7088461518287659, 0.7093161344528198, 0.7096801400184631, 0.7087305784225464, 0.7101293206214905, 0.7091960906982422, 0.7087013125419617, 0.7090719938278198, 0.7094405889511108, 0.7086341977119446, 0.7077546119689941, 0.7088786363601685, 0.7080996632575989, 0.7086882591247559, 0.7085633873939514, 0.7069514989852905, 0.7073454856872559, 0.7079805731773376, 0.7084153294563293, 0.7078036665916443, 0.7079420685768127, 0.7078162431716919, 0.7077349424362183, 0.7074668407440186, 0.7081710696220398, 0.708101749420166, 0.7076193690299988, 0.7078346014022827, 0.708061158657074, 0.7076531052589417, 0.7086772322654724, 0.7072641253471375, 0.7087432146072388, 0.7070348858833313, 0.7072580456733704, 0.7076088190078735, 0.708899199962616, 0.7074816823005676, 0.707282543182373, 0.7073473334312439, 0.7063572406768799, 0.7068682909011841, 0.7062466740608215, 0.7065078020095825, 0.706646740436554, 0.7068220973014832, 0.7071393728256226, 0.7072480916976929, 0.7069475054740906, 0.7067229151725769, 0.7061441540718079, 0.7066550850868225, 0.7063559293746948, 0.7061970829963684, 0.7068206071853638, 0.7071191072463989, 0.708328127861023, 0.7067666053771973, 0.7058144211769104, 0.7066329717636108, 0.7060040831565857, 0.7060607671737671, 0.7061181664466858, 0.7058789134025574, 0.7060743570327759, 0.7060378789901733, 0.7079988121986389, 0.7061829566955566, 0.7065449953079224, 0.7067043781280518, 0.7059910297393799, 0.7061054706573486, 0.7066797614097595, 0.7063621282577515, 0.7062999606132507, 0.7061048746109009, 0.7060781717300415, 0.7058509588241577, 0.7062106728553772, 0.7061760425567627, 0.7059330344200134, 0.7052311897277832, 0.7058008313179016, 0.7058574557304382, 0.7061846852302551, 0.7063308358192444, 0.7100926637649536, 0.7078416347503662, 0.7060137391090393, 0.7060337662696838, 0.7056752443313599, 0.7063344120979309, 0.7058119177818298, 0.7060285210609436, 0.7055560946464539, 0.7058267593383789, 0.7054964303970337, 0.7058993577957153, 0.7056542038917542, 0.7058610320091248, 0.7056981921195984, 0.7059850096702576, 0.7049776315689087, 0.7058775424957275, 0.7056318521499634, 0.705460786819458, 0.7056671380996704, 0.7057573199272156, 0.7061388492584229, 0.7059803605079651, 0.7057396173477173, 0.7059831619262695, 0.7050628066062927, 0.7059777975082397, 0.7054124474525452, 0.7054405212402344, 0.7059347629547119, 0.7057241797447205, 0.705292284488678, 0.7059138417243958, 0.7055597305297852, 0.705597460269928, 0.7062485814094543, 0.7056999802589417, 0.7055960893630981, 0.7057155966758728, 0.705659806728363, 0.7056770920753479, 0.70552 ...
# 41/41 [==============================] - 0s 3ms/step - loss: 0.7221 - accuracy: 0.5078
# 21/21 [==============================] - 0s 2ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
# 3          3667        3493
# 4          5011        4837
# 5          4850        4676
# 6          3891        3717
# 7          1699        1525
# 8          2742        2568
# 9          1703        1529
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
# 3  Allow extensions code to be splitted in severa...
# 4  HdfsMongoDB Job failing due because of missing...
# 5  Rename controllers to have pluralized named (e...
# 6  Reproducing errors of the current obs_decam pa...
# 7                                   Week end 1/23/16
# 8  Ruby: Problem formatting Ruby source code wher...
# 9              Unify connectors and endpoints part 2
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
# 3  As described in the execution section of the s...     EST_BE        Medium
# 4  Looks to have been introduced by https://githu...     EST_BE        Medium
# 5  See implementation used for Steams and apply t...     EST_BE        Medium
# 6  Learning the stack and development worlflow by...     EST_BE        Medium
# 7  Support for lsst-dev cluster, OpenStack, and a...     EST_BE        Medium
# 8  ctrl-shift-f can't format source code of the a...     EST_BE        Medium
# 9  Need to finish implementation of https://docs....     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
# 3  INT Sprint 1                16               16          15  ...
# 4  INT Sprint 1                 6                6           5  ...
# 5  INT Sprint 1                 2                2           1  ...
# 6  INT Sprint 1                 4                5           3  ...
# 7  INT Sprint 1                 4                5           3  ...
# 8  INT Sprint 1                16               17          15  ...
# 9  INT Sprint 1                16               17          15  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
# 3             15.83                0.17         0.01                15.83
# 4              6.00                0.33         0.06                 6.00
# 5              1.83                0.17         0.09                 1.83
# 6              4.00                0.33         0.08                 4.00
# 7              3.83                0.17         0.04                 3.83
# 8             16.00                0.33         0.02                16.00
# 9             16.00                0.33         0.02                16.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
# 3            15.92              16.05               16.23              15
# 4             6.17               6.42                6.77               6
# 5             1.92               2.05                2.23               1
# 6             4.17               4.42                4.77               4
# 7             3.92               4.05                4.23               3
# 8            16.17              16.42               16.77              16
# 9            16.17              16.42               16.77              16
#
#    Variance  Ai_estimate
# 0      6561           17
# 1       441            4
# 2       729            4
# 3      6561           17
# 4      1369            7
# 5       121            3
# 6       729            4
# 7       441            4
# 8      7569           16
# 9      7569           16
#
# [10 rows x 22 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  Weighted_average  Standard_deviation  Risk_factor  \
# 0           16             15.83                0.17         0.01
# 1            4              3.83                0.17         0.04
# 2            5              4.00                0.33         0.08
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                15.83            15.92              16.05
# 1                 3.83             3.92               4.05
# 2                 4.00             4.17               4.42
#
#    Highest_confidence  Final_estimate  Variance  Ai_estimate
# 0               16.23              15      6561           17
# 1                4.23               3       441            4
# 2                4.77               4       729            4

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/Model6_3_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            8
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.67                0.00         0.00
# 1  ...              4.83                0.17         0.04
# 2  ...              8.33                0.33         0.04
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.67            16.67              16.67
# 1                 4.83             4.92               5.05
# 2                 8.33             8.50               8.75
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               16.67              16      6400                0
# 1                5.23               4       676                4
# 2                9.10               8      2704                4
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)

# %%
import tensorflow as tf

# %%
model6 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/model6_3.h5')
model6.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  dense_8 (Dense)             (None, 256)                  196864    ['input_layer_1[0][0]']
#
#  dense_9 (Dense)             (None, 256)                  196864    ['input_layer_2[0][0]']
#
#  dense_10 (Dense)            (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_11 (Dense)            (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_12 (Dense)            (None, 32)                   928       ['input_layer_5[0][0]']
#
#  concatenate_1 (Concatenate  (None, 564)                  0         ['dense_8[0][0]',
#  )                                                                   'dense_9[0][0]',
#                                                                      'dense_10[0][0]',
#                                                                      'dense_11[0][0]',
#                                                                      'dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 384)                  216960    ['concatenate_1[0][0]']
#
#  dense_14 (Dense)            (None, 128)                  49280     ['dense_13[0][0]']
#
#  dense_15 (Dense)            (None, 26)                   3354      ['dense_14[0][0]']
#
# ==================================================================================================
# Total params: 664526 (2.53 MB)
# Trainable params: 664526 (2.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model6.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 96ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model6/model6_3/Model6_3results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            5
# 2   ET Sprint 4                 8                9           8            8
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           16  ...                0.00         0.00                16.67
# 1            5  ...                0.17         0.04                 4.83
# 2           10  ...                0.33         0.04                 8.33
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.67              16.67               16.67              16
# 1             4.92               5.05                5.23               4
# 2             8.50               8.75                9.10               8
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      6400                0           16
# 1       676                4            4
# 2      2704                4            8
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
