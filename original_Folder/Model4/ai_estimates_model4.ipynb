# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import glob
import pandas as pd
import random

# %% [markdown]
# # **Read Dataset**

# %%
train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

# %%
# Multiplying risk factor by 100 to make it an integer

# %%
test_df_res["Risk_factor_int"] = (test_df_res["Risk_factor"]*100).astype(int)

# %%
train_df_res["Risk_factor_int"] = (train_df_res["Risk_factor"]*100).astype(int)

# %%
test_df_res.shape
# Out:
# (644, 22)

# %%
train_df_res.shape
# Out:
# (5791, 22)

# %%
test_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0             15.83                0.17         0.01                15.83
# 1              3.83                0.17         0.04                 3.83
# 2              4.00                0.33         0.08                 4.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
#
#    Variance  Risk_factor_int
# 0      6561                1
# 1       441                4
# 2       729                8
#
# [3 rows x 22 columns]

# %%
train_df_res.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2577        2403
# 1          3433        3259
# 2          3011        2837
#
#                                            Task_name  \
# 0             Document OOTB available ${xd.???} keys
# 1  xd-container should start even if xd-admin is ...
# 2  Allow easier detection when hook signature cha...
#
#                                     Task_description Task_label Task_priority  \
# 0  As a consequence of not fixing XD-1289, we sho...     EST_BE        Medium
# 1  currently xd-container will not start due to a...     EST_BE        Medium
# 2  Currently, if the signature of a hook function...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                 8                9           7  ...
# 1  INT Sprint 1                 4                4           3  ...
# 2  INT Sprint 1                 4                5           3  ...
#
#    Weighted_average  Standard_deviation  Risk_factor  Standard_confidence  \
# 0              8.00                0.33         0.04                 8.00
# 1              4.00                0.33         0.08                 4.00
# 2              3.83                0.17         0.04                 3.83
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0             8.17               8.42                8.77               8
# 1             4.17               4.42                4.77               4
# 2             3.92               4.05                4.23               3
#
#    Variance  Risk_factor_int
# 0      2209                4
# 1       729                8
# 2       441                4
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **One Hot Encoding**

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %% [markdown]
# Features

# %%
#Task_label
tl_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
tl_train = train_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_test = test_df_res["Task_label"].to_numpy().reshape(-1,1)
tl_enc.fit(tl_train)
len_tl_enc = tl_enc.categories_[0].shape
print(len_tl_enc)

tl_train = tl_enc.transform(tl_train)
tl_test = tl_enc.transform(tl_test)
print(tl_train.shape, tl_test.shape)
# Out:
# (4,)
# (5791, 4) (644, 4)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Planned_estimate
pe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
pe_train = train_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_test = test_df_res["Planned_estimate"].to_numpy().reshape(-1,1)
pe_enc.fit(pe_train)
len_pe_enc = pe_enc.categories_[0].shape
print(len_pe_enc)

pe_train = pe_enc.transform(pe_train)
pe_test = pe_enc.transform(pe_test)
print(pe_train.shape, pe_test.shape)
# Out:
# (15,)
# (5791, 15) (644, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Final_estimate
fe_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
fe_train = train_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_test = test_df_res["Final_estimate"].to_numpy().reshape(-1,1)
fe_enc.fit(fe_train)
len_fe_enc = fe_enc.categories_[0].shape
print(len_fe_enc)

fe_train = fe_enc.transform(fe_train)
fe_test = fe_enc.transform(fe_test)
print(fe_train.shape, fe_test.shape)
# Out:
# (28,)
# (5791, 28) (644, 28)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Risk_factor_int
rfi_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
rfi_train = train_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_test = test_df_res["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_enc.fit(rfi_train)
len_rfi_enc = rfi_enc.categories_[0].shape
print(len_rfi_enc)

rfi_train = rfi_enc.transform(rfi_train)
rfi_test = rfi_enc.transform(rfi_test)
print(rfi_train.shape, rfi_test.shape)
# Out:
# (11,)
# (5791, 11) (644, 11)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Label

# %%
#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## **Gpt-2 tokenizer & pre-trained model**

# %%
import tensorflow as tf

# %%
from transformers import GPT2Tokenizer, TFGPT2Model

# %%
class GPT:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = TFGPT2Model.from_pretrained('gpt2')

    def inp_vector(self, inp):
        encoded_inp = self.tokenizer(inp, return_tensors='tf')
        out = self.model(encoded_inp)
        vector = out[0].numpy()[0]
        return np.mean(vector, axis=0)

    def vectors(self, inps):
        feat_vectors = []
        for i in inps:
            if type(i) != 'str':
                i = "NA"
            feat_vectors.append(self.inp_vector(i))
        return np.array(feat_vectors)

gpt_model = GPT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2Model.
#
# All the weights of TFGPT2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %% [markdown]
# ## **Features Encoding**

# %%
# No need to calculate embeddings again if dataset is not changed. Load embeddings from below

# %% [markdown]
# Task Name

# %%
# training embeddings
tn_train = gpt_model.vectors(train_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy', tn_train)
print(type(tn_train))
print(tn_train.shape)

# %%
# testing embeddings
tn_test = gpt_model.vectors(test_df_res["Task_name"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy', tn_test)
print(type(tn_test))
print(tn_test.shape)

# %% [markdown]
# Task description

# %%
# training embeddings
td_train = gpt_model.vectors(train_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy', td_train)
print(type(td_train))
print(td_train.shape)

# %%
# testing embeddings
td_test = gpt_model.vectors(test_df_res["Task_description"])
np.save('../drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy', td_test)
print(type(td_test))
print(td_test.shape)

# %% [markdown]
# ## Load features

# %%
# Use this one

# %%
# Load feature encodings - Task name, task description, task label, planned estimate & final estimate
tn_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_train.npy')
tn_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_name_test.npy')

td_train = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_train.npy')
td_test = np.load('drive/MyDrive/Colab Notebooks/Estimates/task_desc_test.npy')

# %% [markdown]
# ## **Define NN Architecture**

# %%
# Branch-1 Task name
inp1 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_1")
lay1 = tf.keras.layers.Dense(128, activation='relu')(inp1)

# Branch-2 Task description
inp2 = tf.keras.Input(shape=(768,), dtype=tf.int32, name="input_layer_2")
lay2 = tf.keras.layers.Dense(128, activation='relu')(inp2)

# Branch-3 Task label
inp3 = tf.keras.Input(shape=(4,), dtype=tf.int32, name="input_layer_3")
lay3 = tf.keras.layers.Dense(4, activation='relu')(inp3)

# Branch-4 Planned estimate
inp4 = tf.keras.Input(shape=(15,), dtype=tf.int32, name="input_layer_4")
lay4 = tf.keras.layers.Dense(16, activation='relu')(inp4)

# Branch-5 Final estimate
inp5 = tf.keras.Input(shape=(28,), dtype=tf.int32, name="input_layer_5")
lay5 = tf.keras.layers.Dense(32, activation='relu')(inp5)

# Branch-6 Risk Factor multiplied by 100
inp6 = tf.keras.Input(shape=(11,), dtype=tf.int32, name="input_layer_6")
lay6 = tf.keras.layers.Dense(16, activation='relu')(inp6)

# Concatenate Branch
out = tf.keras.layers.Concatenate()([lay1, lay2, lay3, lay4, lay5, lay6])
out = tf.keras.layers.Dense(384, activation='relu')(out)
out = tf.keras.layers.Dense(128, activation='relu')(out)
out = tf.keras.layers.Dense(26, activation='softmax')(out)

model = tf.keras.models.Model(inputs=[inp1, inp2, inp3, inp4, inp5, inp6], outputs=out)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  input_layer_6 (InputLayer)  [(None, 11)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   192       ['input_layer_6[0][0]']
#
#  concatenate (Concatenate)   (None, 324)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]',
#                                                                      'dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 384)                  124800    ['concatenate[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  49280     ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 26)                   3354      ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 375694 (1.43 MB)
# Trainable params: 375694 (1.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5', monitor='loss', save_best_only=True, verbose=1)

# %% [markdown]
# ## **Model Training**

# %%
train_sh = model.fit(
    [tn_train, td_train, tl_train, pe_train, fe_train, rfi_train], ae_train,
    epochs=100,
    callbacks=[checkpoint],
    validation_data=([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test], ae_test),
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 181/181 [==============================] - ETA: 0s - loss: 1.8700 - accuracy: 0.3588
# Epoch 1: loss improved from inf to 1.86999, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 181/181 [==============================] - 8s 33ms/step - loss: 1.8700 - accuracy: 0.3588 - val_loss: 1.0584 - val_accuracy: 0.4798
# Epoch 2/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.9714 - accuracy: 0.4965
# Epoch 2: loss improved from 1.86999 to 0.97064, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 19ms/step - loss: 0.9706 - accuracy: 0.4966 - val_loss: 0.9136 - val_accuracy: 0.4736
# Epoch 3/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8798 - accuracy: 0.4908
# Epoch 3: loss improved from 0.97064 to 0.87976, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 14ms/step - loss: 0.8798 - accuracy: 0.4908 - val_loss: 0.8689 - val_accuracy: 0.5109
# Epoch 4/100
# 181/181 [==============================] - ETA: 0s - loss: 0.8294 - accuracy: 0.4951
# Epoch 4: loss improved from 0.87976 to 0.82938, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.8294 - accuracy: 0.4951 - val_loss: 0.8090 - val_accuracy: 0.4984
# Epoch 5/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.7939 - accuracy: 0.5080
# Epoch 5: loss improved from 0.82938 to 0.79405, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7940 - accuracy: 0.5079 - val_loss: 0.8130 - val_accuracy: 0.4860
# Epoch 6/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.5022
# Epoch 6: loss improved from 0.79405 to 0.77630, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.7763 - accuracy: 0.5022 - val_loss: 0.7680 - val_accuracy: 0.5186
# Epoch 7/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7610 - accuracy: 0.5070
# Epoch 7: loss improved from 0.77630 to 0.76179, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 18ms/step - loss: 0.7618 - accuracy: 0.5066 - val_loss: 0.7659 - val_accuracy: 0.5248
# Epoch 8/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7490 - accuracy: 0.5095
# Epoch 8: loss improved from 0.76179 to 0.74986, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.7499 - accuracy: 0.5098 - val_loss: 0.7930 - val_accuracy: 0.5000
# Epoch 9/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7462 - accuracy: 0.5004
# Epoch 9: loss improved from 0.74986 to 0.74627, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7463 - accuracy: 0.4997 - val_loss: 0.7393 - val_accuracy: 0.5078
# Epoch 10/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7282 - accuracy: 0.5162
# Epoch 10: loss improved from 0.74627 to 0.72727, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7273 - accuracy: 0.5165 - val_loss: 0.7476 - val_accuracy: 0.5016
# Epoch 11/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.5125
# Epoch 11: loss did not improve from 0.72727
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7279 - accuracy: 0.5125 - val_loss: 0.7412 - val_accuracy: 0.4891
# Epoch 12/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7210 - accuracy: 0.5112
# Epoch 12: loss improved from 0.72727 to 0.72064, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7206 - accuracy: 0.5117 - val_loss: 0.7196 - val_accuracy: 0.5062
# Epoch 13/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.5061
# Epoch 13: loss improved from 0.72064 to 0.71542, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.7154 - accuracy: 0.5061 - val_loss: 0.7286 - val_accuracy: 0.5264
# Epoch 14/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.7121 - accuracy: 0.5103
# Epoch 14: loss improved from 0.71542 to 0.71225, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 17ms/step - loss: 0.7123 - accuracy: 0.5098 - val_loss: 0.7342 - val_accuracy: 0.4907
# Epoch 15/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.5216
# Epoch 15: loss improved from 0.71225 to 0.70667, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.7067 - accuracy: 0.5222 - val_loss: 0.7200 - val_accuracy: 0.5078
# Epoch 16/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.7051 - accuracy: 0.5071
# Epoch 16: loss improved from 0.70667 to 0.70531, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7053 - accuracy: 0.5054 - val_loss: 0.7182 - val_accuracy: 0.5124
# Epoch 17/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.7018 - accuracy: 0.5156
# Epoch 17: loss improved from 0.70531 to 0.70149, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.7015 - accuracy: 0.5155 - val_loss: 0.7110 - val_accuracy: 0.5186
# Epoch 18/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.7004 - accuracy: 0.5254
# Epoch 18: loss improved from 0.70149 to 0.70041, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.7004 - accuracy: 0.5251 - val_loss: 0.7048 - val_accuracy: 0.5078
# Epoch 19/100
# 181/181 [==============================] - ETA: 0s - loss: 0.7018 - accuracy: 0.5158
# Epoch 19: loss did not improve from 0.70041
# 181/181 [==============================] - 2s 9ms/step - loss: 0.7018 - accuracy: 0.5158 - val_loss: 0.7147 - val_accuracy: 0.5155
# Epoch 20/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6963 - accuracy: 0.5198
# Epoch 20: loss improved from 0.70041 to 0.69651, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6965 - accuracy: 0.5196 - val_loss: 0.7029 - val_accuracy: 0.5140
# Epoch 21/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6967 - accuracy: 0.5135
# Epoch 21: loss improved from 0.69651 to 0.69647, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6965 - accuracy: 0.5136 - val_loss: 0.7157 - val_accuracy: 0.4767
# Epoch 22/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6936 - accuracy: 0.5196
# Epoch 22: loss improved from 0.69647 to 0.69367, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6937 - accuracy: 0.5198 - val_loss: 0.7036 - val_accuracy: 0.5295
# Epoch 23/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6949 - accuracy: 0.5126
# Epoch 23: loss did not improve from 0.69367
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6953 - accuracy: 0.5103 - val_loss: 0.7120 - val_accuracy: 0.4798
# Epoch 24/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5269
# Epoch 24: loss improved from 0.69367 to 0.69302, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6930 - accuracy: 0.5270 - val_loss: 0.7074 - val_accuracy: 0.4829
# Epoch 25/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6918 - accuracy: 0.5154
# Epoch 25: loss improved from 0.69302 to 0.69137, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6914 - accuracy: 0.5170 - val_loss: 0.7092 - val_accuracy: 0.5171
# Epoch 26/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6928 - accuracy: 0.5230
# Epoch 26: loss did not improve from 0.69137
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6926 - accuracy: 0.5227 - val_loss: 0.7109 - val_accuracy: 0.5124
# Epoch 27/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6931 - accuracy: 0.5128
# Epoch 27: loss did not improve from 0.69137
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6930 - accuracy: 0.5127 - val_loss: 0.6954 - val_accuracy: 0.5373
# Epoch 28/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6911 - accuracy: 0.5092
# Epoch 28: loss improved from 0.69137 to 0.69064, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 5s 26ms/step - loss: 0.6906 - accuracy: 0.5094 - val_loss: 0.7084 - val_accuracy: 0.4876
# Epoch 29/100
# 175/181 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.5168
# Epoch 29: loss did not improve from 0.69064
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6928 - accuracy: 0.5161 - val_loss: 0.7060 - val_accuracy: 0.5016
# Epoch 30/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6917 - accuracy: 0.5087
# Epoch 30: loss did not improve from 0.69064
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6913 - accuracy: 0.5092 - val_loss: 0.7033 - val_accuracy: 0.4767
# Epoch 31/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.5217
# Epoch 31: loss improved from 0.69064 to 0.68794, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6879 - accuracy: 0.5217 - val_loss: 0.7074 - val_accuracy: 0.4891
# Epoch 32/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6886 - accuracy: 0.5161
# Epoch 32: loss did not improve from 0.68794
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6888 - accuracy: 0.5168 - val_loss: 0.7045 - val_accuracy: 0.4984
# Epoch 33/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6888 - accuracy: 0.5139
# Epoch 33: loss did not improve from 0.68794
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6883 - accuracy: 0.5144 - val_loss: 0.7051 - val_accuracy: 0.5078
# Epoch 34/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6889 - accuracy: 0.5108
# Epoch 34: loss did not improve from 0.68794
# 181/181 [==============================] - 3s 14ms/step - loss: 0.6889 - accuracy: 0.5108 - val_loss: 0.6992 - val_accuracy: 0.5217
# Epoch 35/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6852 - accuracy: 0.5210
# Epoch 35: loss improved from 0.68794 to 0.68504, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6850 - accuracy: 0.5208 - val_loss: 0.6976 - val_accuracy: 0.5062
# Epoch 36/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5089
# Epoch 36: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6869 - accuracy: 0.5089 - val_loss: 0.7007 - val_accuracy: 0.4767
# Epoch 37/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.5130
# Epoch 37: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6876 - accuracy: 0.5130 - val_loss: 0.6980 - val_accuracy: 0.5155
# Epoch 38/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6868 - accuracy: 0.5218
# Epoch 38: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6867 - accuracy: 0.5222 - val_loss: 0.7063 - val_accuracy: 0.4969
# Epoch 39/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6869 - accuracy: 0.5146
# Epoch 39: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6875 - accuracy: 0.5134 - val_loss: 0.6967 - val_accuracy: 0.4876
# Epoch 40/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5107
# Epoch 40: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6856 - accuracy: 0.5103 - val_loss: 0.6985 - val_accuracy: 0.5078
# Epoch 41/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6857 - accuracy: 0.5164
# Epoch 41: loss did not improve from 0.68504
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6855 - accuracy: 0.5161 - val_loss: 0.7101 - val_accuracy: 0.5202
# Epoch 42/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.5129
# Epoch 42: loss did not improve from 0.68504
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6867 - accuracy: 0.5129 - val_loss: 0.6927 - val_accuracy: 0.5031
# Epoch 43/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5178
# Epoch 43: loss did not improve from 0.68504
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6860 - accuracy: 0.5180 - val_loss: 0.6999 - val_accuracy: 0.4984
# Epoch 44/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6842 - accuracy: 0.5216
# Epoch 44: loss improved from 0.68504 to 0.68448, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6845 - accuracy: 0.5210 - val_loss: 0.6970 - val_accuracy: 0.4969
# Epoch 45/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6858 - accuracy: 0.5125
# Epoch 45: loss did not improve from 0.68448
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6858 - accuracy: 0.5125 - val_loss: 0.6978 - val_accuracy: 0.5295
# Epoch 46/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6861 - accuracy: 0.5125
# Epoch 46: loss did not improve from 0.68448
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6859 - accuracy: 0.5132 - val_loss: 0.6956 - val_accuracy: 0.5016
# Epoch 47/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6844 - accuracy: 0.5185
# Epoch 47: loss did not improve from 0.68448
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6845 - accuracy: 0.5187 - val_loss: 0.7035 - val_accuracy: 0.4876
# Epoch 48/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6847 - accuracy: 0.5095
# Epoch 48: loss improved from 0.68448 to 0.68403, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6840 - accuracy: 0.5117 - val_loss: 0.6953 - val_accuracy: 0.5311
# Epoch 49/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6853 - accuracy: 0.5132
# Epoch 49: loss did not improve from 0.68403
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6850 - accuracy: 0.5144 - val_loss: 0.6931 - val_accuracy: 0.5342
# Epoch 50/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6843 - accuracy: 0.5160
# Epoch 50: loss improved from 0.68403 to 0.68384, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6838 - accuracy: 0.5168 - val_loss: 0.6968 - val_accuracy: 0.5016
# Epoch 51/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.5176
# Epoch 51: loss improved from 0.68384 to 0.68308, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6831 - accuracy: 0.5180 - val_loss: 0.6917 - val_accuracy: 0.5404
# Epoch 52/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6835 - accuracy: 0.5166
# Epoch 52: loss did not improve from 0.68308
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6836 - accuracy: 0.5167 - val_loss: 0.6968 - val_accuracy: 0.5248
# Epoch 53/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6831 - accuracy: 0.5187
# Epoch 53: loss improved from 0.68308 to 0.68278, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6828 - accuracy: 0.5175 - val_loss: 0.6980 - val_accuracy: 0.5000
# Epoch 54/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6821 - accuracy: 0.5160
# Epoch 54: loss improved from 0.68278 to 0.68237, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6824 - accuracy: 0.5161 - val_loss: 0.6972 - val_accuracy: 0.5248
# Epoch 55/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6830 - accuracy: 0.5096
# Epoch 55: loss did not improve from 0.68237
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6829 - accuracy: 0.5101 - val_loss: 0.7006 - val_accuracy: 0.5031
# Epoch 56/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6823 - accuracy: 0.5141
# Epoch 56: loss improved from 0.68237 to 0.68233, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6823 - accuracy: 0.5141 - val_loss: 0.6934 - val_accuracy: 0.4969
# Epoch 57/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6832 - accuracy: 0.5105
# Epoch 57: loss did not improve from 0.68233
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6830 - accuracy: 0.5113 - val_loss: 0.6935 - val_accuracy: 0.5202
# Epoch 58/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6829 - accuracy: 0.5073
# Epoch 58: loss did not improve from 0.68233
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6829 - accuracy: 0.5073 - val_loss: 0.6962 - val_accuracy: 0.4907
# Epoch 59/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6811 - accuracy: 0.5201
# Epoch 59: loss improved from 0.68233 to 0.68103, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6810 - accuracy: 0.5205 - val_loss: 0.7000 - val_accuracy: 0.5280
# Epoch 60/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6823 - accuracy: 0.5199
# Epoch 60: loss did not improve from 0.68103
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6820 - accuracy: 0.5193 - val_loss: 0.7000 - val_accuracy: 0.4922
# Epoch 61/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6833 - accuracy: 0.5210
# Epoch 61: loss did not improve from 0.68103
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6832 - accuracy: 0.5213 - val_loss: 0.6925 - val_accuracy: 0.5233
# Epoch 62/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6824 - accuracy: 0.5138
# Epoch 62: loss did not improve from 0.68103
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6823 - accuracy: 0.5146 - val_loss: 0.6926 - val_accuracy: 0.5280
# Epoch 63/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6809 - accuracy: 0.5126
# Epoch 63: loss improved from 0.68103 to 0.68089, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6809 - accuracy: 0.5123 - val_loss: 0.6956 - val_accuracy: 0.5109
# Epoch 64/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6810 - accuracy: 0.5227
# Epoch 64: loss did not improve from 0.68089
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6810 - accuracy: 0.5227 - val_loss: 0.6960 - val_accuracy: 0.4876
# Epoch 65/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6814 - accuracy: 0.5109
# Epoch 65: loss improved from 0.68089 to 0.68075, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6808 - accuracy: 0.5111 - val_loss: 0.6938 - val_accuracy: 0.4876
# Epoch 66/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6816 - accuracy: 0.5103
# Epoch 66: loss did not improve from 0.68075
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6819 - accuracy: 0.5104 - val_loss: 0.6940 - val_accuracy: 0.5093
# Epoch 67/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.5139
# Epoch 67: loss did not improve from 0.68075
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6810 - accuracy: 0.5139 - val_loss: 0.6933 - val_accuracy: 0.5062
# Epoch 68/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6807 - accuracy: 0.5085
# Epoch 68: loss did not improve from 0.68075
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6811 - accuracy: 0.5099 - val_loss: 0.6961 - val_accuracy: 0.5000
# Epoch 69/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6798 - accuracy: 0.5180
# Epoch 69: loss improved from 0.68075 to 0.68063, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6806 - accuracy: 0.5160 - val_loss: 0.6950 - val_accuracy: 0.5202
# Epoch 70/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6805 - accuracy: 0.5195
# Epoch 70: loss did not improve from 0.68063
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6807 - accuracy: 0.5196 - val_loss: 0.6949 - val_accuracy: 0.5093
# Epoch 71/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6811 - accuracy: 0.5099
# Epoch 71: loss did not improve from 0.68063
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6811 - accuracy: 0.5099 - val_loss: 0.6901 - val_accuracy: 0.5357
# Epoch 72/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.5210
# Epoch 72: loss did not improve from 0.68063
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6809 - accuracy: 0.5210 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 73/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.5158
# Epoch 73: loss improved from 0.68063 to 0.68012, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 13ms/step - loss: 0.6801 - accuracy: 0.5158 - val_loss: 0.6921 - val_accuracy: 0.5124
# Epoch 74/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6802 - accuracy: 0.5139
# Epoch 74: loss did not improve from 0.68012
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6804 - accuracy: 0.5136 - val_loss: 0.6910 - val_accuracy: 0.4907
# Epoch 75/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6804 - accuracy: 0.5166
# Epoch 75: loss did not improve from 0.68012
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6808 - accuracy: 0.5165 - val_loss: 0.6921 - val_accuracy: 0.4984
# Epoch 76/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.5210
# Epoch 76: loss improved from 0.68012 to 0.67970, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 11ms/step - loss: 0.6797 - accuracy: 0.5210 - val_loss: 0.6957 - val_accuracy: 0.5093
# Epoch 77/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.5189
# Epoch 77: loss did not improve from 0.67970
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6797 - accuracy: 0.5189 - val_loss: 0.6948 - val_accuracy: 0.5031
# Epoch 78/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6792 - accuracy: 0.5256
# Epoch 78: loss did not improve from 0.67970
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6798 - accuracy: 0.5262 - val_loss: 0.6957 - val_accuracy: 0.5093
# Epoch 79/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6804 - accuracy: 0.5186
# Epoch 79: loss did not improve from 0.67970
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6804 - accuracy: 0.5184 - val_loss: 0.6936 - val_accuracy: 0.4938
# Epoch 80/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6807 - accuracy: 0.5253
# Epoch 80: loss did not improve from 0.67970
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6801 - accuracy: 0.5270 - val_loss: 0.6932 - val_accuracy: 0.4845
# Epoch 81/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6800 - accuracy: 0.5142
# Epoch 81: loss did not improve from 0.67970
# 181/181 [==============================] - 4s 21ms/step - loss: 0.6800 - accuracy: 0.5142 - val_loss: 0.6929 - val_accuracy: 0.5186
# Epoch 82/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6787 - accuracy: 0.5314
# Epoch 82: loss improved from 0.67970 to 0.67873, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 18ms/step - loss: 0.6787 - accuracy: 0.5322 - val_loss: 0.6923 - val_accuracy: 0.5342
# Epoch 83/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6798 - accuracy: 0.5246
# Epoch 83: loss did not improve from 0.67873
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6798 - accuracy: 0.5246 - val_loss: 0.6961 - val_accuracy: 0.4891
# Epoch 84/100
# 176/181 [============================>.] - ETA: 0s - loss: 0.6793 - accuracy: 0.5170
# Epoch 84: loss did not improve from 0.67873
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6794 - accuracy: 0.5168 - val_loss: 0.6988 - val_accuracy: 0.4953
# Epoch 85/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6787 - accuracy: 0.5239
# Epoch 85: loss improved from 0.67873 to 0.67862, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6786 - accuracy: 0.5246 - val_loss: 0.6983 - val_accuracy: 0.5078
# Epoch 86/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6794 - accuracy: 0.5186
# Epoch 86: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6794 - accuracy: 0.5186 - val_loss: 0.6924 - val_accuracy: 0.5047
# Epoch 87/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6798 - accuracy: 0.5184
# Epoch 87: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6796 - accuracy: 0.5189 - val_loss: 0.6947 - val_accuracy: 0.5016
# Epoch 88/100
# 181/181 [==============================] - ETA: 0s - loss: 0.6787 - accuracy: 0.5092
# Epoch 88: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 12ms/step - loss: 0.6787 - accuracy: 0.5092 - val_loss: 0.6965 - val_accuracy: 0.4969
# Epoch 89/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6806 - accuracy: 0.5210
# Epoch 89: loss did not improve from 0.67862
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6805 - accuracy: 0.5212 - val_loss: 0.6961 - val_accuracy: 0.4891
# Epoch 90/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6796 - accuracy: 0.5157
# Epoch 90: loss did not improve from 0.67862
# 181/181 [==============================] - 3s 15ms/step - loss: 0.6791 - accuracy: 0.5167 - val_loss: 0.6957 - val_accuracy: 0.4845
# Epoch 91/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6789 - accuracy: 0.5182
# Epoch 91: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6794 - accuracy: 0.5187 - val_loss: 0.6928 - val_accuracy: 0.5093
# Epoch 92/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6794 - accuracy: 0.5186
# Epoch 92: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6793 - accuracy: 0.5193 - val_loss: 0.6938 - val_accuracy: 0.4922
# Epoch 93/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6789 - accuracy: 0.5184
# Epoch 93: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6791 - accuracy: 0.5187 - val_loss: 0.6985 - val_accuracy: 0.5078
# Epoch 94/100
# 179/181 [============================>.] - ETA: 0s - loss: 0.6794 - accuracy: 0.5185
# Epoch 94: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 8ms/step - loss: 0.6794 - accuracy: 0.5177 - val_loss: 0.6896 - val_accuracy: 0.5295
# Epoch 95/100
# 177/181 [============================>.] - ETA: 0s - loss: 0.6791 - accuracy: 0.5208
# Epoch 95: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6793 - accuracy: 0.5205 - val_loss: 0.6969 - val_accuracy: 0.5047
# Epoch 96/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6796 - accuracy: 0.5214
# Epoch 96: loss did not improve from 0.67862
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6792 - accuracy: 0.5218 - val_loss: 0.6895 - val_accuracy: 0.5217
# Epoch 97/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6783 - accuracy: 0.5198
# Epoch 97: loss did not improve from 0.67862
# 181/181 [==============================] - 3s 16ms/step - loss: 0.6789 - accuracy: 0.5189 - val_loss: 0.6935 - val_accuracy: 0.4891
# Epoch 98/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6786 - accuracy: 0.5217
# Epoch 98: loss improved from 0.67862 to 0.67851, saving model to drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5
# 181/181 [==============================] - 3s 17ms/step - loss: 0.6785 - accuracy: 0.5218 - val_loss: 0.6903 - val_accuracy: 0.5124
# Epoch 99/100
# 180/181 [============================>.] - ETA: 0s - loss: 0.6792 - accuracy: 0.5274
# Epoch 99: loss did not improve from 0.67851
# 181/181 [==============================] - 2s 9ms/step - loss: 0.6791 - accuracy: 0.5275 - val_loss: 0.6981 - val_accuracy: 0.4798
# Epoch 100/100
# 178/181 [============================>.] - ETA: 0s - loss: 0.6791 - accuracy: 0.5260
# Epoch 100: loss did not improve from 0.67851
# 181/181 [==============================] - 2s 10ms/step - loss: 0.6789 - accuracy: 0.5253 - val_loss: 0.6894 - val_accuracy: 0.5280

# %%
# print(train_sh.history)
# model = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5')
model.save('drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5')
results = model.evaluate([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test], ae_test, batch_size=16)

predictions = model.predict([tn_test, td_test, tl_test, pe_test, fe_test, rfi_test])

print(predictions.shape)
print(ae_test.shape)

y_actual_label = test_df_res["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)
print(y_actual_label.shape, y_pred_label.shape)

test_df_res['Ai_estimate'] = y_pred_label
test_df_res.head(3)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.5280
# 21/21 [==============================] - 0s 3ms/step
# (644, 26)
# (644, 26)
# (644,) (644, 1)
#    Unnamed: 0.1  Unnamed: 0  \
# 0          2436        2262
# 1          3361        3187
# 2           233          59
#
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  ...  \
# 0  INT Sprint 1                16               16          15  ...
# 1  INT Sprint 1                 4                5           3  ...
# 2  INT Sprint 1                 4                4           3  ...
#
#    Standard_deviation  Risk_factor  Standard_confidence  High_confidence  \
# 0                0.17         0.01                15.83            15.92
# 1                0.17         0.04                 3.83             3.92
# 2                0.33         0.08                 4.00             4.17
#
#    Higher_confidence  Highest_confidence  Final_estimate  Variance  \
# 0              16.05               16.23              15      6561
# 1               4.05                4.23               3       441
# 2               4.42                4.77               4       729
#
#    Risk_factor_int  Ai_estimate
# 0                1           17
# 1                4            5
# 2                8            5
#
# [3 rows x 23 columns]

# %%
test_df_res.drop(test_df_res.columns[[0, 1]], axis=1, inplace=True)

# %%
test_df_res.head(3)
# Out:
#                                            Task_name  \
# 0  [New Containers] Remove input/process dotted l...
# 1         Studio support for new OAuth configuration
# 2  migrate items from 562 get error dialog popup,...
#
#                                     Task_description Task_label Task_priority  \
# 0  Right now the flow container has a dashed line...     EST_BE        Medium
# 1  As a Studio user, I will like to have support ...     EST_BE        Medium
# 2  1. start 562 tac, on configuration page select...     EST_BE        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0  INT Sprint 1                16               16          15           16
# 1  INT Sprint 1                 4                5           3            4
# 2  INT Sprint 1                 4                4           3            4
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           16  ...                0.17         0.01                15.83
# 1            4  ...                0.17         0.04                 3.83
# 2            5  ...                0.33         0.08                 4.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            15.92              16.05               16.23              15
# 1             3.92               4.05                4.23               3
# 2             4.17               4.42                4.77               4
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      6561                1           17
# 1       441                4            5
# 2       729                8            5
#
# [3 rows x 21 columns]

# %%
test_df_res.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/Model4_results.csv')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = test_df_res['Ai_estimate']
x = test_df_res['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
# prepare testing data

# %%
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_data.csv')

# %%
df_test.shape
# Out:
# (21, 7)

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate
# 0   ET Sprint 4                16               16
# 1   ET Sprint 4                 4                4
# 2   ET Sprint 4                 8                9

# %%
import numpy as np

# %%
df_test["Optimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 1, df_test.shape[0])
df_test["Most_likely"] = df_test["Planned_estimate"] + np.random.randint(0, 2, df_test.shape[0])
df_test["Pessimistic"] = df_test["Planned_estimate"] + np.random.randint(0, 3, df_test.shape[0])

# %%
df_test["Weighted_average"] = round(((df_test["Optimistic"] + (4*df_test["Most_likely"]) + df_test["Pessimistic"])/6), 2)
df_test["Standard_deviation"] = round(((df_test["Pessimistic"] - df_test["Optimistic"])/6), 2)
df_test["Risk_factor"] = round((df_test["Standard_deviation"]/df_test["Weighted_average"]), 2)
df_test["Standard_confidence"] = df_test["Weighted_average"]
df_test["High_confidence"] = round((df_test["Weighted_average"] + (0.53 * df_test["Standard_deviation"])), 2)
df_test["Higher_confidence"] = round((df_test["Weighted_average"] + (1.28 * df_test["Standard_deviation"])), 2)
df_test["Highest_confidence"] = round((df_test["Weighted_average"] + (2.33 * df_test["Standard_deviation"])), 2)
df_test["Final_estimate"] = round((df_test["Highest_confidence"]), 1)
df_test["Variance"] = round(((6*df_test["Pessimistic"] - df_test["Optimistic"])**2), 2)
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] >= 0) & (df_test['Risk_factor'] <= 0.05), df_test['Standard_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.05) & (df_test['Risk_factor'] <= 0.1), df_test['High_confidence'], df_test['Final_estimate'])
df_test['Final_estimate'] = np.where((df_test['Risk_factor'] > 0.1) & (df_test['Risk_factor'] <= 0.15), df_test['Higher_confidence'], df_test['Final_estimate'])
df_test["Final_estimate"] = df_test["Final_estimate"].astype(int)
df_test["Risk_factor_int"] = (df_test["Risk_factor"]*100).astype(int)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/test_data_complete.csv')

# %%
### Start

# %%
# need to change this
df_test = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/test_data_complete.csv')

# %%
df_test.shape
# Out:
# (21, 21)

# %%
df_test.head(3)
# Out:
#    Unnamed: 0                                          Task_name  \
# 0           0              Set up JDK and integrate with backend
# 1           1            Set up environment and install packages
# 2           2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            4
# 2   ET Sprint 4                 8                9           8            9
#
#    ...  Weighted_average  Standard_deviation  Risk_factor  \
# 0  ...             16.83                0.17         0.01
# 1  ...              4.33                0.33         0.08
# 2  ...              9.00                0.33         0.04
#
#    Standard_confidence  High_confidence  Higher_confidence  \
# 0                16.83            16.92              17.05
# 1                 4.33             4.50               4.75
# 2                 9.00             9.17               9.42
#
#    Highest_confidence  Final_estimate  Variance  Risk_factor_int
# 0               17.23              16      7396                1
# 1                5.10               4      1024                8
# 2                9.77               9      2704                4
#
# [3 rows x 21 columns]

# %%
# Testing data encodings
tn_testdata = gpt_model.vectors(df_test["Task_name"])
print(type(tn_testdata))
print(tn_testdata.shape)

td_testdata = gpt_model.vectors(df_test["Task_description"])
print(type(td_testdata))
print(td_testdata.shape)

tl_testdata = df_test["Task_label"].to_numpy().reshape(-1,1)
tl_testdata = tl_enc.transform(tl_testdata)
print(tl_testdata.shape)

pe_testdata = df_test["Planned_estimate"].to_numpy().reshape(-1,1)
pe_testdata = pe_enc.transform(pe_testdata)
print(pe_testdata.shape)

fe_testdata = df_test["Final_estimate"].to_numpy().reshape(-1,1)
fe_testdata = fe_enc.transform(fe_testdata)
print(fe_testdata.shape)

rfi_testdata = df_test["Risk_factor_int"].to_numpy().reshape(-1,1)
rfi_testdata = rfi_enc.transform(rfi_testdata)
print(rfi_testdata.shape)
# Out:
# <class 'numpy.ndarray'>
# (21, 768)
# <class 'numpy.ndarray'>
# (21, 768)
# (21, 4)
# (21, 15)
# (21, 28)
# (21, 11)

# %%
import tensorflow as tf

# %%
model4 = tf.keras.models.load_model('drive/MyDrive/Colab Notebooks/Estimates/Model4/model4.h5')
model4.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer_1 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_2 (InputLayer)  [(None, 768)]                0         []
#
#  input_layer_3 (InputLayer)  [(None, 4)]                  0         []
#
#  input_layer_4 (InputLayer)  [(None, 15)]                 0         []
#
#  input_layer_5 (InputLayer)  [(None, 28)]                 0         []
#
#  input_layer_6 (InputLayer)  [(None, 11)]                 0         []
#
#  dense (Dense)               (None, 128)                  98432     ['input_layer_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  98432     ['input_layer_2[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    20        ['input_layer_3[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   256       ['input_layer_4[0][0]']
#
#  dense_4 (Dense)             (None, 32)                   928       ['input_layer_5[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   192       ['input_layer_6[0][0]']
#
#  concatenate (Concatenate)   (None, 324)                  0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]',
#                                                                      'dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 384)                  124800    ['concatenate[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  49280     ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 26)                   3354      ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 375694 (1.43 MB)
# Trainable params: 375694 (1.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
### Not required

# %%
from sklearn.preprocessing import OneHotEncoder

train_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/train_data.csv')
test_df_res = pd.read_csv('drive/MyDrive/Colab Notebooks/Estimates/test_df_res.csv')

#Actual_estimate
ae_enc = OneHotEncoder(sparse=False, handle_unknown='ignore')
ae_train = train_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_test = test_df_res["Actual_estimate"].to_numpy().reshape(-1,1)
ae_enc.fit(ae_train)
len_ae_enc = ae_enc.categories_[0].shape
print(len_ae_enc)

ae_train = ae_enc.transform(ae_train)
ae_test = ae_enc.transform(ae_test)
print(ae_train.shape, ae_test.shape)
# Out:
# (26,)
# (5791, 26) (644, 26)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
ae_testdata = df_test["Actual_estimate"].to_numpy().reshape(-1,1)
ae_testdata = ae_enc.transform(ae_testdata)
print(ae_testdata.shape)
# Out:
# (21, 26)

# %%
predictions = model4.predict([tn_testdata, td_testdata, tl_testdata, pe_testdata, fe_testdata, rfi_testdata])

print(predictions.shape)
print(ae_testdata.shape)

y_actual_label = df_test["Actual_estimate"]
y_pred_label = ae_enc.inverse_transform(predictions)

print(y_actual_label.shape, y_pred_label.shape)

df_test['Ai_estimate'] = y_pred_label

df_test.drop(df_test.columns[0], axis=1, inplace=True)
# Out:
# 1/1 [==============================] - 0s 214ms/step
# (21, 26)
# (21, 26)
# (21,) (21, 1)

# %%
df_test.to_csv('drive/MyDrive/Colab Notebooks/Estimates/Model4/Model4_results_testdata.csv')

# %%
df_test.head(3)
# Out:
#                                            Task_name  \
# 0              Set up JDK and integrate with backend
# 1            Set up environment and install packages
# 2  Create data preprocessing, feature engineering...
#
#                                     Task_description Task_label Task_priority  \
# 0  Setting up the Java Development Kit in the pro...     EST_BE        Medium
# 1  Setting up Python environment in AWS EC-2 Inst...  EST_INFRA        Medium
# 2  Data preprocessing - Data cleaning and transfo...     EST_AI        Medium
#
#   Sprint_number  Planned_estimate  Actual_estimate  Optimistic  Most_likely  \
# 0   ET Sprint 4                16               16          16           17
# 1   ET Sprint 4                 4                4           4            4
# 2   ET Sprint 4                 8                9           8            9
#
#    Pessimistic  ...  Standard_deviation  Risk_factor  Standard_confidence  \
# 0           17  ...                0.17         0.01                16.83
# 1            6  ...                0.33         0.08                 4.33
# 2           10  ...                0.33         0.04                 9.00
#
#    High_confidence  Higher_confidence  Highest_confidence  Final_estimate  \
# 0            16.92              17.05               17.23              16
# 1             4.50               4.75                5.10               4
# 2             9.17               9.42                9.77               9
#
#    Variance  Risk_factor_int  Ai_estimate
# 0      7396                1           16
# 1      1024                8            0
# 2      2704                4            7
#
# [3 rows x 21 columns]

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Final_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('3-point estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

y = df_test['Ai_estimate']
x = df_test['Actual_estimate']
correlation = y.corr(x)
correlation

# adds the title
plt.title('Correlation')

# plot the data
plt.scatter(x, y)

# fits the best fitting line to the data
plt.plot(np.unique(x),
		np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# Labelling axes
plt.xlabel('Actual estimate')
plt.ylabel('AI estimate')
# Out:
# Text(0, 0.5, 'AI estimate')
